# %%
import os
import sys

spark_home = "D:\spark-2.0.0-bin-hadoop2.7"
os.environ['SPARK_HOME'] = spark_home
sys.path.append(os.path.join(spark_home, "python"))
sys.path.append(os.path.join(spark_home, "python", "lib", "py4j-0.10.1-src.zip"))

execfile(os.path.join(spark_home, "python", "pyspark", "shell.py"))
# Out:
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 2.0.0
#       /_/
#
# Using Python version 2.7.12 (default, Jun 29 2016 11:07:13)
# SparkSession available as 'spark'.

# %%
import xmltodict
import json
communities = ['3dprinting.stackexchange.com', 'academia.stackexchange.com', 'ai.stackexchange.com', 'android.stackexchange.com', 'anime.stackexchange.com', 'apple.stackexchange.com', 'arabic.stackexchange.com', 'arduino.stackexchange.com', 'askubuntu.com', 'astronomy.stackexchange.com', 'aviation.stackexchange.com', 'avp.stackexchange.com', 'beer.stackexchange.com', 'bicycles.stackexchange.com', 'biology.stackexchange.com', 'bitcoin.stackexchange.com', 'blender.stackexchange.com', 'boardgames.stackexchange.com', 'bricks.stackexchange.com', 'buddhism.stackexchange.com', 'chemistry.stackexchange.com', 'chess.stackexchange.com', 'chinese.stackexchange.com', 'christianity.stackexchange.com', 'civicrm.stackexchange.com', 'codegolf.stackexchange.com', 'codereview.stackexchange.com', 'coffee.stackexchange.com', 'cogsci.stackexchange.com', 'computergraphics.stackexchange.com', 'cooking.stackexchange.com', 'craftcms.stackexchange.com', 'crafts.stackexchange.com', 'crypto.stackexchange.com', 'cs.stackexchange.com', 'cstheory.stackexchange.com', 'datascience.stackexchange.com', 'dba.stackexchange.com', 'diy.stackexchange.com', 'drupal.stackexchange.com', 'dsp.stackexchange.com', 'earthscience.stackexchange.com', 'ebooks.stackexchange.com', 'economics.stackexchange.com', 'electronics.stackexchange.com', 'elementaryos.stackexchange.com', 'ell.stackexchange.com', 'emacs.stackexchange.com', 'engineering.stackexchange.com', 'english.stackexchange.com', 'es.stackoverflow.com', 'ethereum.stackexchange.com', 'expatriates.stackexchange.com', 'expressionengine.stackexchange.com', 'fitness.stackexchange.com', 'freelancing.stackexchange.com', 'french.stackexchange.com', 'gamedev.stackexchange.com', 'gaming.stackexchange.com', 'gardening.stackexchange.com', 'genealogy.stackexchange.com', 'german.stackexchange.com', 'gis.stackexchange.com', 'graphicdesign.stackexchange.com', 'ham.stackexchange.com', 'hardwarerecs.stackexchange.com', 'health.stackexchange.com', 'hermeneutics.stackexchange.com', 'hinduism.stackexchange.com', 'history.stackexchange.com', 'homebrew.stackexchange.com', 'hsm.stackexchange.com', 'islam.stackexchange.com', 'italian.stackexchange.com', 'ja.stackoverflow.com', 'japanese.stackexchange.com', 'joomla.stackexchange.com', 'judaism.stackexchange.com', 'korean.stackexchange.com', 'languagelearning.stackexchange.com', 'latin.stackexchange.com', 'law.stackexchange.com', 'lifehacks.stackexchange.com', 'linguistics.stackexchange.com', 'magento.stackexchange.com', 'martialarts.stackexchange.com', 'math.stackexchange.com', 'matheducators.stackexchange.com', 'mathematica.stackexchange.com', 'mathoverflow.net', 'mechanics.stackexchange.com', 'meta.3dprinting.stackexchange.com', 'meta.academia.stackexchange.com', 'meta.ai.stackexchange.com', 'meta.android.stackexchange.com', 'meta.anime.stackexchange.com', 'meta.apple.stackexchange.com', 'meta.arabic.stackexchange.com', 'meta.arduino.stackexchange.com', 'meta.askubuntu.com', 'meta.astronomy.stackexchange.com', 'meta.aviation.stackexchange.com', 'meta.avp.stackexchange.com', 'meta.beer.stackexchange.com', 'meta.bicycles.stackexchange.com', 'meta.biology.stackexchange.com', 'meta.bitcoin.stackexchange.com', 'meta.blender.stackexchange.com', 'meta.boardgames.stackexchange.com', 'meta.bricks.stackexchange.com', 'meta.buddhism.stackexchange.com', 'meta.chemistry.stackexchange.com', 'meta.chess.stackexchange.com', 'meta.chinese.stackexchange.com', 'meta.christianity.stackexchange.com', 'meta.civicrm.stackexchange.com', 'meta.codegolf.stackexchange.com', 'meta.codereview.stackexchange.com', 'meta.coffee.stackexchange.com', 'meta.cogsci.stackexchange.com', 'meta.computergraphics.stackexchange.com', 'meta.cooking.stackexchange.com', 'meta.craftcms.stackexchange.com', 'meta.crafts.stackexchange.com', 'meta.crypto.stackexchange.com', 'meta.cs.stackexchange.com', 'meta.cstheory.stackexchange.com', 'meta.datascience.stackexchange.com', 'meta.dba.stackexchange.com', 'meta.diy.stackexchange.com', 'meta.drupal.stackexchange.com', 'meta.dsp.stackexchange.com', 'meta.earthscience.stackexchange.com', 'meta.ebooks.stackexchange.com', 'meta.economics.stackexchange.com', 'meta.electronics.stackexchange.com', 'meta.elementaryos.stackexchange.com', 'meta.ell.stackexchange.com', 'meta.emacs.stackexchange.com', 'meta.engineering.stackexchange.com', 'meta.english.stackexchange.com', 'meta.es.stackoverflow.com', 'meta.ethereum.stackexchange.com', 'meta.expatriates.stackexchange.com', 'meta.expressionengine.stackexchange.com', 'meta.fitness.stackexchange.com', 'meta.freelancing.stackexchange.com', 'meta.french.stackexchange.com', 'meta.gamedev.stackexchange.com', 'meta.gaming.stackexchange.com', 'meta.gardening.stackexchange.com', 'meta.genealogy.stackexchange.com', 'meta.german.stackexchange.com', 'meta.gis.stackexchange.com', 'meta.graphicdesign.stackexchange.com', 'meta.ham.stackexchange.com', 'meta.hardwarerecs.stackexchange.com', 'meta.health.stackexchange.com', 'meta.hermeneutics.stackexchange.com', 'meta.hinduism.stackexchange.com', 'meta.history.stackexchange.com', 'meta.homebrew.stackexchange.com', 'meta.hsm.stackexchange.com', 'meta.islam.stackexchange.com', 'meta.italian.stackexchange.com', 'meta.ja.stackoverflow.com', 'meta.japanese.stackexchange.com', 'meta.joomla.stackexchange.com', 'meta.judaism.stackexchange.com', 'meta.korean.stackexchange.com', 'meta.languagelearning.stackexchange.com', 'meta.latin.stackexchange.com', 'meta.law.stackexchange.com', 'meta.lifehacks.stackexchange.com', 'meta.linguistics.stackexchange.com', 'meta.magento.stackexchange.com', 'meta.martialarts.stackexchange.com', 'meta.math.stackexchange.com', 'meta.matheducators.stackexchange.com', 'meta.mathematica.stackexchange.com', 'meta.mathoverflow.net', 'meta.mechanics.stackexchange.com', 'meta.moderators.stackexchange.com', 'meta.monero.stackexchange.com', 'meta.money.stackexchange.com', 'meta.movies.stackexchange.com', 'meta.music.stackexchange.com', 'meta.musicfans.stackexchange.com', 'meta.mythology.stackexchange.com', 'meta.networkengineering.stackexchange.com', 'meta.opendata.stackexchange.com', 'meta.opensource.stackexchange.com', 'meta.outdoors.stackexchange.com', 'meta.parenting.stackexchange.com', 'meta.patents.stackexchange.com', 'meta.pets.stackexchange.com', 'meta.philosophy.stackexchange.com', 'meta.photo.stackexchange.com', 'meta.physics.stackexchange.com', 'meta.pm.stackexchange.com', 'meta.poker.stackexchange.com', 'meta.politics.stackexchange.com', 'meta.portuguese.stackexchange.com', 'meta.productivity.stackexchange.com', 'meta.programmers.stackexchange.com', 'meta.pt.stackoverflow.com', 'meta.puzzling.stackexchange.com', 'meta.quant.stackexchange.com', 'meta.raspberrypi.stackexchange.com', 'meta.retrocomputing.stackexchange.com', 'meta.reverseengineering.stackexchange.com', 'meta.robotics.stackexchange.com', 'meta.rpg.stackexchange.com', 'meta.ru.stackoverflow.com', 'meta.rus.stackexchange.com', 'meta.russian.stackexchange.com', 'meta.salesforce.stackexchange.com', 'meta.scicomp.stackexchange.com', 'meta.scifi.stackexchange.com', 'meta.security.stackexchange.com', 'meta.serverfault.com', 'meta.sharepoint.stackexchange.com', 'meta.skeptics.stackexchange.com', 'meta.softwarerecs.stackexchange.com', 'meta.sound.stackexchange.com', 'meta.space.stackexchange.com', 'meta.spanish.stackexchange.com', 'meta.sports.stackexchange.com', 'meta.sqa.stackexchange.com', 'meta.stackexchange.com', 'meta.stackoverflow.com', 'meta.startups.stackexchange.com', 'meta.stats.stackexchange.com', 'meta.superuser.com', 'meta.sustainability.stackexchange.com', 'meta.tex.stackexchange.com', 'meta.tor.stackexchange.com', 'meta.travel.stackexchange.com', 'meta.tridion.stackexchange.com', 'meta.unix.stackexchange.com', 'meta.ux.stackexchange.com', 'meta.vi.stackexchange.com', 'meta.webapps.stackexchange.com', 'meta.webmasters.stackexchange.com', 'meta.windowsphone.stackexchange.com', 'meta.woodworking.stackexchange.com', 'meta.wordpress.stackexchange.com', 'meta.workplace.stackexchange.com', 'meta.worldbuilding.stackexchange.com', 'meta.writers.stackexchange.com', 'moderators.stackexchange.com', 'monero.stackexchange.com', 'money.stackexchange.com', 'movies.stackexchange.com', 'music.stackexchange.com', 'musicfans.stackexchange.com', 'mythology.stackexchange.com', 'networkengineering.stackexchange.com', 'opendata.stackexchange.com', 'opensource.stackexchange.com', 'outdoors.stackexchange.com', 'parenting.stackexchange.com', 'patents.stackexchange.com', 'pets.stackexchange.com', 'philosophy.stackexchange.com', 'photo.stackexchange.com', 'physics.stackexchange.com', 'pm.stackexchange.com', 'poker.stackexchange.com', 'politics.stackexchange.com', 'portuguese.stackexchange.com', 'productivity.stackexchange.com', 'programmers.stackexchange.com', 'pt.stackoverflow.com', 'puzzling.stackexchange.com', 'quant.stackexchange.com', 'raspberrypi.stackexchange.com', 'retrocomputing.stackexchange.com', 'reverseengineering.stackexchange.com', 'robotics.stackexchange.com', 'rpg.stackexchange.com', 'ru.stackoverflow.com', 'rus.stackexchange.com', 'russian.stackexchange.com', 'salesforce.stackexchange.com', 'scicomp.stackexchange.com', 'scifi.stackexchange.com', 'security.stackexchange.com', 'serverfault.com', 'sharepoint.stackexchange.com', 'skeptics.stackexchange.com', 'softwarerecs.stackexchange.com', 'sound.stackexchange.com', 'space.stackexchange.com', 'spanish.stackexchange.com', 'sports.stackexchange.com', 'sqa.stackexchange.com', 'stackapps.com', 'stackoverflow.com', 'startups.stackexchange.com', 'stats.stackexchange.com', 'superuser.com', 'sustainability.stackexchange.com', 'tex.stackexchange.com', 'tor.stackexchange.com', 'travel.stackexchange.com', 'tridion.stackexchange.com', 'unix.stackexchange.com', 'ux.stackexchange.com', 'vi.stackexchange.com', 'webapps.stackexchange.com', 'webmasters.stackexchange.com', 'windowsphone.stackexchange.com', 'woodworking.stackexchange.com', 'wordpress.stackexchange.com', 'workplace.stackexchange.com', 'worldbuilding.stackexchange.com', 'writers.stackexchange.com'] 
# communities

# %%
# --------- count tags --------------
def get_tags(line):
    line = xmltodict.parse(line)
    creation_date = line['row']['@CreationDate'].split("-")
    yyyy_mm = str(creation_date[0] + "-" + creation_date[1])
    tags = line["row"]["@Tags"].replace("><", ",").replace("<", "").replace(">", "")
    tags = tags.split(",")
    return map(lambda x: (x, yyyy_mm), tags)

def group_by_date(x):
    creation_dates = {}
    for d in set(x):
        creation_dates[d] = list(x).count(d)
    return creation_dates
    
def count_tags(community="stats.stackexchange.com"):
    wtf = sc.textFile("E:\\stackexchange_Extracted\\" + community + "\\Posts.xml")
    tag_count = wtf.filter(lambda x: 'PostTypeId="1"' in x).flatMap(get_tags).groupByKey().mapValues(group_by_date)
    return tag_count.collect()

# --------- count questions --------------
def count_questions(community="stats.stackexchange.com"):
    wtf = sc.textFile("E:\\stackexchange_Extracted\\" + community + "\\Posts.xml")
    questions_count = wtf.filter(lambda x: 'PostTypeId="1"' in x).count()
    return questions_count
# --------- count answers --------------
def count_answers(community="stats.stackexchange.com"):
    wtf = sc.textFile("E:\\stackexchange_Extracted\\" + community + "\\Posts.xml")
    answers_count = wtf.filter(lambda x: 'PostTypeId="2"' in x).count()
    return answers_count

# %%
def start_task(fun, out_name=""):
    results = {}
    for community in communities:
        if community == "3dprinting.stackexchange.com":
            results["three_d_printing.stackexchange.com"] = fun(community)
        else:
            results[community] = fun(community)
    if out_name:
        with open(out_name + ".txt", "w") as f:
            f.write(json.dumps(results))
    return results

# %%
start_task(count_tags, "tags_count")

# %%
result = start_task(count_questions, "questions_count")

# %%
result2 = start_task(count_answers, "answers_count")

# %%
from pyspark.mllib.fpm import FPGrowth

data = sc.textFile("E:\\stackexchange_Extracted\\stackoverflow.com//Posts.xml")
transactions = data.filter(lambda x: 'PostTypeId="1"' in x).map(
    lambda line: [item.replace("<","").replace(">","") for item in xmltodict.parse(line)['row']["@Tags"].split('><')]
)
model = FPGrowth.train(transactions, minSupport=0.001, numPartitions=100)
result = model.freqItemsets().collect()
for fi in result:
    print(fi)
# Out:
# FreqItemset(items=[u'visual-c++'], freq=22847)
# FreqItemset(items=[u'tsql'], freq=40339)
# FreqItemset(items=[u'tsql', u'sql-server'], freq=25535)
# FreqItemset(items=[u'tsql', u'sql-server', u'sql'], freq=14571)
# FreqItemset(items=[u'tsql', u'sql'], freq=21266)
# FreqItemset(items=[u'visual-studio-2008'], freq=15429)
# FreqItemset(items=[u'javascript'], freq=1206321)
# FreqItemset(items=[u'loops'], freq=40338)
# FreqItemset(items=[u'jsf-2'], freq=15422)
# FreqItemset(items=[u'java'], freq=1128803)
# FreqItemset(items=[u'java', u'javascript'], freq=13814)
# FreqItemset(items=[u'image-processing'], freq=22740)
# FreqItemset(items=[u'c#'], freq=997465)
# FreqItemset(items=[u'c#', u'javascript'], freq=18354)
# FreqItemset(items=[u'networking'], freq=22651)
# FreqItemset(items=[u'actionscript-3'], freq=39984)
# FreqItemset(items=[u'encoding'], freq=15412)
# FreqItemset(items=[u'android-layout'], freq=39682)
# FreqItemset(items=[u'android-layout', u'android'], freq=38387)
# FreqItemset(items=[u'paypal'], freq=15401)
# FreqItemset(items=[u'php'], freq=969707)
# FreqItemset(items=[u'php', u'javascript'], freq=83898)
# FreqItemset(items=[u'visual-studio-2012'], freq=22509)
# FreqItemset(items=[u'sorting'], freq=39525)
# FreqItemset(items=[u'android-listview'], freq=15387)
# FreqItemset(items=[u'android-listview', u'android'], freq=14929)
# FreqItemset(items=[u'android'], freq=887010)
# FreqItemset(items=[u'android', u'java'], freq=159284)
# FreqItemset(items=[u'jquery-mobile'], freq=22493)
# FreqItemset(items=[u'jquery'], freq=770009)
# FreqItemset(items=[u'jquery', u'c#'], freq=12894)
# FreqItemset(items=[u'jquery', u'php'], freq=69941)
# FreqItemset(items=[u'jquery', u'php', u'javascript'], freq=33505)
# FreqItemset(items=[u'jquery', u'javascript'], freq=404396)
# FreqItemset(items=[u'android-activity'], freq=22446)
# FreqItemset(items=[u'android-activity', u'android'], freq=21532)
# FreqItemset(items=[u'email'], freq=39485)
# FreqItemset(items=[u'email', u'php'], freq=12737)
# FreqItemset(items=[u'groovy'], freq=15378)
# FreqItemset(items=[u'date'], freq=39212)
# FreqItemset(items=[u'primefaces'], freq=15352)
# FreqItemset(items=[u'python'], freq=624016)
# FreqItemset(items=[u'canvas'], freq=22431)
# FreqItemset(items=[u'canvas', u'javascript'], freq=12874)
# FreqItemset(items=[u'asp.net-mvc-3'], freq=38716)
# FreqItemset(items=[u'ssh'], freq=15302)
# FreqItemset(items=[u'html'], freq=572556)
# FreqItemset(items=[u'html', u'jquery'], freq=154971)
# FreqItemset(items=[u'html', u'jquery', u'php'], freq=12881)
# FreqItemset(items=[u'html', u'jquery', u'javascript'], freq=107479)
# FreqItemset(items=[u'html', u'php'], freq=74017)
# FreqItemset(items=[u'html', u'php', u'javascript'], freq=19346)
# FreqItemset(items=[u'html', u'javascript'], freq=222625)
# FreqItemset(items=[u'iframe'], freq=22309)
# FreqItemset(items=[u'c++'], freq=467183)
# FreqItemset(items=[u'memory'], freq=22278)
# FreqItemset(items=[u'security'], freq=38609)
# FreqItemset(items=[u'twitter-bootstrap-3'], freq=15291)
# FreqItemset(items=[u'design-patterns'], freq=22208)
# FreqItemset(items=[u'asp.net-mvc-4'], freq=38175)
# FreqItemset(items=[u'asp.net-mvc-4', u'c#'], freq=13710)
# FreqItemset(items=[u'asp.net-mvc-4', u'asp.net-mvc'], freq=14984)
# FreqItemset(items=[u'struct'], freq=15191)
# FreqItemset(items=[u'ios'], freq=457172)
# FreqItemset(items=[u'listview'], freq=38152)
# FreqItemset(items=[u'listview', u'android'], freq=27197)
# FreqItemset(items=[u'graph'], freq=15125)
# FreqItemset(items=[u'mysql'], freq=416697)
# FreqItemset(items=[u'mysql', u'java'], freq=18436)
# FreqItemset(items=[u'mysql', u'php'], freq=172825)
# FreqItemset(items=[u'recursion'], freq=22198)
# FreqItemset(items=[u'css'], freq=414362)
# FreqItemset(items=[u'css', u'jquery'], freq=94351)
# FreqItemset(items=[u'css', u'jquery', u'javascript'], freq=56313)
# FreqItemset(items=[u'css', u'html'], freq=242431)
# FreqItemset(items=[u'css', u'html', u'jquery'], freq=57591)
# FreqItemset(items=[u'css', u'html', u'jquery', u'javascript'], freq=39083)
# FreqItemset(items=[u'css', u'html', u'javascript'], freq=66650)
# FreqItemset(items=[u'css', u'php'], freq=14163)
# FreqItemset(items=[u'css', u'javascript'], freq=103121)
# FreqItemset(items=[u'logging'], freq=22181)
# FreqItemset(items=[u'http'], freq=37817)
# FreqItemset(items=[u'login'], freq=15081)
# FreqItemset(items=[u'powershell'], freq=37519)
# FreqItemset(items=[u'amazon-s3'], freq=15055)
# FreqItemset(items=[u'sql'], freq=347435)
# FreqItemset(items=[u'sql', u'c#'], freq=22871)
# FreqItemset(items=[u'sql', u'mysql'], freq=81843)
# FreqItemset(items=[u'sql', u'mysql', u'php'], freq=19800)
# FreqItemset(items=[u'sql', u'php'], freq=34454)
# FreqItemset(items=[u'core-data'], freq=22165)
# FreqItemset(items=[u'core-data', u'ios'], freq=12820)
# FreqItemset(items=[u'csv'], freq=37438)
# FreqItemset(items=[u'replace'], freq=15052)
# FreqItemset(items=[u'asp.net'], freq=297748)
# FreqItemset(items=[u'asp.net', u'c#'], freq=130612)
# FreqItemset(items=[u'asp.net', u'jquery'], freq=21824)
# FreqItemset(items=[u'asp.net', u'javascript'], freq=27180)
# FreqItemset(items=[u'gridview'], freq=22040)
# FreqItemset(items=[u'gridview', u'asp.net'], freq=12416)
# FreqItemset(items=[u'objective-c'], freq=265171)
# FreqItemset(items=[u'objective-c', u'ios'], freq=146352)
# FreqItemset(items=[u'reactjs'], freq=22022)
# FreqItemset(items=[u'oop'], freq=37435)
# FreqItemset(items=[u'yii'], freq=15034)
# FreqItemset(items=[u'spring-mvc'], freq=37076)
# FreqItemset(items=[u'spring-mvc', u'java'], freq=19691)
# FreqItemset(items=[u'spring-mvc', u'spring'], freq=21298)
# FreqItemset(items=[u'spring-mvc', u'spring', u'java'], freq=13018)
# FreqItemset(items=[u'typescript'], freq=14978)
# FreqItemset(items=[u'ruby-on-rails'], freq=253926)
# FreqItemset(items=[u'razor'], freq=21978)
# FreqItemset(items=[u'user-interface'], freq=36926)
# FreqItemset(items=[u'docker'], freq=14959)
# FreqItemset(items=[u'.net'], freq=238907)
# FreqItemset(items=[u'.net', u'c#'], freq=143885)
# FreqItemset(items=[u'.net', u'asp.net'], freq=20190)
# FreqItemset(items=[u'd3.js'], freq=21859)
# FreqItemset(items=[u'd3.js', u'javascript'], freq=14388)
# FreqItemset(items=[u'c'], freq=226138)
# FreqItemset(items=[u'c', u'c++'], freq=30588)
# FreqItemset(items=[u'activerecord'], freq=21773)
# FreqItemset(items=[u'activerecord', u'ruby-on-rails'], freq=16591)
# FreqItemset(items=[u'delphi'], freq=36567)
# FreqItemset(items=[u'collections'], freq=14924)
# FreqItemset(items=[u'assembly'], freq=21759)
# FreqItemset(items=[u'google-app-engine'], freq=36271)
# FreqItemset(items=[u'view'], freq=14921)
# FreqItemset(items=[u'iphone'], freq=214296)
# FreqItemset(items=[u'iphone', u'objective-c'], freq=72489)
# FreqItemset(items=[u'iphone', u'objective-c', u'ios'], freq=35090)
# FreqItemset(items=[u'iphone', u'ios'], freq=90635)
# FreqItemset(items=[u'parsing'], freq=36196)
# FreqItemset(items=[u'ios7'], freq=14920)
# FreqItemset(items=[u'angularjs'], freq=195020)
# FreqItemset(items=[u'angularjs', u'html'], freq=13034)
# FreqItemset(items=[u'angularjs', u'javascript'], freq=88209)
# FreqItemset(items=[u'cookies'], freq=21659)
# FreqItemset(items=[u'arrays'], freq=192669)
# FreqItemset(items=[u'arrays', u'c++'], freq=15076)
# FreqItemset(items=[u'arrays', u'c'], freq=15181)
# FreqItemset(items=[u'arrays', u'java'], freq=28834)
# FreqItemset(items=[u'arrays', u'php'], freq=46162)
# FreqItemset(items=[u'arrays', u'javascript'], freq=27880)
# FreqItemset(items=[u'encryption'], freq=21400)
# FreqItemset(items=[u'cocoa'], freq=35600)
# FreqItemset(items=[u'cocoa', u'objective-c'], freq=17728)
# FreqItemset(items=[u'uiview'], freq=14909)
# FreqItemset(items=[u'jquery-ui'], freq=35427)
# FreqItemset(items=[u'jquery-ui', u'jquery'], freq=27761)
# FreqItemset(items=[u'deployment'], freq=14886)
# FreqItemset(items=[u'sql-server'], freq=175489)
# FreqItemset(items=[u'sql-server', u'c#'], freq=21529)
# FreqItemset(items=[u'sql-server', u'sql'], freq=76000)
# FreqItemset(items=[u'heroku'], freq=21317)
# FreqItemset(items=[u'magento'], freq=35031)
# FreqItemset(items=[u'command-line'], freq=14808)
# FreqItemset(items=[u'json'], freq=168655)
# FreqItemset(items=[u'json', u'c#'], freq=12543)
# FreqItemset(items=[u'json', u'jquery'], freq=28037)
# FreqItemset(items=[u'json', u'jquery', u'javascript'], freq=13891)
# FreqItemset(items=[u'json', u'android'], freq=16335)
# FreqItemset(items=[u'json', u'java'], freq=20088)
# FreqItemset(items=[u'json', u'php'], freq=25592)
# FreqItemset(items=[u'json', u'javascript'], freq=40061)
# FreqItemset(items=[u'optimization'], freq=21028)
# FreqItemset(items=[u'ruby'], freq=167095)
# FreqItemset(items=[u'ruby', u'ruby-on-rails'], freq=79905)
# FreqItemset(items=[u'serialization'], freq=20947)
# FreqItemset(items=[u'flash'], freq=34118)
# FreqItemset(items=[u'flash', u'actionscript-3'], freq=16395)
# FreqItemset(items=[u'sed'], freq=14763)
# FreqItemset(items=[u'internet-explorer'], freq=33924)
# FreqItemset(items=[u'angularjs-directive'], freq=14700)
# FreqItemset(items=[u'angularjs-directive', u'angularjs'], freq=14322)
# FreqItemset(items=[u'ajax'], freq=152715)
# FreqItemset(items=[u'ajax', u'jquery'], freq=85449)
# FreqItemset(items=[u'ajax', u'jquery', u'php'], freq=24948)
# FreqItemset(items=[u'ajax', u'jquery', u'javascript'], freq=40137)
# FreqItemset(items=[u'ajax', u'json'], freq=12929)
# FreqItemset(items=[u'ajax', u'html'], freq=13508)
# FreqItemset(items=[u'ajax', u'php'], freq=43000)
# FreqItemset(items=[u'ajax', u'php', u'javascript'], freq=19102)
# FreqItemset(items=[u'ajax', u'javascript'], freq=66998)
# FreqItemset(items=[u'model-view-controller'], freq=20909)
# FreqItemset(items=[u'ipad'], freq=33764)
# FreqItemset(items=[u'ipad', u'ios'], freq=17997)
# FreqItemset(items=[u'ipad', u'iphone'], freq=17921)
# FreqItemset(items=[u'printing'], freq=14691)
# FreqItemset(items=[u'regex'], freq=151779)
# FreqItemset(items=[u'regex', u'c#'], freq=12617)
# FreqItemset(items=[u'regex', u'java'], freq=15800)
# FreqItemset(items=[u'regex', u'php'], freq=23281)
# FreqItemset(items=[u'regex', u'python'], freq=14620)
# FreqItemset(items=[u'regex', u'javascript'], freq=21013)
# FreqItemset(items=[u'xpath'], freq=20906)
# FreqItemset(items=[u'r'], freq=150981)
# FreqItemset(items=[u'sharepoint'], freq=20840)
# FreqItemset(items=[u'cocoa-touch'], freq=33664)
# FreqItemset(items=[u'cocoa-touch', u'objective-c'], freq=17199)
# FreqItemset(items=[u'cocoa-touch', u'ios'], freq=16675)
# FreqItemset(items=[u'cocoa-touch', u'iphone'], freq=15211)
# FreqItemset(items=[u'django-models'], freq=14629)
# FreqItemset(items=[u'django-models', u'django'], freq=13913)
# FreqItemset(items=[u'extjs'], freq=20807)
# FreqItemset(items=[u'azure'], freq=33546)
# FreqItemset(items=[u'google-chrome-extension'], freq=14580)
# FreqItemset(items=[u'xml'], freq=143846)
# FreqItemset(items=[u'xml', u'c#'], freq=20943)
# FreqItemset(items=[u'xml', u'android'], freq=19891)
# FreqItemset(items=[u'xml', u'java'], freq=24729)
# FreqItemset(items=[u'xml', u'php'], freq=14087)
# FreqItemset(items=[u'datetime'], freq=33318)
# FreqItemset(items=[u'scroll'], freq=14556)
# FreqItemset(items=[u'asp.net-mvc'], freq=140834)
# FreqItemset(items=[u'asp.net-mvc', u'c#'], freq=49806)
# FreqItemset(items=[u'asp.net-mvc', u'jquery'], freq=15390)
# FreqItemset(items=[u'asp.net-mvc', u'asp.net'], freq=26036)
# FreqItemset(items=[u'matrix'], freq=20803)
# FreqItemset(items=[u'node.js'], freq=138107)
# FreqItemset(items=[u'node.js', u'javascript'], freq=50142)
# FreqItemset(items=[u'mobile'], freq=20749)
# FreqItemset(items=[u'opencv'], freq=33239)
# FreqItemset(items=[u'opencv', u'c++'], freq=12769)
# FreqItemset(items=[u'utf-8'], freq=14474)
# FreqItemset(items=[u'debugging'], freq=32990)
# FreqItemset(items=[u'emacs'], freq=14435)
# FreqItemset(items=[u'linux'], freq=130786)
# FreqItemset(items=[u'linux', u'c'], freq=18377)
# FreqItemset(items=[u'nginx'], freq=20747)
# FreqItemset(items=[u'templates'], freq=32801)
# FreqItemset(items=[u'templates', u'c++'], freq=18464)
# FreqItemset(items=[u'graphics'], freq=14415)
# FreqItemset(items=[u'django'], freq=126363)
# FreqItemset(items=[u'django', u'python'], freq=62813)
# FreqItemset(items=[u'svg'], freq=20690)
# FreqItemset(items=[u'wpf'], freq=122206)
# FreqItemset(items=[u'wpf', u'c#'], freq=69185)
# FreqItemset(items=[u'wpf', u'.net'], freq=12576)
# FreqItemset(items=[u'jdbc'], freq=20119)
# FreqItemset(items=[u'jdbc', u'java'], freq=14306)
# FreqItemset(items=[u'ruby-on-rails-4'], freq=32686)
# FreqItemset(items=[u'ruby-on-rails-4', u'ruby-on-rails'], freq=22989)
# FreqItemset(items=[u'solr'], freq=14394)
# FreqItemset(items=[u'session'], freq=32684)
# FreqItemset(items=[u'session', u'php'], freq=14524)
# FreqItemset(items=[u'amazon-ec2'], freq=14229)
# FreqItemset(items=[u'database'], freq=116904)
# FreqItemset(items=[u'database', u'mysql'], freq=32070)
# FreqItemset(items=[u'database', u'sql'], freq=25813)
# FreqItemset(items=[u'database', u'php'], freq=18586)
# FreqItemset(items=[u'windows-phone-7'], freq=20064)
# FreqItemset(items=[u'c++11'], freq=32526)
# FreqItemset(items=[u'c++11', u'c++'], freq=28621)
# FreqItemset(items=[u'tcp'], freq=14221)
# FreqItemset(items=[u'swift'], freq=110987)
# FreqItemset(items=[u'swift', u'ios'], freq=69190)
# FreqItemset(items=[u'soap'], freq=19983)
# FreqItemset(items=[u'xcode'], freq=104151)
# FreqItemset(items=[u'xcode', u'objective-c'], freq=31145)
# FreqItemset(items=[u'xcode', u'objective-c', u'ios'], freq=16189)
# FreqItemset(items=[u'xcode', u'swift'], freq=12882)
# FreqItemset(items=[u'xcode', u'ios'], freq=53255)
# FreqItemset(items=[u'xcode', u'iphone'], freq=26280)
# FreqItemset(items=[u'xcode', u'iphone', u'ios'], freq=12854)
# FreqItemset(items=[u'backbone.js'], freq=19983)
# FreqItemset(items=[u'variables'], freq=32297)
# FreqItemset(items=[u'datagridview'], freq=14173)
# FreqItemset(items=[u'github'], freq=19949)
# FreqItemset(items=[u'batch-file'], freq=32149)
# FreqItemset(items=[u'dataframe'], freq=14172)
# FreqItemset(items=[u'vb.net'], freq=102568)
# FreqItemset(items=[u'vb.net', u'asp.net'], freq=15721)
# FreqItemset(items=[u'vb.net', u'.net'], freq=13756)
# FreqItemset(items=[u'selenium'], freq=32122)
# FreqItemset(items=[u'charts'], freq=14121)
# FreqItemset(items=[u'excel'], freq=101411)
# FreqItemset(items=[u'web'], freq=19917)
# FreqItemset(items=[u'string'], freq=101309)
# FreqItemset(items=[u'string', u'java'], freq=21009)
# FreqItemset(items=[u'layout'], freq=19864)
# FreqItemset(items=[u'pointers'], freq=31848)
# FreqItemset(items=[u'pointers', u'c'], freq=14890)
# FreqItemset(items=[u'pointers', u'c++'], freq=13956)
# FreqItemset(items=[u'makefile'], freq=14100)
# FreqItemset(items=[u'unix'], freq=31789)
# FreqItemset(items=[u'junit'], freq=14089)
# FreqItemset(items=[u'eclipse'], freq=100451)
# FreqItemset(items=[u'eclipse', u'android'], freq=25067)
# FreqItemset(items=[u'eclipse', u'java'], freq=44948)
# FreqItemset(items=[u'elasticsearch'], freq=19838)
# FreqItemset(items=[u'jsf'], freq=30888)
# FreqItemset(items=[u'highcharts'], freq=14033)
# FreqItemset(items=[u'windows'], freq=99454)
# FreqItemset(items=[u'windows', u'c++'], freq=14899)
# FreqItemset(items=[u'vim'], freq=19832)
# FreqItemset(items=[u'wordpress'], freq=97839)
# FreqItemset(items=[u'wordpress', u'php'], freq=43116)
# FreqItemset(items=[u'ember.js'], freq=19656)
# FreqItemset(items=[u'ubuntu'], freq=30875)
# FreqItemset(items=[u'laravel-4'], freq=13920)
# FreqItemset(items=[u'object'], freq=30656)
# FreqItemset(items=[u'vbscript'], freq=13835)
# FreqItemset(items=[u'spring'], freq=94541)
# FreqItemset(items=[u'spring', u'java'], freq=55119)
# FreqItemset(items=[u'gwt'], freq=19628)
# FreqItemset(items=[u'spring-security'], freq=13779)
# FreqItemset(items=[u'html5'], freq=94169)
# FreqItemset(items=[u'html5', u'css'], freq=18099)
# FreqItemset(items=[u'html5', u'jquery'], freq=18521)
# FreqItemset(items=[u'html5', u'html'], freq=21399)
# FreqItemset(items=[u'html5', u'javascript'], freq=41493)
# FreqItemset(items=[u'zend-framework'], freq=19627)
# FreqItemset(items=[u'amazon-web-services'], freq=30589)
# FreqItemset(items=[u'multithreading'], freq=88618)
# FreqItemset(items=[u'multithreading', u'c#'], freq=17500)
# FreqItemset(items=[u'multithreading', u'java'], freq=25730)
# FreqItemset(items=[u'google-maps-api-3'], freq=19615)
# FreqItemset(items=[u'ms-access'], freq=30589)
# FreqItemset(items=[u'joomla'], freq=13766)
# FreqItemset(items=[u'memory-management'], freq=19546)
# FreqItemset(items=[u'tomcat'], freq=29991)
# FreqItemset(items=[u'tomcat', u'java'], freq=15997)
# FreqItemset(items=[u'types'], freq=13760)
# FreqItemset(items=[u'git'], freq=75236)
# FreqItemset(items=[u'android-studio'], freq=29686)
# FreqItemset(items=[u'android-studio', u'android'], freq=24089)
# FreqItemset(items=[u'plsql'], freq=13735)
# FreqItemset(items=[u'facebook'], freq=74646)
# FreqItemset(items=[u'arraylist'], freq=19400)
# FreqItemset(items=[u'arraylist', u'java'], freq=15203)
# FreqItemset(items=[u'image'], freq=74280)
# FreqItemset(items=[u'unity3d'], freq=19379)
# FreqItemset(items=[u'hadoop'], freq=29542)
# FreqItemset(items=[u'foreach'], freq=13705)
# FreqItemset(items=[u'haskell'], freq=29172)
# FreqItemset(items=[u'webview'], freq=13688)
# FreqItemset(items=[u'forms'], freq=74239)
# FreqItemset(items=[u'forms', u'jquery'], freq=14471)
# FreqItemset(items=[u'forms', u'html'], freq=17361)
# FreqItemset(items=[u'forms', u'php'], freq=23225)
# FreqItemset(items=[u'forms', u'javascript'], freq=17464)
# FreqItemset(items=[u'checkbox'], freq=19312)
# FreqItemset(items=[u'pandas'], freq=28844)
# FreqItemset(items=[u'pandas', u'python'], freq=25559)
# FreqItemset(items=[u'memory-leaks'], freq=13620)
# FreqItemset(items=[u'oracle'], freq=74014)
# FreqItemset(items=[u'oracle', u'sql'], freq=31660)
# FreqItemset(items=[u'twitter'], freq=19283)
# FreqItemset(items=[u'bash'], freq=72696)
# FreqItemset(items=[u'bash', u'linux'], freq=17989)
# FreqItemset(items=[u'asp.net-web-api'], freq=19157)
# FreqItemset(items=[u'facebook-graph-api'], freq=28764)
# FreqItemset(items=[u'facebook-graph-api', u'facebook'], freq=20919)
# FreqItemset(items=[u'google-apps-script'], freq=13555)
# FreqItemset(items=[u'url'], freq=28746)
# FreqItemset(items=[u'rspec'], freq=13554)
# FreqItemset(items=[u'osx'], freq=70438)
# FreqItemset(items=[u'boost'], freq=19065)
# FreqItemset(items=[u'boost', u'c++'], freq=16584)
# FreqItemset(items=[u'tfs'], freq=13521)
# FreqItemset(items=[u'twitter-bootstrap'], freq=69088)
# FreqItemset(items=[u'twitter-bootstrap', u'css'], freq=30023)
# FreqItemset(items=[u'twitter-bootstrap', u'css', u'html'], freq=17677)
# FreqItemset(items=[u'twitter-bootstrap', u'jquery'], freq=19980)
# FreqItemset(items=[u'twitter-bootstrap', u'html'], freq=23523)
# FreqItemset(items=[u'twitter-bootstrap', u'javascript'], freq=18172)
# FreqItemset(items=[u'file-upload'], freq=19052)
# FreqItemset(items=[u'authentication'], freq=28708)
# FreqItemset(items=[u'mongodb'], freq=69027)
# FreqItemset(items=[u'mongodb', u'node.js'], freq=15511)
# FreqItemset(items=[u'multidimensional-array'], freq=19044)
# FreqItemset(items=[u'firefox'], freq=28505)
# FreqItemset(items=[u'ggplot2'], freq=13510)
# FreqItemset(items=[u'ggplot2', u'r'], freq=13355)
# FreqItemset(items=[u'matplotlib'], freq=18954)
# FreqItemset(items=[u'matplotlib', u'python'], freq=16390)
# FreqItemset(items=[u'android-fragments'], freq=28336)
# FreqItemset(items=[u'android-fragments', u'android'], freq=27400)
# FreqItemset(items=[u'lambda'], freq=13435)
# FreqItemset(items=[u'winforms'], freq=68924)
# FreqItemset(items=[u'winforms', u'c#'], freq=54181)
# FreqItemset(items=[u'winforms', u'.net'], freq=15051)
# FreqItemset(items=[u'pdf'], freq=28237)
# FreqItemset(items=[u'linq-to-sql'], freq=13399)
# FreqItemset(items=[u'vba'], freq=68160)
# FreqItemset(items=[u'vba', u'excel'], freq=38956)
# FreqItemset(items=[u'text'], freq=18937)
# FreqItemset(items=[u'algorithm'], freq=67428)
# FreqItemset(items=[u'vector'], freq=18900)
# FreqItemset(items=[u'numpy'], freq=28118)
# FreqItemset(items=[u'numpy', u'python'], freq=25669)
# FreqItemset(items=[u'ionic-framework'], freq=13381)
# FreqItemset(items=[u'winapi'], freq=27970)
# FreqItemset(items=[u'ant'], freq=13376)
# FreqItemset(items=[u'apache'], freq=66037)
# FreqItemset(items=[u'apache', u'php'], freq=19650)
# FreqItemset(items=[u'netbeans'], freq=18781)
# FreqItemset(items=[u'silverlight'], freq=27724)
# FreqItemset(items=[u'syntax'], freq=13350)
# FreqItemset(items=[u'performance'], freq=64130)
# FreqItemset(items=[u'parse.com'], freq=18765)
# FreqItemset(items=[u'matlab'], freq=63946)
# FreqItemset(items=[u'random'], freq=18740)
# FreqItemset(items=[u'animation'], freq=27562)
# FreqItemset(items=[u'oauth'], freq=13276)
# FreqItemset(items=[u'generics'], freq=27541)
# FreqItemset(items=[u'javascript-events'], freq=13266)
# FreqItemset(items=[u'swing'], freq=62506)
# FreqItemset(items=[u'swing', u'java'], freq=61124)
# FreqItemset(items=[u'windows-phone-8'], freq=18519)
# FreqItemset(items=[u'https'], freq=13168)
# FreqItemset(items=[u'entity-framework'], freq=60868)
# FreqItemset(items=[u'entity-framework', u'c#'], freq=32984)
# FreqItemset(items=[u'browser'], freq=18407)
# FreqItemset(items=[u'if-statement'], freq=27502)
# FreqItemset(items=[u'visual-studio'], freq=59325)
# FreqItemset(items=[u'visual-studio', u'c#'], freq=17444)
# FreqItemset(items=[u'mvvm'], freq=18311)
# FreqItemset(items=[u'mvvm', u'wpf'], freq=12455)
# FreqItemset(items=[u'jpa'], freq=27264)
# FreqItemset(items=[u'jpa', u'java'], freq=16064)
# FreqItemset(items=[u'flask'], freq=13157)
# FreqItemset(items=[u'cakephp'], freq=26984)
# FreqItemset(items=[u'filter'], freq=13140)
# FreqItemset(items=[u'linq'], freq=58725)
# FreqItemset(items=[u'linq', u'c#'], freq=42661)
# FreqItemset(items=[u'design'], freq=18300)
# FreqItemset(items=[u'for-loop'], freq=26954)
# FreqItemset(items=[u'import'], freq=13069)
# FreqItemset(items=[u'postgresql'], freq=58181)
# FreqItemset(items=[u'postgresql', u'sql'], freq=15777)
# FreqItemset(items=[u'dynamic'], freq=18166)
# FreqItemset(items=[u'hibernate'], freq=57362)
# FreqItemset(items=[u'hibernate', u'java'], freq=34278)
# FreqItemset(items=[u'hibernate', u'spring'], freq=12650)
# FreqItemset(items=[u'input'], freq=18148)
# FreqItemset(items=[u'redirect'], freq=26911)
# FreqItemset(items=[u'hyperlink'], freq=13061)
# FreqItemset(items=[u'dictionary'], freq=26846)
# FreqItemset(items=[u'dictionary', u'python'], freq=14133)
# FreqItemset(items=[u'playframework'], freq=13037)
# FreqItemset(items=[u'css3'], freq=56189)
# FreqItemset(items=[u'css3', u'css'], freq=36085)
# FreqItemset(items=[u'css3', u'css', u'html'], freq=19802)
# FreqItemset(items=[u'css3', u'html'], freq=23717)
# FreqItemset(items=[u'css3', u'html5'], freq=13927)
# FreqItemset(items=[u'mysqli'], freq=18147)
# FreqItemset(items=[u'mysqli', u'php'], freq=16012)
# FreqItemset(items=[u'opengl'], freq=26677)
# FreqItemset(items=[u'fonts'], freq=13028)
# FreqItemset(items=[u'list'], freq=56091)
# FreqItemset(items=[u'list', u'python'], freq=20670)
# FreqItemset(items=[u'methods'], freq=18136)
# FreqItemset(items=[u'scala'], freq=55495)
# FreqItemset(items=[u'intellij-idea'], freq=18117)
# FreqItemset(items=[u'events'], freq=26638)
# FreqItemset(items=[u'uiviewcontroller'], freq=12995)
# FreqItemset(items=[u'exception'], freq=26485)
# FreqItemset(items=[u'jar'], freq=12983)
# FreqItemset(items=[u'ruby-on-rails-3'], freq=55075)
# FreqItemset(items=[u'ruby-on-rails-3', u'ruby'], freq=15091)
# FreqItemset(items=[u'ruby-on-rails-3', u'ruby-on-rails'], freq=33684)
# FreqItemset(items=[u'sql-server-2005'], freq=18048)
# FreqItemset(items=[u'laravel-5'], freq=12914)
# FreqItemset(items=[u'python-2.7'], freq=54902)
# FreqItemset(items=[u'python-2.7', u'python'], freq=36001)
# FreqItemset(items=[u'dll'], freq=18000)
# FreqItemset(items=[u'servlets'], freq=26366)
# FreqItemset(items=[u'servlets', u'java'], freq=17986)
# FreqItemset(items=[u'perl'], freq=52786)
# FreqItemset(items=[u'visual-studio-2013'], freq=17865)
# FreqItemset(items=[u'ssl'], freq=26235)
# FreqItemset(items=[u'error-handling'], freq=12835)
# FreqItemset(items=[u'mod-rewrite'], freq=26220)
# FreqItemset(items=[u'mod-rewrite', u'.htaccess'], freq=19606)
# FreqItemset(items=[u'mod-rewrite', u'apache'], freq=13884)
# FreqItemset(items=[u'orm'], freq=12816)
# FreqItemset(items=[u'qt'], freq=52576)
# FreqItemset(items=[u'qt', u'c++'], freq=26573)
# FreqItemset(items=[u'nhibernate'], freq=17816)
# FreqItemset(items=[u'table'], freq=25978)
# FreqItemset(items=[u'timer'], freq=12816)
# FreqItemset(items=[u'web-services'], freq=52478)
# FreqItemset(items=[u'go'], freq=17667)
# FreqItemset(items=[u'.htaccess'], freq=52116)
# FreqItemset(items=[u'.htaccess', u'apache'], freq=18371)
# FreqItemset(items=[u'.htaccess', u'php'], freq=18047)
# FreqItemset(items=[u'jenkins'], freq=17555)
# FreqItemset(items=[u'inheritance'], freq=25750)
# FreqItemset(items=[u'dependency-injection'], freq=12794)
# FreqItemset(items=[u'xslt'], freq=25646)
# FreqItemset(items=[u'xslt', u'xml'], freq=15060)
# FreqItemset(items=[u'concurrency'], freq=12771)
# FreqItemset(items=[u'excel-vba'], freq=50316)
# FreqItemset(items=[u'excel-vba', u'vba'], freq=32149)
# FreqItemset(items=[u'excel-vba', u'vba', u'excel'], freq=24745)
# FreqItemset(items=[u'excel-vba', u'excel'], freq=33711)
# FreqItemset(items=[u'plugins'], freq=17496)
# FreqItemset(items=[u'grails'], freq=25630)
# FreqItemset(items=[u'version-control'], freq=12657)
# FreqItemset(items=[u'function'], freq=50241)
# FreqItemset(items=[u'gradle'], freq=17453)
# FreqItemset(items=[u'sqlite'], freq=50107)
# FreqItemset(items=[u'sqlite', u'android'], freq=21084)
# FreqItemset(items=[u'selenium-webdriver'], freq=17427)
# FreqItemset(items=[u'express'], freq=25541)
# FreqItemset(items=[u'express', u'node.js'], freq=22423)
# FreqItemset(items=[u'doctrine2'], freq=12611)
# FreqItemset(items=[u'caching'], freq=25521)
# FreqItemset(items=[u'tkinter'], freq=12578)
# FreqItemset(items=[u'shell'], freq=48691)
# FreqItemset(items=[u'shell', u'bash'], freq=18393)
# FreqItemset(items=[u'shell', u'linux'], freq=13025)
# FreqItemset(items=[u'apache-spark'], freq=17385)
# FreqItemset(items=[u'cmd'], freq=12562)
# FreqItemset(items=[u'file'], freq=48055)
# FreqItemset(items=[u'indexing'], freq=17279)
# FreqItemset(items=[u'dom'], freq=25311)
# FreqItemset(items=[u'dom', u'javascript'], freq=15271)
# FreqItemset(items=[u'codeigniter'], freq=47427)
# FreqItemset(items=[u'codeigniter', u'php'], freq=34375)
# FreqItemset(items=[u'database-design'], freq=17258)
# FreqItemset(items=[u'java-ee'], freq=25188)
# FreqItemset(items=[u'java-ee', u'java'], freq=14320)
# FreqItemset(items=[u'oracle11g'], freq=12552)
# FreqItemset(items=[u'select'], freq=25073)
# FreqItemset(items=[u'colors'], freq=12533)
# FreqItemset(items=[u'sql-server-2008'], freq=47409)
# FreqItemset(items=[u'sql-server-2008', u'sql-server'], freq=20264)
# FreqItemset(items=[u'sql-server-2008', u'sql'], freq=22146)
# FreqItemset(items=[u'drupal'], freq=17257)
# FreqItemset(items=[u'iis'], freq=24954)
# FreqItemset(items=[u'combobox'], freq=12502)
# FreqItemset(items=[u'uitableview'], freq=47297)
# FreqItemset(items=[u'uitableview', u'objective-c'], freq=18139)
# FreqItemset(items=[u'uitableview', u'objective-c', u'ios'], freq=13213)
# FreqItemset(items=[u'uitableview', u'iphone'], freq=12732)
# FreqItemset(items=[u'uitableview', u'ios'], freq=32411)
# FreqItemset(items=[u'file-io'], freq=17161)
# FreqItemset(items=[u'rest'], freq=47122)
# FreqItemset(items=[u'data-structures'], freq=16984)
# FreqItemset(items=[u'testing'], freq=24789)
# FreqItemset(items=[u'parameters'], freq=12498)
# FreqItemset(items=[u'math'], freq=24735)
# FreqItemset(items=[u'jquery-plugins'], freq=12461)
# FreqItemset(items=[u'api'], freq=46974)
# FreqItemset(items=[u'reflection'], freq=16925)
# FreqItemset(items=[u'button'], freq=24724)
# FreqItemset(items=[u'constructor'], freq=12436)
# FreqItemset(items=[u'cordova'], freq=46920)
# FreqItemset(items=[u'cordova', u'android'], freq=16887)
# FreqItemset(items=[u'knockout.js'], freq=16718)
# FreqItemset(items=[u'visual-studio-2010'], freq=46342)
# FreqItemset(items=[u'visual-studio-2010', u'c#'], freq=13405)
# FreqItemset(items=[u'pdo'], freq=16674)
# FreqItemset(items=[u'pdo', u'php'], freq=15366)
# FreqItemset(items=[u'search'], freq=24707)
# FreqItemset(items=[u'binding'], freq=12393)
# FreqItemset(items=[u'curl'], freq=24626)
# FreqItemset(items=[u'curl', u'php'], freq=15184)
# FreqItemset(items=[u'clojure'], freq=12391)
# FreqItemset(items=[u'google-maps'], freq=45954)
# FreqItemset(items=[u'google-maps', u'android'], freq=12880)
# FreqItemset(items=[u'google-maps', u'javascript'], freq=14557)
# FreqItemset(items=[u'web-applications'], freq=16554)
# FreqItemset(items=[u'wcf'], freq=45820)
# FreqItemset(items=[u'wcf', u'c#'], freq=19363)
# FreqItemset(items=[u'angular2'], freq=16286)
# FreqItemset(items=[u'post'], freq=24591)
# FreqItemset(items=[u'maven'], freq=45566)
# FreqItemset(items=[u'maven', u'java'], freq=22391)
# FreqItemset(items=[u'reporting-services'], freq=16272)
# FreqItemset(items=[u'flex'], freq=24445)
# FreqItemset(items=[u'gcc'], freq=23787)
# FreqItemset(items=[u'laravel'], freq=44776)
# FreqItemset(items=[u'laravel', u'php'], freq=28836)
# FreqItemset(items=[u'unicode'], freq=16220)
# FreqItemset(items=[u'join'], freq=23763)
# FreqItemset(items=[u'validation'], freq=44599)
# FreqItemset(items=[u'javafx'], freq=16168)
# FreqItemset(items=[u'class'], freq=44190)
# FreqItemset(items=[u'plot'], freq=16137)
# FreqItemset(items=[u'svn'], freq=23739)
# FreqItemset(items=[u'audio'], freq=23609)
# FreqItemset(items=[u'unit-testing'], freq=43601)
# FreqItemset(items=[u'data-binding'], freq=16103)
# FreqItemset(items=[u'c#-4.0'], freq=23348)
# FreqItemset(items=[u'sockets'], freq=43030)
# FreqItemset(items=[u'time'], freq=15960)
# FreqItemset(items=[u'symfony2'], freq=42260)
# FreqItemset(items=[u'symfony2', u'php'], freq=19824)
# FreqItemset(items=[u'hash'], freq=15909)
# FreqItemset(items=[u'asynchronous'], freq=23331)
# FreqItemset(items=[u'stored-procedures'], freq=23328)
# FreqItemset(items=[u'google-chrome'], freq=41937)
# FreqItemset(items=[u'google-chrome', u'javascript'], freq=15903)
# FreqItemset(items=[u'awk'], freq=15877)
# FreqItemset(items=[u'jsp'], freq=41804)
# FreqItemset(items=[u'jsp', u'java'], freq=21561)
# FreqItemset(items=[u'xamarin'], freq=15860)
# FreqItemset(items=[u'meteor'], freq=23101)
# FreqItemset(items=[u'xaml'], freq=41054)
# FreqItemset(items=[u'xaml', u'wpf'], freq=24112)
# FreqItemset(items=[u'xaml', u'wpf', u'c#'], freq=14390)
# FreqItemset(items=[u'xaml', u'c#'], freq=24295)
# FreqItemset(items=[u'service'], freq=15699)
# FreqItemset(items=[u'android-intent'], freq=23044)
# FreqItemset(items=[u'android-intent', u'android'], freq=22393)
# FreqItemset(items=[u'video'], freq=22976)
# FreqItemset(items=[u'python-3.x'], freq=40447)
# FreqItemset(items=[u'python-3.x', u'python'], freq=27839)
# FreqItemset(items=[u'drop-down-menu'], freq=15597)

# %%
def get_keyWords(line):
    line = xmltodict.parse(line)
    keyWords = line["row"]["@Title"].replace("?", ",").replace(".", "")
    keyWords = keyWords.split(" ")
    return map(lambda x: (x, 1), keyWords)

def count_keyWords(community="stats.stackexchange.com"):
    wtf = sc.textFile("E:\\stackexchange_Extracted\\" + community + "\\Posts.xml")
    tag_count = wtf.filter(lambda x: 'PostTypeId="1"' in x).flatMap(get_keyWords).reduceByKey(lambda a, b: a + b).sortBy(lambda (word, count): count)
    return tag_count.collect()

results = count_keyWords()

# %%
def get_tags(line):
    line = xmltodict.parse(line)
    tags = line["row"]["@Tags"].replace("><", ",").replace("<", "").replace(">", "")
    tags = tags.split(",")
    return map(lambda x: (x, 1), tags)

def count_tags(community="stats.stackexchange.com"):
    wtf = sc.textFile("E:\\stackexchange_Extracted\\" + community + "\\Posts.xml")
    tag_count = wtf.filter(lambda x: 'PostTypeId="1"' in x).flatMap(get_tags).reduceByKey(lambda a, b: a + b).sortBy(lambda (word, count): count)
    return tag_count.collect()

r = count_tags()

# %%
r[::-1]
# Out:
# [(u'r', 13977),
#  (u'regression', 11269),
#  (u'machine-learning', 6098),
#  (u'time-series', 5545),
#  (u'probability', 4303),
#  (u'hypothesis-testing', 3907),
#  (u'self-study', 3812),
#  (u'distributions', 3566),
#  (u'logistic', 3385),
#  (u'correlation', 2963),
#  (u'classification', 2879),
#  (u'statistical-significance', 2722),
#  (u'bayesian', 2663),
#  (u'anova', 2524),
#  (u'normal-distribution', 2253),
#  (u'multiple-regression', 2095),
#  (u'clustering', 2004),
#  (u'mathematical-statistics', 1956),
#  (u'mixed-model', 1955),
#  (u'neural-networks', 1829),
#  (u'confidence-interval', 1815),
#  (u'categorical-data', 1717),
#  (u'generalized-linear-model', 1633),
#  (u'data-visualization', 1608),
#  (u'variance', 1592),
#  (u'estimation', 1537),
#  (u'pca', 1495),
#  (u'forecasting', 1449),
#  (u't-test', 1434),
#  (u'sampling', 1407),
#  (u'spss', 1354),
#  (u'cross-validation', 1325),
#  (u'repeated-measures', 1311),
#  (u'svm', 1302),
#  (u'chi-squared', 1264),
#  (u'maximum-likelihood', 1215),
#  (u'predictive-models', 1206),
#  (u'multivariate-analysis', 1128),
#  (u'references', 1093),
#  (u'data-transformation', 1089),
#  (u'p-value', 1086),
#  (u'survival', 1072),
#  (u'modeling', 1059),
#  (u'data-mining', 1013),
#  (u'matlab', 1000),
#  (u'feature-selection', 1000),
#  (u'econometrics', 997),
#  (u'python', 995),
#  (u'interaction', 979),
#  (u'panel-data', 970),
#  (u'linear-model', 949),
#  (u'arima', 938),
#  (u'random-forest', 937),
#  (u'binomial', 931),
#  (u'nonparametric', 929),
#  (u'dataset', 921),
#  (u'standard-deviation', 918),
#  (u'optimization', 901),
#  (u'least-squares', 901),
#  (u'interpretation', 888),
#  (u'stata', 876),
#  (u'poisson', 868),
#  (u'model-selection', 862),
#  (u'mean', 860),
#  (u'sample-size', 854),
#  (u'prediction', 842),
#  (u'conditional-probability', 828),
#  (u'multiple-comparisons', 826),
#  (u'bootstrap', 816),
#  (u'experiment-design', 771),
#  (u'random-variable', 749),
#  (u'pdf', 689),
#  (u'autocorrelation', 683),
#  (u'simulation', 683),
#  (u'regression-coefficients', 666),
#  (u'covariance', 665),
#  (u'factor-analysis', 665),
#  (u'multilevel-analysis', 662),
#  (u'missing-data', 653),
#  (u'expected-value', 647),
#  (u'mcmc', 646),
#  (u'standard-error', 638),
#  (u'outliers', 629),
#  (u'ordinal', 629),
#  (u'inference', 627),
#  (u'survey', 621),
#  (u'cart', 595),
#  (u'model', 581),
#  (u'residuals', 578),
#  (u'goodness-of-fit', 575),
#  (u'binary-data', 574),
#  (u'random-effects-model', 564),
#  (u'deep-learning', 549),
#  (u'terminology', 543),
#  (u'stochastic-processes', 526),
#  (u'sas', 521),
#  (u'nonlinear-regression', 520),
#  (u'algorithms', 514),
#  (u'cox-model', 511),
#  (u'normalization', 511),
#  (u'proportion', 500),
#  (u'monte-carlo', 499),
#  (u'lmer', 494),
#  (u'multinomial', 490),
#  (u'lasso', 487),
#  (u'error', 485),
#  (u'heteroscedasticity', 480),
#  (u'k-means', 478),
#  (u'independence', 478),
#  (u'meta-analysis', 463),
#  (u'multicollinearity', 450),
#  (u'descriptive-statistics', 446),
#  (u'text-mining', 440),
#  (u'sample', 436),
#  (u'spatial', 431),
#  (u'markov-process', 429),
#  (u'matrix', 428),
#  (u'aic', 428),
#  (u'scikit-learn', 428),
#  (u'assumptions', 418),
#  (u'dimensionality-reduction', 413),
#  (u'sem', 404),
#  (u'bias', 400),
#  (u'likelihood', 400),
#  (u'lme4', 400),
#  (u'fixed-effects-model', 388),
#  (u'normality', 388),
#  (u'logit', 385),
#  (u'r-squared', 380),
#  (u'likert', 375),
#  (u'roc', 370),
#  (u'effect-size', 366),
#  (u'random-generation', 362),
#  (u'convergence', 361),
#  (u'power-analysis', 360),
#  (u'fitting', 358),
#  (u'computational-statistics', 357),
#  (u'summary-statistics', 357),
#  (u'glmm', 352),
#  (u'negative-binomial', 349),
#  (u'ranking', 341),
#  (u'covariance-matrix', 338),
#  (u'count-data', 338),
#  (u'stationarity', 337),
#  (u'prior', 336),
#  (u'natural-language', 334),
#  (u'kernel-trick', 329),
#  (u'continuous-data', 324),
#  (u'gamma-distribution', 321),
#  (u'skewness', 317),
#  (u'naive-bayes', 315),
#  (u'reliability', 312),
#  (u'hidden-markov-model', 312),
#  (u'regularization', 310),
#  (u'biostatistics', 310),
#  (u'causality', 308),
#  (u'gaussian-process', 307),
#  (u'distance', 306),
#  (u'power', 306),
#  (u'standardization', 306),
#  (u'group-differences', 304),
#  (u'ancova', 304),
#  (u'autoregressive', 304),
#  (u'garch', 301),
#  (u'small-sample', 297),
#  (u'excel', 294),
#  (u'validation', 294),
#  (u'bayes', 292),
#  (u'exponential', 292),
#  (u'kernel-smoothing', 290),
#  (u'quantiles', 290),
#  (u'posterior', 289),
#  (u'post-hoc', 287),
#  (u'curve-fitting', 286),
#  (u'large-data', 283),
#  (u'robust', 282),
#  (u'var', 281),
#  (u'uniform', 280),
#  (u'odds-ratio', 276),
#  (u'average', 276),
#  (u'seasonality', 276),
#  (u'lognormal', 272),
#  (u'kolmogorov-smirnov', 272),
#  (u'discrete-data', 271),
#  (u'median', 271),
#  (u'expectation-maximization', 270),
#  (u'wilcoxon', 270),
#  (u'histogram', 267),
#  (u'gradient-descent', 267),
#  (u'pearson', 266),
#  (u'cointegration', 264),
#  (u'cdf', 261),
#  (u'entropy', 260),
#  (u'non-independent', 258),
#  (u'contingency-tables', 257),
#  (u'joint-distribution', 257),
#  (u'linear', 257),
#  (u'trend', 256),
#  (u'arma', 256),
#  (u'pattern-recognition', 255),
#  (u'scales', 253),
#  (u'mann-whitney-u-test', 248),
#  (u'unbiased-estimator', 247),
#  (u'manova', 247),
#  (u'gaussian-mixture', 245),
#  (u'data-imputation', 243),
#  (u'central-limit-theorem', 243),
#  (u'caret', 243),
#  (u'boosting', 242),
#  (u'permutation', 241),
#  (u'measurement-error', 241),
#  (u'conditional-expectation', 241),
#  (u'discriminant-analysis', 239),
#  (u'ridge-regression', 238),
#  (u'hierarchical-bayesian', 237),
#  (u'unsupervised-learning', 236),
#  (u'image-processing', 236),
#  (u'unbalanced-classes', 235),
#  (u'mixture', 235),
#  (u'graphical-model', 235),
#  (u'basic-concepts', 235),
#  (u'population', 234),
#  (u'poisson-regression', 233),
#  (u'conv-neural-network', 233),
#  (u'k-nearest-neighbour', 231),
#  (u'likelihood-ratio', 231),
#  (u'paired-comparisons', 229),
#  (u'psychometrics', 228),
#  (u'distance-functions', 226),
#  (u'probit', 225),
#  (u'instrumental-variables', 224),
#  (u'multiple-imputation', 224),
#  (u'asymptotics', 224),
#  (u'similarities', 220),
#  (u'predictor', 217),
#  (u'accuracy', 216),
#  (u'overfitting', 213),
#  (u'degrees-of-freedom', 213),
#  (u'gibbs', 212),
#  (u'jags', 212),
#  (u'information-theory', 209),
#  (u'finance', 207),
#  (u'recommender-system', 207),
#  (u'beta-distribution', 205),
#  (u'estimators', 204),
#  (u'notation', 204),
#  (u'glmnet', 203),
#  (u'proof', 202),
#  (u'epidemiology', 202),
#  (u'svd', 200),
#  (u'moments', 199),
#  (u'gam', 197),
#  (u'linear-algebra', 196),
#  (u'model-comparison', 195),
#  (u'feature-construction', 195),
#  (u'lme', 194),
#  (u'nonlinear', 192),
#  (u'bayesian-network', 192),
#  (u'smoothing', 190),
#  (u'libsvm', 189),
#  (u'cross-correlation', 188),
#  (u'logarithm', 187),
#  (u'prediction-interval', 187),
#  (u'approximation', 185),
#  (u'nested', 184),
#  (u'gee', 183),
#  (u'kalman-filter', 182),
#  (u'supervised-learning', 179),
#  (u't-distribution', 179),
#  (u'fishers-exact', 179),
#  (u'precision-recall', 179),
#  (u'frequency', 177),
#  (u'unit-root', 176),
#  (u'measurement', 175),
#  (u'contrasts', 173),
#  (u'latent-variable', 173),
#  (u'loss-functions', 173),
#  (u'zero-inflation', 173),
#  (u'bernoulli-distribution', 173),
#  (u'censoring', 171),
#  (u'splines', 171),
#  (u'resampling', 171),
#  (u'software', 170),
#  (u'intuition', 169),
#  (u'weka', 169),
#  (u'kruskal-wallis', 168),
#  (u'auc', 167),
#  (u'glmer', 167),
#  (u'regression-strategies', 166),
#  (u'graph-theory', 165),
#  (u'f-test', 165),
#  (u'order-statistics', 164),
#  (u'hazard', 163),
#  (u'mediation', 161),
#  (u'lm', 161),
#  (u'uncertainty', 160),
#  (u'parametric', 159),
#  (u'polynomial', 159),
#  (u'confirmatory-factor', 158),
#  (u'signal-processing', 157),
#  (u'marginal', 156),
#  (u'frequentist', 156),
#  (u'ensemble', 156),
#  (u'definition', 155),
#  (u'copula', 152),
#  (u'weighted-regression', 152),
#  (u'performance', 152),
#  (u'multi-class', 151),
#  (u'bonferroni', 147),
#  (u'mutual-information', 147),
#  (u'matching', 145),
#  (u'genetics', 143),
#  (u'eigenvalues', 143),
#  (u'dirichlet-distribution', 143),
#  (u'non-stationary', 142),
#  (u'propensity-scores', 142),
#  (u'methodology', 141),
#  (u'reinforcement-learning', 141),
#  (u'analysis', 140),
#  (u'theory', 140),
#  (u'scatterplot', 140),
#  (u'hierarchical-clustering', 139),
#  (u'pymc', 139),
#  (u'diagnostic', 139),
#  (u'stepwise-regression', 139),
#  (u'metropolis-hastings', 139),
#  (u'difference-in-difference', 138),
#  (u'inter-rater', 138),
#  (u'combinatorics', 136),
#  (u'gbm', 134),
#  (u'ggplot2', 134),
#  (u'intraclass-correlation', 132),
#  (u'aggregation', 132),
#  (u'multivariate-regression', 131),
#  (u'interpolation', 131),
#  (u'paired-data', 130),
#  (u'topic-models', 130),
#  (u'kullback-leibler', 130),
#  (u'hierarchical', 130),
#  (u'bic', 130),
#  (u'parameterization', 129),
#  (u'quantile-regression', 129),
#  (u'reporting', 129),
#  (u'error-propagation', 129),
#  (u'weibull', 128),
#  (u'multidimensional-scaling', 128),
#  (u'qq-plot', 128),
#  (u'metric', 127),
#  (u'mse', 126),
#  (u'bioinformatics', 125),
#  (u'bivariate', 125),
#  (u'train', 124),
#  (u'decision-theory', 123),
#  (u'multivariate-normal', 122),
#  (u'change-point', 122),
#  (u'spearman', 121),
#  (u'matrix-decomposition', 121),
#  (u'statistical-learning', 121),
#  (u'weighted-mean', 120),
#  (u'sparse', 120),
#  (u'eda', 119),
#  (u'endogeneity', 119),
#  (u'lags', 119),
#  (u'nlme', 119),
#  (u'kurtosis', 118),
#  (u'irt', 117),
#  (u'boxplot', 117),
#  (u'poisson-process', 117),
#  (u'exponential-smoothing', 117),
#  (u'ratio', 116),
#  (u'z-test', 116),
#  (u'probability-inequalities', 115),
#  (u'percentage', 115),
#  (u'networks', 115),
#  (u'markov-chain', 115),
#  (u'confidence', 114),
#  (u'bugs', 114),
#  (u'exponential-family', 113),
#  (u'ecology', 112),
#  (u'randomization', 112),
#  (u'covariate', 112),
#  (u'state-space-models', 112),
#  (u'sums-of-squares', 111),
#  (u'confounding', 111),
#  (u'learning', 110),
#  (u'teaching', 110),
#  (u'convolution', 110),
#  (u'pls', 110),
#  (u'coefficient', 108),
#  (u'ab-test', 107),
#  (u'false-discovery-rate', 107),
#  (u'extreme-value', 106),
#  (u'treatment-effect', 106),
#  (u'generalized-least-squares', 105),
#  (u'consistency', 105),
#  (u'sufficient-statistics', 105),
#  (u'conjugate-prior', 104),
#  (u'autoencoders', 104),
#  (u'clinical-trials', 103),
#  (u'backpropagation', 103),
#  (u'stratification', 102),
#  (u'randomness', 102),
#  (u'hyperparameter', 101),
#  (u'online', 101),
#  (u'moving-average', 100),
#  (u'mathematics', 99),
#  (u'games', 98),
#  (u'weighted-sampling', 98),
#  (u'computer-vision', 97),
#  (u'high-dimensional', 97),
#  (u'scores', 96),
#  (u'rms', 95),
#  (u'elastic-net', 95),
#  (u'granger-causality', 95),
#  (u'tukey-hsd', 94),
#  (u'nominal', 94),
#  (u'bounds', 94),
#  (u'threshold', 94),
#  (u'kaplan-meier', 94),
#  (u'sample-mean', 94),
#  (u'rpart', 94),
#  (u'spearman-rho', 93),
#  (u'intercept', 93),
#  (u'time-varying-covariate', 93),
#  (u'pooling', 93),
#  (u'fourier-transform', 92),
#  (u'scipy', 92),
#  (u'augmented-dickey-fuller', 92),
#  (u'type-i-errors', 92),
#  (u'deviance', 92),
#  (u'hypergeometric', 92),
#  (u'maximum', 92),
#  (u'vecm', 91),
#  (u'integral', 91),
#  (u'power-law', 90),
#  (u'fisher-information', 90),
#  (u'overdispersion', 89),
#  (u'binning', 89),
#  (u'interval', 88),
#  (u'function', 88),
#  (u'residual-analysis', 87),
#  (u'cross-section', 87),
#  (u'rank-correlation', 87),
#  (u'log-linear', 85),
#  (u'weighted-data', 85),
#  (u'partial-correlation', 85),
#  (u'genetic-algorithms', 85),
#  (u'information-retrieval', 85),
#  (u'psychology', 84),
#  (u'java', 82),
#  (u'calibration', 82),
#  (u'model-evaluation', 82),
#  (u'quality-control', 81),
#  (u'lstm', 81),
#  (u'winbugs', 81),
#  (u'truncation', 81),
#  (u'generalized-moments', 80),
#  (u'data-preprocessing', 79),
#  (u'z-score', 79),
#  (u'risk', 78),
#  (u'importance', 78),
#  (u'centering', 78),
#  (u'dice', 78),
#  (u'kappa', 78),
#  (u'point-estimation', 78),
#  (u'rare-events', 77),
#  (u'deep-belief-networks', 77),
#  (u'link-function', 76),
#  (u'partitioning', 76),
#  (u'social-network', 76),
#  (u'bagging', 76),
#  (u'artificial-intelligence', 76),
#  (u'empirical', 76),
#  (u'point-process', 75),
#  (u'odds', 75),
#  (u'quadratic-form', 75),
#  (u'spectral-analysis', 74),
#  (u'matrix-inverse', 74),
#  (u'maximum-entropy', 74),
#  (u'history', 74),
#  (u'sequence-analysis', 74),
#  (u'control', 73),
#  (u'case-control-study', 73),
#  (u'clustered-standard-errors', 73),
#  (u'validity', 73),
#  (u'dirichlet-process', 73),
#  (u'sensitivity', 73),
#  (u'association-measure', 72),
#  (u'rbm', 71),
#  (u'confusion-matrix', 71),
#  (u'cohens-d', 71),
#  (u'observational-study', 71),
#  (u'association-rules', 70),
#  (u'kendall-tau', 70),
#  (u'filter', 70),
#  (u'pareto-distribution', 70),
#  (u'shrinkage', 70),
#  (u'method-comparison', 70),
#  (u'out-of-sample', 69),
#  (u'sequential-analysis', 69),
#  (u'random-walk', 69),
#  (u'fisher', 67),
#  (u'mcnemar-test', 67),
#  (u'parameter-optimization', 67),
#  (u'segmentation', 67),
#  (u'volatility-forecasting', 67),
#  (u'rnn', 67),
#  (u'2sls', 67),
#  (u'scoring', 66),
#  (u'loess', 66),
#  (u'ranks', 66),
#  (u'meta-regression', 66),
#  (u'circular-statistics', 65),
#  (u'euclidean', 65),
#  (u'dynamic-regression', 65),
#  (u'tobit-regression', 65),
#  (u'cluster-sample', 65),
#  (u'delta-method', 65),
#  (u'inferential-statistics', 64),
#  (u'mode', 64),
#  (u'method-of-moments', 64),
#  (u'mice', 64),
#  (u'iid', 64),
#  (u'beta-binomial', 63),
#  (u'stan', 63),
#  (u'intervention-analysis', 63),
#  (u'minimum', 63),
#  (u'rating', 62),
#  (u'equivalence', 62),
#  (u'correspondence-analysis', 62),
#  (u'relative-risk', 62),
#  (u'moderation', 62),
#  (u'numerical-integration', 61),
#  (u'marketing', 61),
#  (u'mgcv', 60),
#  (u'vif', 60),
#  (u'coefficient-of-variation', 60),
#  (u'ordered-logit', 60),
#  (u'programming', 59),
#  (u'noise', 59),
#  (u'hausman', 59),
#  (u'traminer', 58),
#  (u'identifiability', 57),
#  (u'combination', 56),
#  (u'subset', 56),
#  (u'education', 56),
#  (u'beta-regression', 56),
#  (u'latent-class', 56),
#  (u'geostatistics', 56),
#  (u'philosophical', 56),
#  (u'white-noise', 56),
#  (u'canonical-correlation', 56),
#  (u'efficiency', 56),
#  (u'statistical', 55),
#  (u'variational-bayes', 55),
#  (u'offset', 55),
#  (u'signal-detection', 55),
#  (u'nls', 54),
#  (u'adjustment', 54),
#  (u'growth-model', 53),
#  (u'anomaly-detection', 53),
#  (u'lsa', 52),
#  (u'levenes-test', 52),
#  (u'multilabel', 52),
#  (u'amos', 52),
#  (u'credible-interval', 52),
#  (u'cronbachs-alpha', 52),
#  (u'spatio-temporal', 52),
#  (u'queueing', 52),
#  (u'structural-change', 51),
#  (u'self-organizing-maps', 51),
#  (u'minitab', 51),
#  (u'derivative', 51),
#  (u'variability', 51),
#  (u'penalized', 51),
#  (u'lsmeans', 50),
#  (u'gradient', 50),
#  (u'finite-population', 50),
#  (u'importance-sampling', 50),
#  (u'nonparametric-bayes', 49),
#  (u'mgf', 49),
#  (u'variogram', 49),
#  (u'wishart', 49),
#  (u'application', 48),
#  (u'particle-filter', 48),
#  (u'careers', 48),
#  (u'arithmetic', 48),
#  (u'combining-p-values', 48),
#  (u'split-plot', 48),
#  (u'numerics', 48),
#  (u'composite', 48),
#  (u'eviews', 47),
#  (u'c++', 47),
#  (u'univariate', 47),
#  (u'code', 47),
#  (u'sensitivity-analysis', 47),
#  (u'multivariable', 47),
#  (u'macroeconomics', 47),
#  (u'geometric-distribution', 47),
#  (u'statsmodels', 46),
#  (u'perceptron', 46),
#  (u'specificity', 46),
#  (u'geometry', 46),
#  (u'fuzzy', 46),
#  (u'path-model', 46),
#  (u'robust-standard-error', 45),
#  (u'type-ii-errors', 45),
#  (u'barplot', 45),
#  (u'tensorflow', 45),
#  (u'agreement-statistics', 45),
#  (u'word2vec', 45),
#  (u'weights', 44),
#  (u'constrained-regression', 44),
#  (u'microarray', 44),
#  (u'arch', 44),
#  (u'density-estimation', 43),
#  (u'jmp', 43),
#  (u'conjoint-analysis', 43),
#  (u'blocking', 43),
#  (u'log-likelihood', 43),
#  (u'imbalanced', 43),
#  (u'tables', 43),
#  (u'model-based-clustering', 43),
#  (u'data-cleaning', 43),
#  (u'gini', 42),
#  (u'z-statistic', 42),
#  (u'replication', 42),
#  (u'clogit', 42),
#  (u'summations', 42),
#  (u'rejection-sampling', 42),
#  (u'multiarmed-bandit', 41),
#  (u'change-scores', 41),
#  (u'back-transformation', 41),
#  (u'package', 41),
#  (u'communication', 40),
#  (u'demography', 40),
#  (u'reproducible-research', 40),
#  (u'f-distribution', 40),
#  (u'measure-theory', 40),
#  (u'mlogit', 40),
#  (u'impulse-response', 39),
#  (u'plm', 39),
#  (u'semi-supervised', 39),
#  (u'mixed-design', 39),
#  (u'hauck-donner-effect', 39),
#  (u'functional-data-analysis', 39),
#  (u'brownian', 39),
#  (u'dlm', 38),
#  (u'formula', 38),
#  (u'conditioning', 38),
#  (u'umvue', 38),
#  (u'logrank', 38),
#  (u'lavaan', 38),
#  (u'curves', 38),
#  (u'word-embeddings', 37),
#  (u'mathematica', 37),
#  (u'bias-correction', 37),
#  (u'friedman-test', 37),
#  (u'fat-tails', 36),
#  (u'ica', 36),
#  (u'fractional-factorial', 36),
#  (u'biplot', 35),
#  (u'rotation', 35),
#  (u'uninformative-prior', 35),
#  (u'cauchy', 35),
#  (u'marginal-effect', 35),
#  (u'multiple-seasonalities', 35),
#  (u'dataframe', 35),
#  (u'two-way', 35),
#  (u'census', 34),
#  (u'lars', 34),
#  (u'numpy', 34),
#  (u'wavelet', 34),
#  (u'projection', 34),
#  (u'valuation', 34),
#  (u'sentiment-analysis', 34),
#  (u'law-of-large-numbers', 34),
#  (u'error-message', 34),
#  (u'signed-rank-test', 34),
#  (u'web', 33),
#  (u'mplus', 33),
#  (u'generative-models', 33),
#  (u'dendrogram', 33),
#  (u'kriging', 32),
#  (u'anderson-darling', 32),
#  (u'best-practices', 32),
#  (u'survey-weights', 32),
#  (u'cholesky', 32),
#  (u'interval-censoring', 32),
#  (u'igraph', 32),
#  (u'f-statistic', 31),
#  (u'piecewise-linear', 31),
#  (u'inverse-gamma', 31),
#  (u'heterogeneity', 31),
#  (u'computing', 31),
#  (u'business-intelligence', 30),
#  (u'softmax', 30),
#  (u'real-time', 30),
#  (u'dispersion', 30),
#  (u'discontinuity', 30),
#  (u'factor-rotation', 30),
#  (u'random-matrix', 30),
#  (u'parallel-computing', 30),
#  (u'rule-of-thumb', 30),
#  (u'spark-mllib', 30),
#  (u'incidence-rate-ratio', 30),
#  (u'chemometrics', 29),
#  (u'conditional-random-field', 29),
#  (u'adaboost', 29),
#  (u'cosine-similarity', 29),
#  (u'radial-basis', 29),
#  (u'bayes-factors', 29),
#  (u'optimal-scaling', 29),
#  (u'crossover-study', 29),
#  (u'statistical-control', 28),
#  (u'e1071', 28),
#  (u'social-science', 28),
#  (u'quasi-likelihood', 28),
#  (u'effects', 28),
#  (u'jaccard-similarity', 28),
#  (u'oversampling', 28),
#  (u'laplace-distribution', 28),
#  (u'neyman-pearson-lemma', 28),
#  (u'sql', 28),
#  (u'moving-window', 28),
#  (u'frailty', 28),
#  (u'constraint', 27),
#  (u'errors-in-variables', 27),
#  (u'vc-dimension', 27),
#  (u'big-data', 27),
#  (u'churn', 27),
#  (u'test-for-trend', 27),
#  (u'ecdf', 27),
#  (u'k-medoids', 27),
#  (u'model-averaging', 27),
#  (u'range', 27),
#  (u'heckman', 27),
#  (u'theano', 26),
#  (u'tolerance-interval', 26),
#  (u'discriminant', 26),
#  (u'convex', 26),
#  (u'database', 26),
#  (u'nnet', 26),
#  (u'information', 26),
#  (u'tbats', 26),
#  (u'apriori', 26),
#  (u'sphericity', 26),
#  (u'rapidminer', 26),
#  (u'mad', 26),
#  (u'transition-matrix', 25),
#  (u'stacking', 25),
#  (u'total-least-squares', 25),
#  (u'segmented-regression', 25),
#  (u'non-response', 25),
#  (u'heavy-tailed', 25),
#  (u'profile-likelihood', 25),
#  (u'control-chart', 25),
#  (u'scale-invariance', 25),
#  (u'representative', 24),
#  (u'non-central', 24),
#  (u'concordance', 24),
#  (u'probabilistic-programming', 24),
#  (u'leverage', 24),
#  (u'kde', 24),
#  (u'interactive-visualization', 24),
#  (u'chow-test', 24),
#  (u'jeffreys-prior', 24),
#  (u'precision', 24),
#  (u'correlated-predictors', 24),
#  (u'presentation', 23),
#  (u'poisson-binomial', 23),
#  (u'repeatability', 23),
#  (u'determinant', 23),
#  (u'interaction-variable', 23),
#  (u'indicator-variables', 23),
#  (u'trimmed-mean', 23),
#  (u'qualitative', 23),
#  (u'c#', 23),
#  (u'ecm', 23),
#  (u'dunn-test', 22),
#  (u'cosine-distance', 22),
#  (u'integration', 22),
#  (u'deming-regression', 22),
#  (u'age', 22),
#  (u'coding', 22),
#  (u'subsampling', 22),
#  (u'units', 22),
#  (u'standard', 22),
#  (u'gumbel', 22),
#  (u'paradox', 22),
#  (u'funnel-plot', 22),
#  (u'partial', 22),
#  (u'choice', 21),
#  (u'pandas', 21),
#  (u'jackknife', 21),
#  (u'average-precision', 21),
#  (u'correlation-matrix', 21),
#  (u'truncated-normal', 21),
#  (u'compositional-data', 21),
#  (u'dropout', 21),
#  (u'survey-sampling', 21),
#  (u'simpsons-paradox', 21),
#  (u'polling', 21),
#  (u'martingale', 21),
#  (u'capture-mark-recapture', 21),
#  (u'synthetic-data', 21),
#  (u'matplotlib', 21),
#  (u'skew-normal', 21),
#  (u'neweywest', 21),
#  (u'singular', 20),
#  (u'hessian', 20),
#  (u'geometric-mean', 20),
#  (u'neuroscience', 20),
#  (u'failure', 20),
#  (u'neuroimaging', 20),
#  (u'characteristic-function', 20),
#  (u'coverage-probability', 20),
#  (u'taylor-series', 20),
#  (u'two-step-estimation', 20),
#  (u'mancova', 20),
#  (u'zero-inflated', 20),
#  (u'cost-maximization', 20),
#  (u'proportional-hazards', 20),
#  (u'abc', 20),
#  (u'open-bugs', 20),
#  (u'optimal-stopping', 20),
#  (u'operations-research', 19),
#  (u'nonparametric-regression', 19),
#  (u'familywise-error', 19),
#  (u'box-jenkins', 19),
#  (u'time-complexity', 19),
#  (u'ergodic', 19),
#  (u'events', 19),
#  (u'variance-decomposition', 19),
#  (u'bimodal', 19),
#  (u'academia', 19),
#  (u'fraud', 19),
#  (u'heatmap', 19),
#  (u'sequential-pattern-mining', 19),
#  (u'directional-statistics', 19),
#  (u'publication-bias', 19),
#  (u'reml', 18),
#  (u'hotelling', 18),
#  (u'zipf', 18),
#  (u'compression', 18),
#  (u'decomposition', 18),
#  (u'elasticity', 18),
#  (u'updating', 18),
#  (u'untagged', 18),
#  (u'multivariate-distribution', 18),
#  (u'cfa', 18),
#  (u'causalimpact', 18),
#  (u'phylogeny', 18),
#  (u'mape', 18),
#  (u'tost', 17),
#  (u'non-nested', 17),
#  (u'pivot', 17),
#  (u'cross-entropy', 17),
#  (u'steins-phenomenon', 17),
#  (u'nnmf', 17),
#  (u'planned-comparisons-test', 17),
#  (u'interarrival-time', 17),
#  (u'coupon-collector-problem', 17),
#  (u'overlapping-data', 17),
#  (u'recurrent-events', 17),
#  (u'differences', 17),
#  (u'dependence', 17),
#  (u'language-models', 17),
#  (u'bernoulli-process', 17),
#  (u'exact-test', 17),
#  (u'data-association', 16),
#  (u'cramers-v', 16),
#  (u'symmetry', 16),
#  (u'underdispersion', 16),
#  (u'tsne', 16),
#  (u'library', 16),
#  (u'differential-equations', 16),
#  (u'lrt', 16),
#  (u'sign-test', 16),
#  (u'competing-risks', 16),
#  (u'index-decomposition', 16),
#  (u'scoring-rules', 16),
#  (u'open-source', 15),
#  (u'benchmark', 15),
#  (u'rasch', 15),
#  (u'gamm4', 15),
#  (u'mortality', 15),
#  (u'recursive-model', 15),
#  (u'dbscan', 15),
#  (u'linearity', 15),
#  (u'pie-chart', 15),
#  (u'sandwich', 15),
#  (u'finite-mixture-model', 15),
#  (u'heuristic', 15),
#  (u'gis', 15),
#  (u'climate', 15),
#  (u'project-management', 15),
#  (u'rayleigh', 15),
#  (u'population-average', 15),
#  (u'collaborative', 15),
#  (u'fuzzy-set', 14),
#  (u'fractal', 14),
#  (u'breusch-pagan', 14),
#  (u'quasi-binomial', 14),
#  (u'homogeneity', 14),
#  (u'extrapolation', 14),
#  (u'one-class', 14),
#  (u'manifold-learning', 14),
#  (u'vowpal-wabbit', 14),
#  (u'elections', 14),
#  (u'order', 14),
#  (u'pcoa', 14),
#  (u'data-generating-process', 14),
#  (u'suppressor', 14),
#  (u'fisher-transform', 14),
#  (u'interquartile', 14),
#  (u'latex', 14),
#  (u'stochastic-approximation', 14),
#  (u'sgd', 14),
#  (u'discussion', 14),
#  (u'xgboost', 14),
#  (u'inequality', 14),
#  (u'statistical-bias', 13),
#  (u'dag', 13),
#  (u'labeling', 13),
#  (u'checking', 13),
#  (u'vector-fields', 13),
#  (u'semiparametric', 13),
#  (u'underdetermined', 13),
#  (u'distance-covariance', 13),
#  (u'cochran-mantel-haenszel', 13),
#  (u'skellam', 13),
#  (u'viterbi-algorithm', 13),
#  (u'bland-altman-plot', 13),
#  (u'game-theory', 13),
#  (u'cochran-q', 13),
#  (u'error-in-variables', 12),
#  (u'case-cohort', 12),
#  (u'environmental-data', 12),
#  (u'latin-hypercube', 12),
#  (u'science', 12),
#  (u'geography', 12),
#  (u'expectation', 12),
#  (u'jacobian', 12),
#  (u'markov-random-field', 12),
#  (u'javascript', 12),
#  (u'search-theory', 12),
#  (u'matrix-calculus', 12),
#  (u'explanatory', 12),
#  (u'nltk', 12),
#  (u'journals', 12),
#  (u'novelty-detection', 12),
#  (u'relative-distribution', 12),
#  (u'nonparametric-density', 12),
#  (u'gwas', 12),
#  (u'growth-mixture-model', 12),
#  (u'latent-semantic-indexing', 12),
#  (u'modularity', 11),
#  (u'tweedie-distribution', 11),
#  (u'diffusion', 11),
#  (u'dyadic-data', 11),
#  (u'point-mass-at-zero', 11),
#  (u'baum-welch', 11),
#  (u'systematic', 11),
#  (u'l-moments', 11),
#  (u'lme4-nlme', 11),
#  (u'pareto', 11),
#  (u'quasi-monte-carlo', 11),
#  (u'nonlinearity', 11),
#  (u'mase', 11),
#  (u'mars', 11),
#  (u'rbf-network', 11),
#  (u'inverse-gaussian-distrib', 11),
#  (u'gamlss', 11),
#  (u'probability-calculus', 11),
#  (u'politics', 11),
#  (u'two-sample', 11),
#  (u'armax', 11),
#  (u'local-statistics', 11),
#  (u'automatic-algorithms', 11),
#  (u'mae', 11),
#  (u'invariance', 11),
#  (u'mean-shift', 11),
#  (u'disease', 10),
#  (u'q-learning', 10),
#  (u'contrast', 10),
#  (u'linear-dynamical-system', 10),
#  (u'poker', 10),
#  (u'julia', 10),
#  (u'counterbalancing', 10),
#  (u'minimum-variance', 10),
#  (u'explanatory-models', 10),
#  (u'crostons-method', 10),
#  (u'pre-training', 10),
#  (u'rao-blackwell', 10),
#  (u'party', 10),
#  (u'nlmer', 10),
#  (u'puzzle', 10),
#  (u'ward', 10),
#  (u'ordered-probit', 10),
#  ...]

# %%
results[::-1]
# Out:
# [(u'of', 27046),
#  (u'a', 20133),
#  (u'to', 19869),
#  (u'in', 19493),
#  (u'the', 19151),
#  (u'for', 16135),
#  (u'and', 12466),
#  (u'How', 11370),
#  (u'with', 10422),
#  (u'is', 7170),
#  (u'data', 6794),
#  (u'regression', 6381),
#  (u'model', 5536),
#  (u'What', 4742),
#  (u'on', 4598),
#  (u'from', 4373),
#  (u'test', 4193),
#  (u'I', 4187),
#  (u'R', 3992),
#  (u'distribution', 3862),
#  (u'between', 3632),
#  (u'variables', 3366),
#  (u'using', 3272),
#  (u'two', 3224),
#  (u'variable', 2823),
#  (u'Is', 2799),
#  (u'or', 2749),
#  (u'an', 2702),
#  (u'are', 2646),
#  (u'when', 2639),
#  (u'do', 2624),
#  (u'time', 2620),
#  (u'linear', 2549),
#  (u'random', 2451),
#  (u'-', 2420),
#  (u'use', 2348),
#  (u'sample', 2226),
#  (u'analysis', 2198),
#  (u'Why', 2112),
#  (u'multiple', 2029),
#  (u'that', 2011),
#  (u'can', 1919),
#  (u'different', 1909),
#  (u'series', 1845),
#  (u'function', 1823),
#  (u'be', 1791),
#  (u'vs', 1770),
#  (u'does', 1709),
#  (u'it', 1667),
#  (u'logistic', 1663),
#  (u'mean', 1650),
#  (u'probability', 1595),
#  (u'one', 1530),
#  (u'values', 1522),
#  (u'models', 1508),
#  (u'correlation', 1498),
#  (u'as', 1472),
#  (u'not', 1458),
#  (u'Regression', 1455),
#  (u'Can', 1446),
#  (u'error', 1416),
#  (u'how', 1415),
#  (u'this', 1368),
#  (u'by', 1362),
#  (u'variance', 1331),
#  (u'difference', 1261),
#  (u'value', 1243),
#  (u'there', 1235),
#  (u'if', 1232),
#  (u'number', 1225),
#  (u'data,', 1204),
#  (u'size', 1178),
#  (u'standard', 1158),
#  (u'calculate', 1123),
#  (u'matrix', 1111),
#  (u'effect', 1104),
#  (u'confidence', 1060),
#  (u'normal', 1050),
#  (u'statistical', 1041),
#  (u'ANOVA', 1030),
#  (u'set', 1030),
#  (u'than', 1020),
#  (u'results', 1017),
#  (u'my', 1001),
#  (u'categorical', 969),
#  (u'Bayesian', 960),
#  (u'regression,', 954),
#  (u'effects', 951),
#  (u'independent', 939),
#  (u'should', 910),
#  (u'have', 885),
#  (u'interval', 872),
#  (u'dependent', 865),
#  (u'Using', 865),
#  (u'model,', 864),
#  (u'R,', 862),
#  (u'what', 858),
#  (u'based', 854),
#  (u'mixed', 851),
#  (u'same', 846),
#  (u'about', 840),
#  (u'compare', 831),
#  (u'Model', 830),
#  (u'classification', 828),
#  (u'learning', 813),
#  (u'given', 810),
#  (u'you', 806),
#  (u'distributions', 798),
#  (u'coefficients', 796),
#  (u'continuous', 780),
#  (u'fit', 770),
#  (u'find', 768),
#  (u'method', 766),
#  (u'binary', 764),
#  (u'Does', 764),
#  (u'Linear', 763),
#  (u'Comparing', 763),
#  (u'way', 746),
#  (u'testing', 732),
#  (u'estimate', 728),
#  (u'samples', 722),
#  (u'selection', 722),
#  (u'Which', 717),
#  (u'Test', 716),
#  (u'Probability', 708),
#  (u'we', 706),
#  (u'parameters', 700),
#  (u'Random', 697),
#  (u'groups', 695),
#  (u'measures', 691),
#  (u'factor', 690),
#  (u'Poisson', 687),
#  (u'but', 685),
#  (u'Data', 684),
#  (u'interpret', 682),
#  (u'which', 680),
#  (u'significance', 678),
#  (u'likelihood', 668),
#  (u'repeated', 666),
#  (u'PCA', 661),
#  (u'prediction', 658),
#  (u'Gaussian', 657),
#  (u'parameter', 652),
#  (u'2', 648),
#  (u'binomial', 640),
#  (u'multivariate', 636),
#  (u'Distribution', 635),
#  (u'When', 635),
#  (u'neural', 633),
#  (u'distribution,', 630),
#  (u'estimation', 625),
#  (u'used', 624),
#  (u'significant', 621),
#  (u'algorithm', 619),
#  (u'interaction', 618),
#  (u'Logistic', 618),
#  (u'coefficient', 615),
#  (u'statistics', 613),
#  (u'over', 608),
#  (u'problem', 605),
#  (u'at', 595),
#  (u'measure', 594),
#  (u'plot', 593),
#  (u'clustering', 592),
#  (u'more', 592),
#  (u'best', 590),
#  (u'output', 588),
#  (u'sampling', 575),
#  (u'variables,', 571),
#  (u'Analysis', 570),
#  (u'Multiple', 569),
#  (u'package', 560),
#  (u'intervals', 557),
#  (u'large', 554),
#  (u'after', 554),
#  (u'Calculating', 553),
#  (u'only', 553),
#  (u'Statistical', 550),
#  (u'network', 549),
#  (u'many', 541),
#  (u'deviation', 539),
#  (u'into', 538),
#  (u'determine', 533),
#  (u'dataset', 529),
#  (u'Testing', 528),
#  (u'covariance', 527),
#  (u'get', 524),
#  (u'question', 523),
#  (u'population', 521),
#  (u'process', 520),
#  (u'tests', 517),
#  (u'Time', 517),
#  (u'hypothesis', 512),
#  (u'group', 512),
#  (u'training', 511),
#  (u'ratio', 510),
#  (u'density', 507),
#  (u'feature', 506),
#  (u'conditional', 506),
#  (u'A', 506),
#  (u'Difference', 499),
#  (u'each', 496),
#  (u'Are', 496),
#  (u'response', 494),
#  (u'means', 487),
#  (u'SVM', 487),
#  (u'sum', 483),
#  (u'small', 481),
#  (u'Interpreting', 479),
#  (u'Finding', 479),
#  (u'Correlation', 478),
#  (u'/', 474),
#  (u'possible', 470),
#  (u'Confidence', 469),
#  (u'validation', 469),
#  (u'errors', 466),
#  (u'Estimating', 465),
#  (u'change', 465),
#  (u'negative', 465),
#  (u'design', 459),
#  (u'some', 453),
#  (u'where', 452),
#  (u'without', 451),
#  (u'1', 451),
#  (u'all', 451),
#  (u'variable,', 447),
#  (u'methods', 447),
#  (u'features', 445),
#  (u'The', 443),
#  (u'missing', 442),
#  (u'points', 441),
#  (u'scale', 440),
#  (u'estimator', 436),
#  (u'machine', 435),
#  (u'simple', 432),
#  (u'Interpretation', 430),
#  (u'differences', 428),
#  (u'&', 422),
#  (u'distance', 421),
#  (u'residuals', 414),
#  (u'observations', 414),
#  (u'SPSS', 412),
#  (u'Markov', 412),
#  (u'other', 410),
#  (u'fixed', 408),
#  (u'test,', 408),
#  (u'distributed', 406),
#  (u'probabilities', 406),
#  (u'good', 405),
#  (u'level', 402),
#  (u'ordinal', 401),
#  (u'Should', 399),
#  (u'average', 398),
#  (u'sets', 398),
#  (u'order', 397),
#  (u'analysis,', 397),
#  (u'term', 394),
#  (u'correlated', 390),
#  (u'Standard', 386),
#  (u'=', 386),
#  (u'any', 385),
#  (u't-test', 383),
#  (u'compute', 382),
#  (u'Bayes', 382),
#  (u'has', 381),
#  (u'Sample', 381),
#  (u'make', 380),
#  (u'p-value', 379),
#  (u'point', 378),
#  (u'Understanding', 377),
#  (u'prior', 377),
#  (u'Error', 376),
#  (u'discrete', 376),
#  (u'predictor', 376),
#  (u'predictors', 374),
#  (u'Variance', 373),
#  (u'OLS', 373),
#  (u'power', 367),
#  (u'In', 367),
#  (u'GLM', 366),
#  (u'cross', 366),
#  (u'out', 365),
#  (u'log', 358),
#  (u'vector', 354),
#  (u'ARIMA', 351),
#  (u'predict', 350),
#  (u'why', 347),
#  (u'survival', 346),
#  (u'interpretation', 346),
#  (u'statistic', 344),
#  (u'single', 343),
#  (u'Neural', 342),
#  (u'appropriate', 341),
#  (u'rate', 341),
#  (u'maximum', 340),
#  (u'information', 338),
#  (u'Do', 336),
#  (u'terms', 336),
#  (u'correct', 335),
#  (u'exponential', 333),
#  (u'cluster', 333),
#  (u'perform', 330),
#  (u'factors', 330),
#  (u'accuracy', 329),
#  (u'estimates', 329),
#  (u'mean,', 328),
#  (u'need', 324),
#  (u'class', 323),
#  (u'least', 321),
#  (u'kernel', 321),
#  (u'relationship', 320),
#  (u'classifier', 319),
#  (u'Question', 319),
#  (u'Cox', 318),
#  (u'better', 316),
#  (u'zero', 316),
#  (u'models,', 316),
#  (u'comparing', 314),
#  (u'score', 314),
#  (u'weights', 311),
#  (u'equation', 311),
#  (u'curve', 311),
#  (u'whether', 310),
#  (u'within', 310),
#  (u'type', 309),
#  (u'count', 309),
#  (u'expected', 307),
#  (u'performance', 306),
#  (u"What's", 305),
#  (u'would', 304),
#  (u'panel', 304),
#  (u'fitting', 301),
#  (u'very', 299),
#  (u'transformation', 298),
#  (u'Best', 293),
#  (u'posterior', 291),
#  (u'high', 291),
#  (u'outcome', 291),
#  (u'scores', 290),
#  (u'no', 289),
#  (u'its', 285),
#  (u'3', 283),
#  (u'comparison', 282),
#  (u'weighted', 281),
#  (u'calculation', 278),
#  (u'dummy', 277),
#  (u'squares', 277),
#  (u'Fitting', 276),
#  (u'Likelihood', 275),
#  (u'Learning', 275),
#  (u'predictive', 274),
#  (u'Sampling', 274),
#  (u'Variable', 274),
#  (u'forecast', 272),
#  (u'proportions', 272),
#  (u'result', 272),
#  (u'related', 272),
#  (u'versus', 272),
#  (u'choose', 269),
#  (u'formula', 268),
#  (u'Clustering', 268),
#  (u'event', 268),
#  (u'decision', 268),
#  (u'study', 266),
#  (u'p-values', 265),
#  (u'Conditional', 265),
#  (u'equal', 265),
#  (u'survey', 264),
#  (u'help', 264),
#  (u'rank', 264),
#  (u'before', 264),
#  (u'squared', 264),
#  (u'across', 263),
#  (u'approach', 263),
#  (u'Help', 263),
#  (u'Calculate', 262),
#  (u'another', 262),
#  (u'mixture', 262),
#  (u'bias', 261),
#  (u'positive', 260),
#  (u'square', 260),
#  (u'control', 259),
#  (u'deal', 259),
#  (u'three', 259),
#  (u'If', 259),
#  (u'new', 258),
#  (u'functions', 258),
#  (u'levels', 258),
#  (u'known', 257),
#  (u'forecasting', 256),
#  (u'most', 255),
#  (u'Find', 253),
#  (u'odds', 253),
#  (u'0', 252),
#  (u'modeling', 251),
#  (u'Mean', 251),
#  (u'events', 251),
#  (u'multinomial', 250),
#  (u'check', 250),
#  (u'numbers', 248),
#  (u'outliers', 245),
#  (u'proportion', 244),
#  (u'Hypothesis', 244),
#  (u'Maximum', 242),
#  (u'Expected', 239),
#  (u'R:', 238),
#  (u'several', 237),
#  (u'table', 237),
#  (u'Mixed', 236),
#  (u'Machine', 235),
#  (u'logit', 234),
#  (u'bootstrap', 233),
#  (u'these', 233),
#  (u'non', 233),
#  (u'intercept', 232),
#  (u'Multivariate', 232),
#  (u'MLE', 232),
#  (u'tree', 232),
#  (u'comparisons', 231),
#  (u'component', 230),
#  (u'show', 230),
#  (u'input', 230),
#  (u'MCMC', 228),
#  (u'Normal', 228),
#  (u'uniform', 225),
#  (u'Two', 225),
#  (u'under', 225),
#  (u'detection', 224),
#  (u'case', 224),
#  (u'networks', 223),
#  (u't', 222),
#  (u'algorithms', 221),
#  (u'forest', 221),
#  (u'hierarchical', 220),
#  (u'null', 219),
#  (u'X', 218),
#  (u'sizes', 218),
#  (u'similarity', 218),
#  (u'apply', 218),
#  (u'AIC', 218),
#  (u'specific', 216),
#  (u'run', 216),
#  (u'both', 216),
#  (u'Binomial', 216),
#  (u'generalized', 215),
#  (u'+', 215),
#  (u'Series', 215),
#  (u'paired', 215),
#  (u'Classification', 215),
#  (u'components', 214),
#  (u'Compare', 214),
#  (u'low', 214),
#  (u'Variables', 214),
#  (u'create', 214),
#  (u'Prediction', 214),
#  (u'datasets', 213),
#  (u'Combining', 213),
#  (u'first', 213),
#  (u'graph', 213),
#  (u'Monte', 212),
#  (u'analyze', 212),
#  (u'gradient', 212),
#  (u'calculating', 211),
#  (u'trend', 211),
#  (u'up', 211),
#  (u'correlations', 211),
#  (u'treatment', 211),
#  (u'residual', 210),
#  (u'Determining', 210),
#  (u'instead', 208),
#  (u'items', 208),
#  (u'Problem', 208),
#  (u'predicted', 208),
#  (u'function,', 207),
#  (u'ROC', 207),
#  (u'median', 207),
#  (u'product', 206),
#  (u'', 206),
#  (u'statistically', 205),
#  (u'series,', 205),
#  (u'vectors', 205),
#  (u'normally', 205),
#  (u'form', 203),
#  (u'predictions', 203),
#  (u'Estimation', 203),
#  (u'Carlo', 203),
#  (u'right', 202),
#  (u'Significance', 202),
#  (u'unequal', 201),
#  (u'frequency', 200),
#  (u'independence', 200),
#  (u'range', 200),
#  (u'autocorrelation', 199),
#  (u'expectation', 199),
#  (u'cross-validation', 198),
#  (u'measurement', 198),
#  (u'sequence', 198),
#  (u'always', 198),
#  (u'Use', 197),
#  (u'Stata', 197),
#  (u'marginal', 197),
#  (u'normality', 197),
#  (u'joint', 196),
#  (u'space', 195),
#  (u'Forecasting', 195),
#  (u'Factor', 194),
#  (u'p', 192),
#  (u'nested', 192),
#  (u'principal', 192),
#  (u'importance', 191),
#  (u'Likert', 191),
#  (u'SAS', 190),
#  (u'correction', 189),
#  (u'Network', 188),
#  (u'Computing', 188),
#  (u'Confusion', 188),
#  (u'assumption', 188),
#  (u'Repeated', 188),
#  (u'fitted', 187),
#  (u'freedom', 187),
#  (u'Simple', 187),
#  (u'estimated', 186),
#  (u'include', 186),
#  (u'transform', 186),
#  (u'Forest', 186),
#  (u'know', 186),
#  (u'per', 185),
#  (u'constant', 184),
#  (u'Models', 183),
#  (u'beta', 183),
#  (u'loss', 183),
#  (u'Negative', 182),
#  (u'spatial', 181),
#  (u'handle', 181),
#  (u'example', 181),
#  (u'Feature', 181),
#  (u'Effect', 180),
#  (u'individual', 180),
#  (u'generate', 180),
#  (u'Choosing', 179),
#  (u'assumptions', 178),
#  (u'values,', 178),
#  (u'similar', 178),
#  (u'Expectation', 177),
#  (u'unknown', 176),
#  (u'Modeling', 176),
#  (u'time-series', 176),
#  (u'(or', 176),
#  (u'their', 174),
#  (u'valid', 174),
#  (u'experiment', 174),
#  (u'covariates', 174),
#  (u'estimating', 173),
#  (u'nonlinear', 173),
#  (u'while', 173),
#  (u'x', 173),
#  (u'true', 173),
#  (u'text', 172),
#  (u'optimal', 172),
#  (u'set,', 171),
#  (u'Different', 171),
#  (u'report', 170),
#  (u'ANOVA,', 169),
#  (u'Predicting', 169),
#  (u'use,', 169),
#  (u'like', 169),
#  (u'Kernel', 168),
#  (u'Wilcoxon', 168),
#  (u'Binary', 168),
#  (u'skewed', 168),
#  (u'through', 168),
#  (u'Cross', 167),
#  (u'they', 167),
#  (u'clusters', 167),
#  (u'questions', 167),
#  (u'select', 166),
#  (u'inference', 166),
#  (u'variation', 165),
#  (u'Estimate', 165),
#  (u'line', 165),
#  (u'understand', 165),
#  (u'finding', 164),
#  (u'r', 164),
#  (u'lmer', 164),
#  (u'exact', 164),
#  (u'Function', 164),
#  (u'percentage', 164),
#  (u'changes', 164),
#  (u'work', 164),
#  (u'n', 163),
#  (u'transformed', 163),
#  (u'simulation', 163),
#  (u'Generating', 163),
#  (u'assess', 163),
#  (u'modelling', 163),
#  (u'Dirichlet', 163),
#  (u'non-normal', 162),
#  (u'matrices', 162),
#  (u'Naive', 162),
#  (u'minimum', 162),
#  (u'unbalanced', 161),
#  (u'Statistics', 161),
#  (u'plots', 161),
#  (u'glm', 161),
#  (u'so', 161),
#  (u'Covariance', 160),
#  (u'optimization', 160),
#  (u'non-linear', 160),
#  (u'gamma', 159),
#  (u'multilevel', 159),
#  (u'needed', 159),
#  (u'interactions', 158),
#  (u'combine', 158),
#  (u'poisson', 157),
#  (u'covariate', 157),
#  (u'weight', 156),
#  (u'partial', 156),
#  (u'Power', 154),
#  (u'times', 154),
#  (u'will', 154),
#  (u'bivariate', 153),
#  (u'variance,', 153),
#  (u'behind', 153),
#  (u'main', 153),
#  (u'among', 152),
#  (u'stochastic', 152),
#  (u'sense', 152),
#  (u'being', 152),
#  (u'Matrix', 152),
#  (u'explain', 152),
#  (u'distributions,', 152),
#  (u'doing', 152),
#  (u'proportional', 152),
#  (u'Comparison', 151),
#  (u'noise', 151),
#  (u'observed', 151),
#  (u'imputation', 151),
#  (u'Bernoulli', 151),
#  (u'matrix,', 150),
#  (u'via', 150),
#  (u'ratios', 150),
#  (u'$R^2$', 150),
#  (u'system', 150),
#  (u'state', 149),
#  (u'parametric', 149),
#  (u'size,', 149),
#  (u'name', 149),
#  (u'convergence', 149),
#  (u'measurements', 149),
#  (u'chi-squared', 148),
#  (u'metric', 148),
#  (u'slope', 148),
#  (u'quantile', 148),
#  (u'Algorithm', 148),
#  (u'latent', 148),
#  (u'certain', 148),
#  (u'structure', 147),
#  (u'definition', 147),
#  (u'EM', 146),
#  (u'subset', 146),
#  (u'Pearson', 146),
#  (u'regarding', 146),
#  (u'relative', 146),
#  (u'equivalent', 146),
#  (u'stationary', 146),
#  (u'meaning', 145),
#  (u'robust', 145),
#  (u'Process', 145),
#  (u'regressions', 145),
#  (u'Fisher', 145),
#  (u'problem,', 145),
#  (u'95%', 144),
#  (u'evaluate', 144),
#  (u'reliability', 144),
#  (u'reduction', 144),
#  (u'degrees', 144),
#  (u'inverse', 143),
#  (u',', 143),
#  (u'total', 143),
#  (u'understanding', 143),
#  (u'categories', 143),
#  (u'Gamma', 143),
#  (u'prove', 143),
#  (u'longitudinal', 143),
#  (u'sparse', 142),
#  (u'gaussian', 141),
#  (u'explanatory', 141),
#  (u'Where', 140),
#  (u'code', 140),
#  (u'index', 140),
#  (u'significant,', 140),
#  (u'statistics,', 140),
#  (u'having', 140),
#  (u'give', 140),
#  (u'it,', 139),
#  (u'theorem', 139),
#  (u'CDF', 139),
#  (u'following', 139),
#  (u'Number', 138),
#  (u'polynomial', 138),
#  (u'limit', 138),
#  (u'entropy', 137),
#  (u'non-parametric', 137),
#  (u'real', 137),
#  (u'Need', 137),
#  (u':', 137),
#  (u'implementation', 136),
#  (u'rule', 136),
#  (u'approximation', 136),
#  (u'Sum', 136),
#  (u'lower', 136),
#  (u'me', 136),
#  (u'variances', 135),
#  (u'significantly', 135),
#  (u'length', 135),
#  (u'dataset,', 135),
#  (u'GARCH', 135),
#  (u'Y', 135),
#  (u'trees', 135),
#  (u'chain', 135),
#  (u'regression:', 135),
#  (u'less', 135),
#  (u"doesn't", 134),
#  (u'higher', 134),
#  (u'techniques', 134),
#  (u'reference', 134),
#  (u'Modelling', 134),
#  (u'Generalized', 134),
#  (u'alternative', 134),
#  (u'just', 133),
#  (u'risk', 133),
#  (u'goodness', 133),
#  (u'step', 133),
#  (u'Relationship', 133),
#  (u'results,', 132),
#  (u'experimental', 132),
#  (u'observation', 132),
#  (u'ANCOVA', 132),
#  (u'kind', 132),
#  (u'sample,', 132),
#  (u'unit', 131),
#  (u'detect', 131),
#  (u'PDF', 131),
#  (u'classes', 131),
#  (u'Convergence', 131),
#  (u'pattern', 131),
#  (u'Multinomial', 131),
#  (u'groups,', 130),
#  (u'Interaction', 130),
#  (u'support', 130),
#  (u'VAR', 129),
#  (u'too', 129),
#  (u'bayesian', 129),
#  (u'Method', 128),
#  (u'(in', 128),
#  (u'Survival', 128),
#  (u'combination', 127),
#  (u'hazard', 127),
#  (u'Categorical', 127),
#  (u'Given', 127),
#  (u'conditions', 126),
#  (u'uncertainty', 126),
#  (u'original', 126),
#  (u'learning,', 126),
#  (u'Weighted', 125),
#  (u'choice', 125),
#  (u'quadratic', 125),
#  (u'wrong', 125),
#  (u'moments', 125),
#  (u'Interval', 125),
#  (u'--', 125),
#  (u'N', 125),
#  (u'Information', 124),
#  (u'account', 124),
#  (u'rates', 124),
#  (u'precision', 124),
#  (u'exactly', 124),
#  (u'estimators', 123),
#  (u'identify', 123),
#  (u'time,', 123),
#  (u'unbiased', 123),
#  (u'against', 123),
#  (u'analyse', 123),
#  (u'empirical', 123),
#  (u'computing', 123),
#  (u'pairwise', 122),
#  (u'train', 122),
#  (u'LDA', 122),
#  (u'Gibbs', 122),
#  (u'Cluster', 122),
#  (u'seasonality', 121),
#  (u'increase', 121),
#  (u'performing', 121),
#  (u'outcomes', 121),
#  (u'Training', 121),
#  (u'problems', 121),
#  (u'Plotting', 121),
#  (u'ordered', 121),
#  (u'root', 121),
#  (u'obtain', 120),
#  (u'calculated', 120),
#  (u'correlation,', 120),
#  (u'Ratio', 120),
#  (u'Fit', 120),
#  (u'descent', 120),
#  (u'much', 120),
#  (u'greater', 120),
#  (u'Beta', 120),
#  (u'factorial', 119),
#  (u'chi', 119),
#  (u'Decision', 119),
#  (u'Effects', 119),
#  (u'add', 118),
#  (u'i', 118),
#  (u'threshold', 118),
#  (u'Average', 118),
#  (u'important', 118),
#  (u'GLMM', 117),
#  (u'family', 117),
#  (u'For', 117),
#  (u"Fisher's", 117),
#  (u'absolute', 117),
#  (u'examples', 117),
#  (u'theory', 116),
#  (u'cumulative', 116),
#  (u'required', 116),
#  (u'condition', 116),
#  (u'hidden', 116),
#  (u'Getting', 116),
#  (u'meta-analysis', 116),
#  (u'chi-square', 116),
#  (u'applied', 115),
#  (u'explanation', 115),
#  (u'Vector', 115),
#  (u'smoothing', 115),
#  (u'learn', 115),
#  (u'contingency', 114),
#  (u'ARMA', 114),
#  (u'general', 114),
#  (u'still', 114),
#  (u'Correct', 114),
#  (u'classifiers', 114),
#  (u'IV', 114),
#  (u'classification,', 113),
#  (u'bound', 113),
#  (u'Python', 113),
#  (u'larger', 113),
#  (u'Least', 113),
#  (u'Value', 113),
#  (u'standardized', 113),
#  (u'proper', 112),
#  (u'matching', 112),
#  (u'One', 112),
#  (u'Density', 112),
#  (u'k-means', 112),
#  (u'pdf', 112),
#  (u'remove', 112),
#  (u'(and', 112),
#  (u'mining', 112),
#  (u'Determine', 112),
#  (u'y', 112),
#  (u'Appropriate', 112),
#  (u'derive', 112),
#  (u'define', 111),
#  (u'proof', 111),
#  (u'varying', 111),
#  (u'getting', 111),
#  (u'adjusted', 111),
#  (u'network,', 111),
#  (u'predicting', 111),
#  (u'am', 111),
#  (u'not,', 111),
#  (u'then', 111),
#  (u'curves', 111),
#  (u"R's", 111),
#  (u'link', 110),
#  (u'subjects', 110),
#  (u'counts', 110),
#  (u'types', 110),
#  (u'LASSO', 110),
#  (u'scaling', 110),
#  (u'lme4', 110),
#  (u'F', 110),
#  (u'Hierarchical', 110),
#  (u'value,', 110),
#  (u'processes', 109),
#  (u'AUC', 109),
#  (u'Principal', 109),
#  (u'quality', 109),
#  (u'probit', 109),
#  (u'k', 109),
#  (u'dimension', 109),
#  (u'adding', 109),
#  (u'improve', 109),
#  (u'Coefficient', 108),
#  (u'dimensional', 108),
#  (u'people', 108),
#  (u'filter', 108),
#  (u'nominal', 107),
#  (u'post-hoc', 107),
#  (u'Selection', 107),
#  (u'univariate', 107),
#  (u'Joint', 107),
#  (u'measured', 107),
#  (u'relation', 107),
#  (u'cases', 107),
#  (u'deep', 107),
#  (u'convert', 106),
#  (u'Matlab', 106),
#  (u'numerical', 106),
#  (u'seasonal', 105),
#  (u'error,', 105),
#  (u'software', 105),
#  (u'Measuring', 105),
#  (u'normalization', 105),
#  (u'common', 105),
#  (u'reduce', 105),
#  (u'iid', 105),
#  (u'take', 105),
#  (u'image', 104),
#  (u'tell', 104),
#  (u"don't", 104),
#  (u'subject', 104),
#  (u'explained', 104),
#  (u'PCA,', 104),
#  (u'algorithm,', 104),
#  (u'Kolmogorov-Smirnov', 104),
#  (u'Creating', 104),
#  (u'sign', 104),
#  (u'slopes', 104),
#  (u'dimensionality', 104),
#  (u'second', 104),
#  (u'ridge', 104),
#  (u'affect', 103),
#  (u'necessary', 103),
#  (u'distributed,', 103),
#  (u'post', 103),
#  (u'visualize', 103),
#  (u'cost', 103),
#  (u'solution', 102),
#  (u'lag', 102),
#  (u'discriminant', 101),
#  (u'Kalman', 101),
#  (u'tests,', 101),
#  (u'split', 101),
#  (u'Good', 101),
#  (u'particular', 101),
#  (u'structural', 101),
#  (u'Panel', 101),
#  (u'Plot', 101),
#  (u'highly', 101),
#  (u'A/B', 101),
#  (u'populations', 101),
#  (u'Dealing', 100),
#  (u'Independent', 100),
#  (u'alpha', 100),
#  (u'anova', 100),
#  (u'Weibull', 100),
#  (u'Analyzing', 100),
#  (u'association', 100),
#  (u'trials', 99),
#  (u'histogram', 99),
#  (u'SPSS,', 99),
#  (u'decomposition', 99),
#  (u'2D', 99),
#  (u'R)', 99),
#  (u'complex', 99),
#  (u'outlier', 99),
#  (u'lasso', 99),
#  (u'Methods', 99),
#  (u'gives', 99),
#  (u'Fixed', 99),
#  (u'target', 99),
#  (u'Gradient', 98),
#  (u'technique', 98),
#  (u'Robust', 98),
#  (u'Proof', 98),
#  (u'evaluation', 98),
#  (u'Exponential', 98),
#  (u"Pearson's", 98),
#  (u'false', 97),
#  (u'separate', 97),
#  (u'Missing', 97),
#  (u'confusion', 97),
#  (u'interpreting', 97),
#  (u'represent', 97),
#  (u'Multilevel', 97),
#  (u'samples,', 97),
#  (u'summary', 97),
#  (u'regularization', 96),
#  (u'ML', 96),
#  (u'them', 96),
#  (u'Log', 96),
#  (u'two-way', 96),
#  (u'could', 96),
#  (u'5', 96),
#  (u'Parameter', 95),
#  (u'Chi', 95),
#  (u'sufficient', 95),
#  (u'Detecting', 95),
#  ...]
