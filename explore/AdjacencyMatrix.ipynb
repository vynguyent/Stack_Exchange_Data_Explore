# %%
import os
import sys

spark_home = "D:\spark-2.0.0-bin-hadoop2.7"
os.environ['SPARK_HOME'] = spark_home
sys.path.append(os.path.join(spark_home, "python"))
sys.path.append(os.path.join(spark_home, "python", "lib", "py4j-0.10.1-src.zip"))

execfile(os.path.join(spark_home, "python", "pyspark", "shell.py"))
# Out:
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 2.0.0
#       /_/
#
# Using Python version 2.7.12 (default, Jun 29 2016 11:07:13)
# SparkSession available as 'spark'.

# %%
import xmltodict
import json
import itertools
import math
communities = ['3dprinting.stackexchange.com', 'academia.stackexchange.com', 'ai.stackexchange.com', 'android.stackexchange.com', 'anime.stackexchange.com', 'apple.stackexchange.com', 'arabic.stackexchange.com', 'arduino.stackexchange.com', 'askubuntu.com', 'astronomy.stackexchange.com', 'aviation.stackexchange.com', 'avp.stackexchange.com', 'beer.stackexchange.com', 'bicycles.stackexchange.com', 'biology.stackexchange.com', 'bitcoin.stackexchange.com', 'blender.stackexchange.com', 'boardgames.stackexchange.com', 'bricks.stackexchange.com', 'buddhism.stackexchange.com', 'chemistry.stackexchange.com', 'chess.stackexchange.com', 'chinese.stackexchange.com', 'christianity.stackexchange.com', 'civicrm.stackexchange.com', 'codegolf.stackexchange.com', 'codereview.stackexchange.com', 'coffee.stackexchange.com', 'cogsci.stackexchange.com', 'computergraphics.stackexchange.com', 'cooking.stackexchange.com', 'craftcms.stackexchange.com', 'crafts.stackexchange.com', 'crypto.stackexchange.com', 'cs.stackexchange.com', 'cstheory.stackexchange.com', 'datascience.stackexchange.com', 'dba.stackexchange.com', 'diy.stackexchange.com', 'drupal.stackexchange.com', 'dsp.stackexchange.com', 'earthscience.stackexchange.com', 'ebooks.stackexchange.com', 'economics.stackexchange.com', 'electronics.stackexchange.com', 'elementaryos.stackexchange.com', 'ell.stackexchange.com', 'emacs.stackexchange.com', 'engineering.stackexchange.com', 'english.stackexchange.com', 'es.stackoverflow.com', 'ethereum.stackexchange.com', 'expatriates.stackexchange.com', 'expressionengine.stackexchange.com', 'fitness.stackexchange.com', 'freelancing.stackexchange.com', 'french.stackexchange.com', 'gamedev.stackexchange.com', 'gaming.stackexchange.com', 'gardening.stackexchange.com', 'genealogy.stackexchange.com', 'german.stackexchange.com', 'gis.stackexchange.com', 'graphicdesign.stackexchange.com', 'ham.stackexchange.com', 'hardwarerecs.stackexchange.com', 'health.stackexchange.com', 'hermeneutics.stackexchange.com', 'hinduism.stackexchange.com', 'history.stackexchange.com', 'homebrew.stackexchange.com', 'hsm.stackexchange.com', 'islam.stackexchange.com', 'italian.stackexchange.com', 'ja.stackoverflow.com', 'japanese.stackexchange.com', 'joomla.stackexchange.com', 'judaism.stackexchange.com', 'korean.stackexchange.com', 'languagelearning.stackexchange.com', 'latin.stackexchange.com', 'law.stackexchange.com', 'lifehacks.stackexchange.com', 'linguistics.stackexchange.com', 'magento.stackexchange.com', 'martialarts.stackexchange.com', 'math.stackexchange.com', 'matheducators.stackexchange.com', 'mathematica.stackexchange.com', 'mathoverflow.net', 'mechanics.stackexchange.com', 'meta.3dprinting.stackexchange.com', 'meta.academia.stackexchange.com', 'meta.ai.stackexchange.com', 'meta.android.stackexchange.com', 'meta.anime.stackexchange.com', 'meta.apple.stackexchange.com', 'meta.arabic.stackexchange.com', 'meta.arduino.stackexchange.com', 'meta.askubuntu.com', 'meta.astronomy.stackexchange.com', 'meta.aviation.stackexchange.com', 'meta.avp.stackexchange.com', 'meta.beer.stackexchange.com', 'meta.bicycles.stackexchange.com', 'meta.biology.stackexchange.com', 'meta.bitcoin.stackexchange.com', 'meta.blender.stackexchange.com', 'meta.boardgames.stackexchange.com', 'meta.bricks.stackexchange.com', 'meta.buddhism.stackexchange.com', 'meta.chemistry.stackexchange.com', 'meta.chess.stackexchange.com', 'meta.chinese.stackexchange.com', 'meta.christianity.stackexchange.com', 'meta.civicrm.stackexchange.com', 'meta.codegolf.stackexchange.com', 'meta.codereview.stackexchange.com', 'meta.coffee.stackexchange.com', 'meta.cogsci.stackexchange.com', 'meta.computergraphics.stackexchange.com', 'meta.cooking.stackexchange.com', 'meta.craftcms.stackexchange.com', 'meta.crafts.stackexchange.com', 'meta.crypto.stackexchange.com', 'meta.cs.stackexchange.com', 'meta.cstheory.stackexchange.com', 'meta.datascience.stackexchange.com', 'meta.dba.stackexchange.com', 'meta.diy.stackexchange.com', 'meta.drupal.stackexchange.com', 'meta.dsp.stackexchange.com', 'meta.earthscience.stackexchange.com', 'meta.ebooks.stackexchange.com', 'meta.economics.stackexchange.com', 'meta.electronics.stackexchange.com', 'meta.elementaryos.stackexchange.com', 'meta.ell.stackexchange.com', 'meta.emacs.stackexchange.com', 'meta.engineering.stackexchange.com', 'meta.english.stackexchange.com', 'meta.es.stackoverflow.com', 'meta.ethereum.stackexchange.com', 'meta.expatriates.stackexchange.com', 'meta.expressionengine.stackexchange.com', 'meta.fitness.stackexchange.com', 'meta.freelancing.stackexchange.com', 'meta.french.stackexchange.com', 'meta.gamedev.stackexchange.com', 'meta.gaming.stackexchange.com', 'meta.gardening.stackexchange.com', 'meta.genealogy.stackexchange.com', 'meta.german.stackexchange.com', 'meta.gis.stackexchange.com', 'meta.graphicdesign.stackexchange.com', 'meta.ham.stackexchange.com', 'meta.hardwarerecs.stackexchange.com', 'meta.health.stackexchange.com', 'meta.hermeneutics.stackexchange.com', 'meta.hinduism.stackexchange.com', 'meta.history.stackexchange.com', 'meta.homebrew.stackexchange.com', 'meta.hsm.stackexchange.com', 'meta.islam.stackexchange.com', 'meta.italian.stackexchange.com', 'meta.ja.stackoverflow.com', 'meta.japanese.stackexchange.com', 'meta.joomla.stackexchange.com', 'meta.judaism.stackexchange.com', 'meta.korean.stackexchange.com', 'meta.languagelearning.stackexchange.com', 'meta.latin.stackexchange.com', 'meta.law.stackexchange.com', 'meta.lifehacks.stackexchange.com', 'meta.linguistics.stackexchange.com', 'meta.magento.stackexchange.com', 'meta.martialarts.stackexchange.com', 'meta.math.stackexchange.com', 'meta.matheducators.stackexchange.com', 'meta.mathematica.stackexchange.com', 'meta.mathoverflow.net', 'meta.mechanics.stackexchange.com', 'meta.moderators.stackexchange.com', 'meta.monero.stackexchange.com', 'meta.money.stackexchange.com', 'meta.movies.stackexchange.com', 'meta.music.stackexchange.com', 'meta.musicfans.stackexchange.com', 'meta.mythology.stackexchange.com', 'meta.networkengineering.stackexchange.com', 'meta.opendata.stackexchange.com', 'meta.opensource.stackexchange.com', 'meta.outdoors.stackexchange.com', 'meta.parenting.stackexchange.com', 'meta.patents.stackexchange.com', 'meta.pets.stackexchange.com', 'meta.philosophy.stackexchange.com', 'meta.photo.stackexchange.com', 'meta.physics.stackexchange.com', 'meta.pm.stackexchange.com', 'meta.poker.stackexchange.com', 'meta.politics.stackexchange.com', 'meta.portuguese.stackexchange.com', 'meta.productivity.stackexchange.com', 'meta.programmers.stackexchange.com', 'meta.pt.stackoverflow.com', 'meta.puzzling.stackexchange.com', 'meta.quant.stackexchange.com', 'meta.raspberrypi.stackexchange.com', 'meta.retrocomputing.stackexchange.com', 'meta.reverseengineering.stackexchange.com', 'meta.robotics.stackexchange.com', 'meta.rpg.stackexchange.com', 'meta.ru.stackoverflow.com', 'meta.rus.stackexchange.com', 'meta.russian.stackexchange.com', 'meta.salesforce.stackexchange.com', 'meta.scicomp.stackexchange.com', 'meta.scifi.stackexchange.com', 'meta.security.stackexchange.com', 'meta.serverfault.com', 'meta.sharepoint.stackexchange.com', 'meta.skeptics.stackexchange.com', 'meta.softwarerecs.stackexchange.com', 'meta.sound.stackexchange.com', 'meta.space.stackexchange.com', 'meta.spanish.stackexchange.com', 'meta.sports.stackexchange.com', 'meta.sqa.stackexchange.com', 'meta.stackexchange.com', 'meta.stackoverflow.com', 'meta.startups.stackexchange.com', 'meta.stats.stackexchange.com', 'meta.superuser.com', 'meta.sustainability.stackexchange.com', 'meta.tex.stackexchange.com', 'meta.tor.stackexchange.com', 'meta.travel.stackexchange.com', 'meta.tridion.stackexchange.com', 'meta.unix.stackexchange.com', 'meta.ux.stackexchange.com', 'meta.vi.stackexchange.com', 'meta.webapps.stackexchange.com', 'meta.webmasters.stackexchange.com', 'meta.windowsphone.stackexchange.com', 'meta.woodworking.stackexchange.com', 'meta.wordpress.stackexchange.com', 'meta.workplace.stackexchange.com', 'meta.worldbuilding.stackexchange.com', 'meta.writers.stackexchange.com', 'moderators.stackexchange.com', 'monero.stackexchange.com', 'money.stackexchange.com', 'movies.stackexchange.com', 'music.stackexchange.com', 'musicfans.stackexchange.com', 'mythology.stackexchange.com', 'networkengineering.stackexchange.com', 'opendata.stackexchange.com', 'opensource.stackexchange.com', 'outdoors.stackexchange.com', 'parenting.stackexchange.com', 'patents.stackexchange.com', 'pets.stackexchange.com', 'philosophy.stackexchange.com', 'photo.stackexchange.com', 'physics.stackexchange.com', 'pm.stackexchange.com', 'poker.stackexchange.com', 'politics.stackexchange.com', 'portuguese.stackexchange.com', 'productivity.stackexchange.com', 'programmers.stackexchange.com', 'pt.stackoverflow.com', 'puzzling.stackexchange.com', 'quant.stackexchange.com', 'raspberrypi.stackexchange.com', 'retrocomputing.stackexchange.com', 'reverseengineering.stackexchange.com', 'robotics.stackexchange.com', 'rpg.stackexchange.com', 'ru.stackoverflow.com', 'rus.stackexchange.com', 'russian.stackexchange.com', 'salesforce.stackexchange.com', 'scicomp.stackexchange.com', 'scifi.stackexchange.com', 'security.stackexchange.com', 'serverfault.com', 'sharepoint.stackexchange.com', 'skeptics.stackexchange.com', 'softwarerecs.stackexchange.com', 'sound.stackexchange.com', 'space.stackexchange.com', 'spanish.stackexchange.com', 'sports.stackexchange.com', 'sqa.stackexchange.com', 'stackapps.com', 'stackoverflow.com', 'startups.stackexchange.com', 'stats.stackexchange.com', 'superuser.com', 'sustainability.stackexchange.com', 'tex.stackexchange.com', 'tor.stackexchange.com', 'travel.stackexchange.com', 'tridion.stackexchange.com', 'unix.stackexchange.com', 'ux.stackexchange.com', 'vi.stackexchange.com', 'webapps.stackexchange.com', 'webmasters.stackexchange.com', 'windowsphone.stackexchange.com', 'woodworking.stackexchange.com', 'wordpress.stackexchange.com', 'workplace.stackexchange.com', 'worldbuilding.stackexchange.com', 'writers.stackexchange.com'] 
# communities

# %%
def get_tags(line):
    line = xmltodict.parse(line)
    tags = line["row"]["@Tags"].replace("><", ",").replace("<", "").replace(">", "")
    tags = tags.split(",")
    tags_link = itertools.combinations(tags, 2)
    return map(lambda x:(frozenset(x), 1), tags_link)

def get_links(community, prop=0.2):
    wtf = sc.textFile("E:\\stackexchange_Extracted\\" + community + "\\Posts.xml")
    links = wtf.filter(lambda x: 'PostTypeId="1"' in x).flatMap(get_tags).reduceByKey(lambda a, b: a + b)
    sorted_links = links.sortBy(lambda (pair, count): -count).map(lambda x:(list(x[0]), x[1]))
    first_sorted_links = sorted_links.take(100)
    return first_sorted_links

# %%
def start_task(fun, out_name=""):
    results = {}
    for community in communities:
        if community == "3dprinting.stackexchange.com":
            results["three_d_printing.stackexchange.com"] = fun(community)
        else:
            results[community] = fun(community)
    if out_name:
        with open(out_name + ".txt", "w") as f:
            f.write(json.dumps(results))
    return results

# %%
start_task(get_links, "weighted_edges_min")
# Out:
# {'academia.stackexchange.com': [([u'graduate-admissions', u'phd'], 536),
#   ([u'journals', u'publications'], 412),
#   ([u'graduate-admissions', u'graduate-school'], 346),
#   ([u'peer-review', u'publications'], 290),
#   ([u'advisor', u'phd'], 273),
#   ([u'thesis', u'phd'], 249),
#   ([u'graduate-school', u'phd'], 236),
#   ([u'citations', u'publications'], 228),
#   ([u'graduate-admissions', u'masters'], 221),
#   ([u'application', u'phd'], 219),
#   ([u'publications', u'research'], 210),
#   ([u'research', u'phd'], 209),
#   ([u'paper-submission', u'publications'], 201),
#   ([u'authorship', u'publications'], 200),
#   ([u'graduate-admissions', u'application'], 194),
#   ([u'conference', u'publications'], 191),
#   ([u'graduate-admissions', u'mathematics'], 182),
#   ([u'masters', u'phd'], 170),
#   ([u'ethics', u'publications'], 169),
#   ([u'mathematics', u'phd'], 165),
#   ([u'peer-review', u'journals'], 164),
#   ([u'career-path', u'phd'], 150),
#   ([u'graduate-admissions', u'statement-of-purpose'], 149),
#   ([u'masters', u'thesis'], 145),
#   ([u'graduate-admissions', u'recommendation-letter'], 143),
#   ([u'publications', u'writing'], 142),
#   ([u'funding', u'phd'], 136),
#   ([u'publications', u'phd'], 132),
#   ([u'graduate-admissions', u'united-states'], 125),
#   ([u'computer-science', u'phd'], 122),
#   ([u'graduate-admissions', u'computer-science'], 117),
#   ([u'publications', u'editors'], 114),
#   ([u'united-states', u'phd'], 108),
#   ([u'graduate-school', u'advisor'], 107),
#   ([u'job-search', u'faculty-application'], 106),
#   ([u'job-search', u'postdocs'], 105),
#   ([u'publications', u'thesis'], 103),
#   ([u'thesis', u'writing'], 101),
#   ([u'paper-submission', u'journals'], 101),
#   ([u'peer-review', u'editors'], 98),
#   ([u'writing-style', u'writing'], 97),
#   ([u'graduate-school', u'research'], 96),
#   ([u'masters', u'graduate-school'], 96),
#   ([u'job', u'job-search'], 89),
#   ([u'mathematics', u'graduate-school'], 88),
#   ([u'masters', u'computer-science'], 85),
#   ([u'citations', u'writing'], 84),
#   ([u'journals', u'editors'], 83),
#   ([u'etiquette', u'email'], 83),
#   ([u'peer-review', u'paper-submission'], 83),
#   ([u'citations', u'citation-style'], 81),
#   ([u'graduate-admissions', u'gre'], 81),
#   ([u'arxiv', u'publications'], 80),
#   ([u'computer-science', u'publications'], 80),
#   ([u'career-path', u'postdocs'], 79),
#   ([u'publications', u'copyright'], 78),
#   ([u'citations', u'thesis'], 76),
#   ([u'mathematics', u'publications'], 76),
#   ([u'graduate-admissions', u'advisor'], 74),
#   ([u'etiquette', u'publications'], 73),
#   ([u'conference', u'paper-submission'], 72),
#   ([u'thesis', u'research'], 71),
#   ([u'conference', u'presentation'], 70),
#   ([u'research-undergraduate', u'research'], 69),
#   ([u'funding', u'united-states'], 69),
#   ([u'graduate-admissions', u'research'], 69),
#   ([u'professors', u'etiquette'], 69),
#   ([u'career-path', u'research'], 68),
#   ([u'graduate-admissions', u'career-path'], 68),
#   ([u'conference', u'peer-review'], 67),
#   ([u'masters', u'research'], 67),
#   ([u'conference', u'journals'], 67),
#   ([u'mathematics', u'research'], 66),
#   ([u'thesis', u'advisor'], 66),
#   ([u'job-search', u'tenure-track'], 65),
#   ([u'authorship', u'ethics'], 64),
#   ([u'plagiarism', u'publications'], 64),
#   ([u'publications', u'advisor'], 63),
#   ([u'postdocs', u'phd'], 63),
#   ([u'computer-science', u'research'], 61),
#   ([u'graduate-admissions', u'cv'], 61),
#   ([u'publishers', u'publications'], 61),
#   ([u'advisor', u'research'], 60),
#   ([u'recommendation-letter', u'phd'], 60),
#   ([u'etiquette', u'phd'], 59),
#   ([u'career-path', u'mathematics'], 59),
#   ([u'computer-science', u'graduate-school'], 59),
#   ([u'graduate-admissions', u'funding'], 58),
#   ([u'graduate-admissions', u'grades'], 58),
#   ([u'publications', u'graphics'], 57),
#   ([u'ethics', u'research'], 57),
#   ([u'graduate-admissions', u'undergraduate'], 57),
#   ([u'graduate-admissions', u'research-undergraduate'], 57),
#   ([u'publications', u'cv'], 57),
#   ([u'graduate-admissions', u'changing-fields'], 56),
#   ([u'cv', u'phd'], 55),
#   ([u'funding', u'research'], 55),
#   ([u'conference', u'computer-science'], 54),
#   ([u'peer-review', u'ethics'], 53),
#   ([u'application', u'masters'], 52)],
#  'ai.stackexchange.com': [([u'image-recognition', u'classification'], 5),
#   ([u'cars', u'self-driving'], 5),
#   ([u'image-recognition', u'deep-network'], 5),
#   ([u'turing-test', u'history'], 4),
#   ([u'neural-networks', u'machine-learning'], 4),
#   ([u'neural-networks', u'research'], 4),
#   ([u'neural-networks', u'deep-network'], 4),
#   ([u'training', u'neural-networks'], 3),
#   ([u'backpropagation', u'neural-networks'], 3),
#   ([u'conv-neural-network', u'neural-networks'], 3),
#   ([u'conv-neural-network', u'image-recognition'], 3),
#   ([u'deep-learning', u'image-recognition'], 3),
#   ([u'conv-neural-network', u'classification'], 3),
#   ([u'comparison', u'neural-networks'], 3),
#   ([u'decision-theory', u'self-driving'], 3),
#   ([u'deep-learning', u'research'], 3),
#   ([u'chat-bots', u'history'], 3),
#   ([u'algorithm', u'research'], 3),
#   ([u'gaming', u'monte-carlo-search'], 3),
#   ([u'chat-bots', u'turing-test'], 3),
#   ([u'neural-networks', u'computer-programming'], 3),
#   ([u'deep-learning', u'datasets'], 3),
#   ([u'deep-learning', u'algorithm'], 2),
#   ([u'chat-bots', u'emotional-intelligence'], 2),
#   ([u'deep-learning', u'classification'], 2),
#   ([u'language-processing', u'voice-recognition'], 2),
#   ([u'language-processing', u'research'], 2),
#   ([u'deep-learning', u'neural-networks'], 2),
#   ([u'implementation', u'neural-networks'], 2),
#   ([u'image-recognition', u'neural-networks'], 2),
#   ([u'self-driving', u'algorithm'], 2),
#   ([u'self-learning', u'machine-learning'], 2),
#   ([u'natural-language', u'algorithm'], 2),
#   ([u'symbolic-computing', u'gofai'], 2),
#   ([u'comparison', u'deep-network'], 2),
#   ([u'hidden-layers', u'neural-networks'], 2),
#   ([u'strong-ai', u'turing-test'], 2),
#   ([u'deepdream', u'conv-neural-network'], 2),
#   ([u'emotional-intelligence', u'intelligence-testing'], 2),
#   ([u'cars', u'object-recognition'], 2),
#   ([u'weak-ai', u'strong-ai'], 2),
#   ([u'deep-learning', u'language-processing'], 2),
#   ([u'gaming', u'search'], 2),
#   ([u'image-recognition', u'research'], 2),
#   ([u'datasets', u'image-recognition'], 2),
#   ([u'implementation', u'computer-programming'], 2),
#   ([u'hidden-layers', u'deep-network'], 2),
#   ([u'challenges', u'game-theory'], 2),
#   ([u'ethics', u'decision-theory'], 2),
#   ([u'computer-vision', u'image-recognition'], 2),
#   ([u'programming-languages', u'history'], 2),
#   ([u'algorithm', u'deep-network'], 2),
#   ([u'lexical-recognition', u'algorithm'], 2),
#   ([u'overfitting', u'deep-network'], 2),
#   ([u'computer-vision', u'conv-neural-network'], 2),
#   ([u'neural-networks', u'recurrent-neural-networks'], 2),
#   ([u'reinforcement-learning', u'research'], 2),
#   ([u'ai-design', u'strong-ai'], 2),
#   ([u'deepdreaming', u'conv-neural-network'], 2),
#   ([u'self-driving', u'object-recognition'], 2),
#   ([u'machine-learning', u'deep-network'], 2),
#   ([u'intelligence-testing', u'history'], 2),
#   ([u'self-driving', u'deep-network'], 2),
#   ([u'neural-networks', u'unsupervised-learning'], 2),
#   ([u'neural-networks', u'gofai'], 2),
#   ([u'definitions', u'intelligent-agent'], 2),
#   ([u'machine-learning', u'research'], 2),
#   ([u'emotional-intelligence', u'turing-test'], 2),
#   ([u'training', u'image-recognition'], 1),
#   ([u'neural-networks', u'agi'], 1),
#   ([u'performance', u'deepdreaming'], 1),
#   ([u'spatial-cognition', u'math'], 1),
#   ([u'definitions', u'nlp'], 1),
#   ([u'classification', u'machine-learning'], 1),
#   ([u'comparison', u'robots'], 1),
#   ([u'image-recognition', u'algorithm'], 1),
#   ([u'logic', u'gofai'], 1),
#   ([u'nlp', u'lexical-recognition'], 1),
#   ([u'genetic-algorithms', u'probabilistic'], 1),
#   ([u'datasets', u'text-generation'], 1),
#   ([u'robotics', u'navigation-systems'], 1),
#   ([u'action-recognition', u'subspace-analysis'], 1),
#   ([u'gaming', u'heuristics'], 1),
#   ([u'definitions', u'death'], 1),
#   ([u'intelligent-agent', u'reinforcement-learning'], 1),
#   ([u'reinforcement-learning', u'machine-learning'], 1),
#   ([u'texture-synthesis', u'research'], 1),
#   ([u'training', u'math'], 1),
#   ([u'emotional-intelligence', u'natural-language'], 1),
#   ([u'training', u'action-recognition'], 1),
#   ([u'posture-recognition', u'detecting-patterns'], 1),
#   ([u'texture-synthesis', u'real-time'], 1),
#   ([u'intelligence-testing', u'classification'], 1),
#   ([u'natural-language', u'world-knowledge'], 1),
#   ([u'hardware', u'neuromorphic-computing'], 1),
#   ([u'game-theory', u'history'], 1),
#   ([u'computational-linguistics', u'neuromorphic-computing'], 1),
#   ([u'neural-networks', u'misbehaviour-detection'], 1),
#   ([u'comparison', u'definitions'], 1),
#   ([u'genetic-algorithms', u'markov-chain'], 1)],
#  'android.stackexchange.com': [([u'applications', u'google-play-store'], 257),
#   ([u'battery', u'charging'], 206),
#   ([u'battery', u'battery-life'], 161),
#   ([u'sync', u'contacts'], 161),
#   ([u'insufficient-memory', u'internal-storage'], 141),
#   ([u'custom-roms', u'rom-flashing'], 133),
#   ([u'root-access', u'rooting'], 118),
#   ([u'wi-fi', u'connection-issues'], 111),
#   ([u'cyanogenmod', u'rom-flashing'], 109),
#   ([u'google-play-store', u'updates'], 109),
#   ([u'google-play-store', u'google-account'], 107),
#   ([u'wi-fi', u'networking'], 100),
#   ([u'applications', u'installation'], 100),
#   ([u'restore', u'backup'], 99),
#   ([u'adb', u'backup'], 96),
#   ([u'adb', u'fastboot'], 92),
#   ([u'nexus-5', u'5.0-lollipop'], 91),
#   ([u'cyanogenmod', u'clockworkmod-recovery'], 89),
#   ([u'recovery-mode', u'clockworkmod-recovery'], 88),
#   ([u'rom-flashing', u'rom'], 86),
#   ([u'custom-roms', u'cyanogenmod'], 84),
#   ([u'external-sd', u'sd-card'], 82),
#   ([u'samsung-galaxy-s-2', u'4.0-ice-cream-sandwich'], 79),
#   ([u'google-play-store', u'installation'], 76),
#   ([u'applications', u'security'], 75),
#   ([u'usb', u'charging'], 74),
#   ([u'shell', u'adb'], 74),
#   ([u'battery-life', u'charging'], 73),
#   ([u'storage', u'internal-storage'], 73),
#   ([u'calendar', u'sync'], 71),
#   ([u'sd-card', u'internal-storage'], 70),
#   ([u'4.4-kitkat', u'5.0-lollipop'], 70),
#   ([u'rom-flashing', u'recovery-mode'], 69),
#   ([u'wi-fi', u'internet'], 68),
#   ([u'5.0-lollipop', u'updates'], 67),
#   ([u'external-sd', u'internal-storage'], 67),
#   ([u'wi-fi', u'wifi-hotspot'], 67),
#   ([u'recovery-mode', u'adb'], 66),
#   ([u'cyanogenmod', u'samsung-galaxy-s-3'], 66),
#   ([u'security', u'lock-screens'], 65),
#   ([u'applications', u'internal-storage'], 65),
#   ([u'bootloader', u'fastboot'], 65),
#   ([u'cyanogenmod', u'adb'], 65),
#   ([u'root-access', u'adb'], 64),
#   ([u'email', u'exchange'], 64),
#   ([u'sync', u'gmail'], 63),
#   ([u'email', u'gmail'], 62),
#   ([u'recovery-mode', u'twrp'], 62),
#   ([u'nexus-5', u'4.4-kitkat'], 61),
#   ([u'rom-flashing', u'rooting'], 60),
#   ([u'4.4-kitkat', u'rooting'], 59),
#   ([u'applications', u'sd-card'], 59),
#   ([u'adb', u'rooting'], 59),
#   ([u'6.0-marshmallow', u'nexus-5'], 59),
#   ([u'notifications', u'5.0-lollipop'], 59),
#   ([u'applications', u'uninstallation'], 58),
#   ([u'usb-debugging', u'adb'], 57),
#   ([u'2.3-gingerbread', u'updates'], 57),
#   ([u'ota-update', u'updates'], 57),
#   ([u'cyanogenmod', u'recovery-mode'], 56),
#   ([u'cyanogenmod', u'samsung-galaxy-s-2'], 56),
#   ([u'4.1-jelly-bean', u'samsung-galaxy-s-3'], 56),
#   ([u'4.4-kitkat', u'updates'], 56),
#   ([u'applications', u'updates'], 55),
#   ([u'notifications', u'gmail'], 55),
#   ([u'sms', u'mms'], 55),
#   ([u'usb', u'usb-connection-mode'], 55),
#   ([u'recovery-mode', u'fastboot'], 55),
#   ([u'cyanogenmod', u'4.4-kitkat'], 55),
#   ([u'cyanogenmod', u'5.0-lollipop'], 55),
#   ([u'motorola-moto-g', u'5.0-lollipop'], 54),
#   ([u'notifications', u'sms'], 54),
#   ([u'oneplus-one', u'cyanogenmod'], 54),
#   ([u'sd-card', u'storage'], 54),
#   ([u'wi-fi', u'4.4-kitkat'], 54),
#   ([u'apk', u'installation'], 54),
#   ([u'insufficient-memory', u'storage'], 53),
#   ([u'cyanogenmod', u'root-access'], 53),
#   ([u'cyanogenmod', u'6.0-marshmallow'], 52),
#   ([u'applications', u'root-access'], 52),
#   ([u'music', u'music-player'], 52),
#   ([u'internal-sd', u'internal-storage'], 51),
#   ([u'adb', u'linux'], 51),
#   ([u'nexus-4', u'5.0-lollipop'], 51),
#   ([u'adb', u'usb'], 51),
#   ([u'cyanogenmod', u'twrp'], 51),
#   ([u'rom-flashing', u'clockworkmod-recovery'], 51),
#   ([u'languages', u'localization'], 50),
#   ([u'google-play-store', u'cyanogenmod'], 50),
#   ([u'sync', u'google-account'], 50),
#   ([u'lock-screens', u'5.0-lollipop'], 50),
#   ([u'custom-roms', u'rom'], 50),
#   ([u'google-contacts', u'contacts'], 50),
#   ([u'wi-fi', u'5.0-lollipop'], 49),
#   ([u'sms', u'contacts'], 49),
#   ([u'gmail', u'contacts'], 49),
#   ([u'locked-out', u'lock-screens'], 49),
#   ([u'6.0-marshmallow', u'adoptable-storage'], 49),
#   ([u'cyanogenmod', u'rooting'], 49),
#   ([u'applications', u'5.0-lollipop'], 49)],
#  'anime.stackexchange.com': [([u'fma-brotherhood', u'fma-series'], 68),
#   ([u'fate-zero', u'fate-stay-night'], 29),
#   ([u'fma-series', u'fullmetal-alchemist-2003'], 23),
#   ([u'dragon-ball-series', u'dragon-ball-z'], 21),
#   ([u'one-piece', u'music'], 21),
#   ([u'anime-production', u'manga-production'], 20),
#   ([u'anime-production', u'anime-history'], 20),
#   ([u'tropes', u'anime-history'], 19),
#   ([u'culture', u'tropes'], 17),
#   ([u'fullmetal-alchemist-manga', u'fma-series'], 15),
#   ([u'manga-history', u'anime-history'], 14),
#   ([u'toaru-majutsu-no-index', u'toaru-kagaku-no-railgun'], 12),
#   ([u'music', u'parasyte'], 12),
#   ([u'fma-brotherhood', u'fullmetal-alchemist-2003'], 11),
#   ([u'naruto', u'music'], 11),
#   ([u'anime-production', u'tropes'], 9),
#   ([u'dragon-ball-super', u'dragon-ball-series'], 9),
#   ([u'manga-production', u'mangaka'], 8),
#   ([u'music', u'shigatsu-wa-kimi-no-uso'], 8),
#   ([u'music', u'tokyo-ghoul'], 8),
#   ([u'manga-production', u'manga-history'], 7),
#   ([u'naruto', u'naruto-gaiden'], 7),
#   ([u'anime-production', u'terminology'], 7),
#   ([u'dragon-ball', u'dragon-ball-z'], 7),
#   ([u'japanese-language', u'terminology'], 7),
#   ([u'anime-production', u'voice-acting'], 7),
#   ([u'code-geass', u'music'], 7),
#   ([u'music', u'sekai-ichi-hatsukoi'], 7),
#   ([u'culture', u'japanese-language'], 6),
#   ([u'dragon-ball', u'dragon-ball-series'], 6),
#   ([u'culture', u'anime-history'], 6),
#   ([u'fma-brotherhood', u'fullmetal-alchemist-manga'], 6),
#   ([u'code-geass', u'akito-the-exiled'], 6),
#   ([u'music', u'fairy-tail'], 5),
#   ([u'anime-production', u'music'], 5),
#   ([u'naruto', u'japanese-language'], 5),
#   ([u'anime-production', u'censorship'], 5),
#   ([u'k-project', u'music'], 5),
#   ([u'attack-on-titan', u'music'], 5),
#   ([u'theme-song', u'music'], 5),
#   ([u'tsubasa-chronicle', u'xxxholic'], 5),
#   ([u'anime-production', u'culture'], 5),
#   ([u'tropes', u'terminology'], 5),
#   ([u'tropes', u'manga-history'], 5),
#   ([u'dragon-ball-super', u'dragon-ball-z'], 5),
#   ([u'fma-brotherhood', u'music'], 4),
#   ([u'tsubasa-chronicle', u'cardcaptor-sakura'], 4),
#   ([u'naruto', u'tropes'], 4),
#   ([u'fma-series', u'music'], 4),
#   ([u'dragon-ball-series', u'dragon-ball-gt'], 4),
#   ([u'ghost-in-the-shell-sac', u'ghost-in-the-shell'], 4),
#   ([u'ghost-in-the-shell-sac', u'ghost-in-the-shell-arise'], 4),
#   ([u'music', u'bleach'], 4),
#   ([u'ghost-in-the-shell', u'ghost-in-the-shell-arise'], 4),
#   ([u'dragon-ball', u'dragon-ball-gt'], 4),
#   ([u'madoka-magica', u'music'], 4),
#   ([u'fate-stay-night', u'fate-kaleid-liner'], 4),
#   ([u'music', u'hunter-x-hunter'], 4),
#   ([u'naruto', u'india'], 4),
#   ([u'death-billiards', u'death-parade'], 3),
#   ([u'manga-production', u'bakuman'], 3),
#   ([u'lucky-star', u'tropes'], 3),
#   ([u'anime-production', u'streaming-sites'], 3),
#   ([u'magi', u'music'], 3),
#   ([u'naruto', u'culture'], 3),
#   ([u'steins-gate', u'chaos-head'], 3),
#   ([u'anime-production', u'crunchyroll'], 3),
#   ([u'akame-ga-kill', u'music'], 3),
#   ([u'theme-song', u'tropes'], 3),
#   ([u'hellsing', u'music'], 3),
#   ([u'dragon-ball-z', u'dragon-ball-gt'], 3),
#   ([u'robotics-notes', u'chaos-head'], 3),
#   ([u'steins-gate', u'robotics-notes'], 3),
#   ([u'culture', u'sailor-moon'], 3),
#   ([u'cowboy-bebop', u'music'], 3),
#   ([u'digimon-tri', u'digimon'], 3),
#   ([u'merchandise', u'anime-history'], 3),
#   ([u'fate-extra', u'fate-stay-night'], 3),
#   ([u'anime-production', u'japanese-language'], 3),
#   ([u'anime-production', u'theme-song'], 3),
#   ([u'terminology', u'amv'], 3),
#   ([u'symbolism', u'naruto'], 3),
#   ([u'music', u'vocaloid'], 3),
#   ([u'culture', u'terminology'], 3),
#   ([u'fate-zero', u'fate-extra'], 3),
#   ([u'code-geass', u'merchandise'], 3),
#   ([u'anime-production', u'naruto'], 3),
#   ([u'culture', u'manga-history'], 3),
#   ([u'cardcaptor-sakura', u'xxxholic'], 3),
#   ([u'manga-production', u'monthly-girls-nozaki-kun'], 3),
#   ([u'symbolism', u'theme-song'], 3),
#   ([u'monogatari-series', u'japanese-language'], 3),
#   ([u'uq-holder', u'negima'], 3),
#   ([u'diebuster', u'gunbuster'], 2),
#   ([u'culture', u'chuunibyou'], 2),
#   ([u'manga-production', u'copyright'], 2),
#   ([u'tropes', u'japanese-language'], 2),
#   ([u'tsukihime', u'fate-stay-night'], 2),
#   ([u'one-piece', u'fairy-tail'], 2),
#   ([u'culture', u'dragon-ball-series'], 2)],
#  'apple.stackexchange.com': [([u'ios', u'iphone'], 1987),
#   ([u'osx', u'yosemite'], 1358),
#   ([u'terminal', u'osx'], 1253),
#   ([u'osx', u'macbook'], 1180),
#   ([u'osx', u'mac'], 1065),
#   ([u'osx', u'mavericks'], 1059),
#   ([u'osx', u'el-capitan'], 1033),
#   ([u'osx', u'finder'], 958),
#   ([u'ipad', u'ios'], 932),
#   ([u'osx', u'lion'], 913),
#   ([u'itunes', u'iphone'], 886),
#   ([u'osx', u'keyboard'], 845),
#   ([u'macbook', u'display'], 799),
#   ([u'osx', u'mountain-lion'], 743),
#   ([u'wifi', u'network'], 709),
#   ([u'backup', u'time-machine'], 604),
#   ([u'ipad', u'iphone'], 591),
#   ([u'iphone', u'icloud'], 587),
#   ([u'osx', u'network'], 565),
#   ([u'mail.app', u'email'], 561),
#   ([u'osx', u'command-line'], 478),
#   ([u'itunes', u'ios'], 446),
#   ([u'terminal', u'bash'], 443),
#   ([u'terminal', u'command-line'], 436),
#   ([u'osx', u'hard-drive'], 429),
#   ([u'itunes', u'music'], 425),
#   ([u'macbook', u'yosemite'], 418),
#   ([u'osx', u'safari'], 416),
#   ([u'windows', u'bootcamp'], 412),
#   ([u'hard-drive', u'disk-utility'], 410),
#   ([u'hard-drive', u'macbook'], 410),
#   ([u'osx', u'applescript'], 397),
#   ([u'hardware', u'macbook'], 397),
#   ([u'battery', u'macbook'], 397),
#   ([u'applications', u'ios'], 390),
#   ([u'ios', u'icloud'], 387),
#   ([u'osx', u'applications'], 382),
#   ([u'itunes', u'data-synchronization'], 379),
#   ([u'macbook', u'mavericks'], 372),
#   ([u'lion', u'macbook'], 369),
#   ([u'applications', u'iphone'], 366),
#   ([u'ssd', u'macbook'], 365),
#   ([u'osx', u'install'], 359),
#   ([u'ios-appstore', u'ios'], 358),
#   ([u'macbook', u'keyboard'], 354),
#   ([u'osx', u'software-recommendation'], 351),
#   ([u'partition', u'disk-utility'], 350),
#   ([u'ipad', u'itunes'], 341),
#   ([u'wifi', u'macbook'], 338),
#   ([u'osx', u'snow-leopard'], 338),
#   ([u'sleep-wake', u'macbook'], 332),
#   ([u'data-synchronization', u'iphone'], 329),
#   ([u'osx', u'bash'], 327),
#   ([u'windows-7', u'bootcamp'], 322),
#   ([u'mountain-lion', u'macbook'], 316),
#   ([u'photos', u'iphone'], 312),
#   ([u'partition', u'bootcamp'], 311),
#   ([u'applescript', u'automator'], 308),
#   ([u'jailbreak', u'ios'], 304),
#   ([u'airport', u'wifi'], 294),
#   ([u'osx', u'mail.app'], 285),
#   ([u'wifi', u'iphone'], 284),
#   ([u'ssd', u'hard-drive'], 284),
#   ([u'airport', u'network'], 281),
#   ([u'macbook', u'memory'], 277),
#   ([u'osx', u'time-machine'], 277),
#   ([u'osx', u'disk-utility'], 277),
#   ([u'jailbreak', u'iphone'], 277),
#   ([u'boot', u'macbook'], 275),
#   ([u'osx', u'display'], 275),
#   ([u'backup', u'iphone'], 272),
#   ([u'osx', u'partition'], 266),
#   ([u'mac', u'macbook'], 265),
#   ([u'osx', u'boot'], 261),
#   ([u'osx', u'ios'], 260),
#   ([u'hard-drive', u'partition'], 260),
#   ([u'macbook', u'bootcamp'], 258),
#   ([u'osx', u'permission'], 255),
#   ([u'osx', u'security'], 251),
#   ([u'iphone-4', u'iphone'], 251),
#   ([u'osx', u'dock'], 250),
#   ([u'audio', u'macbook'], 247),
#   ([u'iphone', u'imessage'], 237),
#   ([u'osx', u'wifi'], 235),
#   ([u'iphone', u'contacts'], 231),
#   ([u'windows', u'osx'], 227),
#   ([u'iphone-4', u'ios'], 226),
#   ([u'osx', u'homebrew'], 225),
#   ([u'osx', u'bootcamp'], 224),
#   ([u'itunes', u'osx'], 224),
#   ([u'photos', u'icloud'], 222),
#   ([u'mail.app', u'gmail'], 218),
#   ([u'itunes', u'icloud'], 211),
#   ([u'pdf', u'preview'], 210),
#   ([u'osx', u'mac-appstore'], 208),
#   ([u'osx', u'backup'], 208),
#   ([u'el-capitan', u'macbook'], 208),
#   ([u'osx', u'google-chrome'], 206),
#   ([u'iphone-4s', u'iphone'], 205),
#   ([u'thunderbolt', u'display'], 205)],
#  'arabic.stackexchange.com': [([u'quran', u'grammar'], 6),
#   ([u'declination', u'grammar'], 4),
#   ([u'meaning', u'vocabulary'], 3),
#   ([u'quran', u'meaning'], 3),
#   ([u'quran', u'gender'], 3),
#   ([u'meaning', u'grammar'], 2),
#   ([u'spelling', u'grammar'], 2),
#   ([u'meaning', u'synonym'], 2),
#   ([u'grammar', u'learning'], 2),
#   ([u'quran', u'classical-arabic'], 2),
#   ([u'grammar', u'conjugation'], 2),
#   ([u'alphabet', u'dictation'], 2),
#   ([u'madhab', u'grammar'], 2),
#   ([u'grammar', u'poetry'], 2),
#   ([u'gender', u'grammar'], 2),
#   ([u'translation', u'single-word-requests'], 1),
#   ([u'orthography', u'transliteration'], 1),
#   ([u'meaning', u'translation'], 1),
#   ([u'translation', u'arabic-to-english'], 1),
#   ([u'english-to-arabic', u'synonym'], 1),
#   ([u'orthography', u'classical-arabic'], 1),
#   ([u'orthography', u'pronouns'], 1),
#   ([u'tree', u'synonym'], 1),
#   ([u'meaning', u'root'], 1),
#   ([u'lam', u'negation'], 1),
#   ([u'numbers', u'writing'], 1),
#   ([u'grammar', u'msa'], 1),
#   ([u'maa', u'grammar'], 1),
#   ([u'basra', u'grammar'], 1),
#   ([u'school', u'basra'], 1),
#   ([u'particles', u'orthography'], 1),
#   ([u'orthography', u'meaning'], 1),
#   ([u'usage-in-sentence', u'conjugation'], 1),
#   ([u'root', u'vocabulary'], 1),
#   ([u'origin', u'translation'], 1),
#   ([u'english-to-arabic', u'grammar'], 1),
#   ([u'grammar', u'plural'], 1),
#   ([u'quran', u'orthography'], 1),
#   ([u'dimuntives', u'nouns'], 1),
#   ([u'usage-in-sentence', u'grammar'], 1),
#   ([u'classical-arabic', u'conjugation'], 1),
#   ([u'morphology', u'dimuntives'], 1),
#   ([u'orthography', u'conjugation'], 1),
#   ([u'translation', u'learning'], 1),
#   ([u'english-to-arabic', u'meaning'], 1),
#   ([u'idafa', u'word-combination'], 1),
#   ([u'orthography', u'dictation'], 1),
#   ([u'poet', u'verse'], 1),
#   ([u'english-to-arabic', u'learning'], 1),
#   ([u'hamza', u'classical-arabic'], 1),
#   ([u'morphology', u'nouns'], 1),
#   ([u'grammar', u'vocabulary'], 1),
#   ([u'conversation', u'colloquial'], 1),
#   ([u'madhab', u'kufa'], 1),
#   ([u'translation', u'judeo-arabic'], 1),
#   ([u'school', u'grammar'], 1),
#   ([u'orthography', u'grammar'], 1),
#   ([u'grammar', u'five-nouns'], 1),
#   ([u'arabic-to-english', u'learning'], 1),
#   ([u'pronunciation', u'classical-arabic'], 1),
#   ([u'quran', u'pronunciation'], 1),
#   ([u'english-to-arabic', u'vocabulary'], 1),
#   ([u'learning', u'vocabulary'], 1),
#   ([u'classical-arabic', u'grammar'], 1),
#   ([u'particles', u'pronouns'], 1),
#   ([u'pronunciation', u'hamza'], 1),
#   ([u'quran', u'hamza'], 1),
#   ([u'semitic-languages', u'hebrew'], 1),
#   ([u'declination', u'substantive'], 1),
#   ([u'article', u'idafa'], 1),
#   ([u'pattern', u'grammar'], 1),
#   ([u'semitic-languages', u'usage-in-sentence'], 1),
#   ([u'declination', u'plural'], 1),
#   ([u'poet', u'poem'], 1),
#   ([u'adjective', u'definition'], 1),
#   ([u'alphabet', u'verse'], 1),
#   ([u'arabic-the', u'al'], 1),
#   ([u'phrase', u'translation'], 1),
#   ([u'poetry', u'conjugation'], 1),
#   ([u'orthography', u'alphabet'], 1),
#   ([u'conversation', u'grammar'], 1),
#   ([u'declination', u'nouns'], 1),
#   ([u'vocabulary', u'hebrew'], 1),
#   ([u'lam', u'lan'], 1),
#   ([u'classical-arabic', u'writing'], 1),
#   ([u'gender', u'meaning'], 1),
#   ([u'gender', u'plural'], 1),
#   ([u'gender', u'nouns'], 1),
#   ([u'quran', u'tajweed'], 1),
#   ([u'madhab', u'school'], 1),
#   ([u'gender', u'music'], 1),
#   ([u'kufa', u'grammar'], 1),
#   ([u'dialects', u'translation'], 1),
#   ([u'quran', u'writing'], 1),
#   ([u'particles', u'prepositions'], 1),
#   ([u'quran', u'declination'], 1),
#   ([u'arud', u'writing'], 1),
#   ([u'kufa', u'basra'], 1),
#   ([u'pattern', u'plural'], 1),
#   ([u'madhab', u'learning'], 1)],
#  'arduino.stackexchange.com': [([u'serial', u'arduino-uno'], 269),
#   ([u'arduino-uno', u'programming'], 216),
#   ([u'sensors', u'arduino-uno'], 175),
#   ([u'arduino-uno', u'c++'], 138),
#   ([u'arduino-uno', u'motor'], 125),
#   ([u'led', u'arduino-uno'], 104),
#   ([u'arduino-uno', u'power'], 102),
#   ([u'arduino-uno', u'shields'], 102),
#   ([u'programming', u'c++'], 91),
#   ([u'arduino-uno', u'bluetooth'], 90),
#   ([u'arduino-ide', u'arduino-uno'], 88),
#   ([u'arduino-uno', u'arduino-mega'], 87),
#   ([u'arduino-uno', u'esp8266'], 87),
#   ([u'ethernet', u'arduino-uno'], 85),
#   ([u'gsm', u'arduino-uno'], 83),
#   ([u'serial', u'arduino-mega'], 83),
#   ([u'wifi', u'arduino-uno'], 80),
#   ([u'lcd', u'arduino-uno'], 79),
#   ([u'pins', u'arduino-uno'], 73),
#   ([u'arduino-uno', u'servo'], 72),
#   ([u'pwm', u'arduino-uno'], 72),
#   ([u'i2c', u'arduino-uno'], 72),
#   ([u'serial', u'programming'], 67),
#   ([u'serial', u'softwareserial'], 65),
#   ([u'c', u'arduino-uno'], 63),
#   ([u'sketch', u'programming'], 55),
#   ([u'serial', u'usb'], 53),
#   ([u'arduino-uno', u'atmega328'], 53),
#   ([u'communication', u'serial'], 52),
#   ([u'programming', u'arduino-mega'], 51),
#   ([u'serial', u'c++'], 50),
#   ([u'arduino-uno', u'softwareserial'], 50),
#   ([u'communication', u'arduino-uno'], 50),
#   ([u'arduino-uno', u'analogread'], 48),
#   ([u'c', u'programming'], 47),
#   ([u'interrupt', u'arduino-uno'], 47),
#   ([u'python', u'serial'], 43),
#   ([u'serial', u'bluetooth'], 43),
#   ([u'arduino-uno', u'usb'], 43),
#   ([u'xbee', u'arduino-uno'], 42),
#   ([u'timers', u'arduino-uno'], 42),
#   ([u'sketch', u'arduino-uno'], 41),
#   ([u'wifi', u'esp8266'], 40),
#   ([u'arduino-uno', u'uploading'], 39),
#   ([u'battery', u'power'], 39),
#   ([u'arduino-motor-shield', u'arduino-uno'], 38),
#   ([u'arduino-motor-shield', u'motor'], 38),
#   ([u'arduino-uno', u'voltage-level'], 38),
#   ([u'adafruit', u'arduino-uno'], 37),
#   ([u'arduino-ide', u'esp8266'], 37),
#   ([u'sd-card', u'arduino-uno'], 36),
#   ([u'electronics', u'arduino-uno'], 35),
#   ([u'sensors', u'arduino-mega'], 35),
#   ([u'rfid', u'arduino-uno'], 35),
#   ([u'arduino-ide', u'programming'], 34),
#   ([u'button', u'arduino-uno'], 34),
#   ([u'interrupt', u'timers'], 34),
#   ([u'arduino-uno', u'library'], 34),
#   ([u'c++', u'arduino-mega'], 34),
#   ([u'sensors', u'programming'], 32),
#   ([u'wifi', u'shields'], 32),
#   ([u'arduino-nano', u'arduino-uno'], 32),
#   ([u'bootloader', u'arduino-uno'], 32),
#   ([u'hardware', u'arduino-uno'], 31),
#   ([u'arduino-uno', u'accelerometer'], 31),
#   ([u'arduino-uno', u'gps'], 31),
#   ([u'robotics', u'arduino-uno'], 31),
#   ([u'serial', u'sensors'], 30),
#   ([u'web-server', u'arduino-uno'], 30),
#   ([u'arduino-ide', u'c++'], 30),
#   ([u'arduino-uno', u'time'], 30),
#   ([u'arduino-uno', u'relay'], 29),
#   ([u'serial', u'arduino-ide'], 29),
#   ([u'xbee', u'serial'], 29),
#   ([u'temperature-sensor', u'arduino-uno'], 29),
#   ([u'arduino-uno', u'string'], 29),
#   ([u'voltage-level', u'power'], 28),
#   ([u'power', u'arduino-mega'], 28),
#   ([u'c++', u'library'], 27),
#   ([u'serial', u'arduino-due'], 27),
#   ([u'uart', u'serial'], 27),
#   ([u'servo', u'motor'], 26),
#   ([u'ir', u'arduino-uno'], 26),
#   ([u'interrupt', u'arduino-mega'], 26),
#   ([u'arduino-yun', u'wifi'], 26),
#   ([u'motor', u'arduino-mega'], 26),
#   ([u'shields', u'arduino-mega'], 25),
#   ([u'arduino-uno', u'mpu6050'], 25),
#   ([u'avrdude', u'arduino-uno'], 25),
#   ([u'nrf24l01+', u'arduino-uno'], 25),
#   ([u'pwm', u'motor'], 25),
#   ([u'pwm', u'led'], 25),
#   ([u'compile', u'arduino-uno'], 24),
#   ([u'c', u'c++'], 24),
#   ([u'gsm', u'shields'], 24),
#   ([u'gsm', u'arduino-mega'], 24),
#   ([u'serial', u'arduino-nano'], 24),
#   ([u'android', u'arduino-uno'], 23),
#   ([u'python', u'arduino-uno'], 23),
#   ([u'programming', u'library'], 23)],
#  'askubuntu.com': [([u'grub2', u'boot'], 3164),
#   ([u'grub2', u'dual-boot'], 2890),
#   ([u'wireless', u'networking'], 2721),
#   ([u'dual-boot', u'boot'], 2672),
#   ([u'partitioning', u'dual-boot'], 2225),
#   ([u'drivers', u'nvidia'], 2118),
#   ([u'command-line', u'bash'], 2079),
#   ([u'package-management', u'apt'], 2048),
#   ([u'wireless', u'drivers'], 1661),
#   ([u'networking', u'server'], 1567),
#   ([u'drivers', u'graphics'], 1508),
#   ([u'bash', u'scripts'], 1390),
#   ([u'14.04', u'networking'], 1323),
#   ([u'partitioning', u'boot'], 1271),
#   ([u'drivers', u'14.04'], 1204),
#   ([u'dual-boot', u'uefi'], 1197),
#   ([u'command-line', u'scripts'], 1133),
#   ([u'drivers', u'networking'], 1112),
#   ([u'graphics', u'nvidia'], 1111),
#   ([u'boot', u'usb'], 1105),
#   ([u'14.04', u'boot'], 1101),
#   ([u'dual-boot', u'windows-7'], 1098),
#   ([u'launcher', u'unity'], 1098),
#   ([u'boot', u'uefi'], 1086),
#   ([u'12.04', u'installation'], 1080),
#   ([u'sound', u'pulseaudio'], 1071),
#   ([u'wireless', u'14.04'], 1020),
#   ([u'networking', u'network-manager'], 1018),
#   ([u'dpkg', u'apt'], 1006),
#   ([u'updates', u'apt'], 990),
#   ([u'drivers', u'ati'], 964),
#   ([u'windows-8', u'dual-boot'], 964),
#   ([u'grub2', u'partitioning'], 919),
#   ([u'wireless', u'12.04'], 913),
#   ([u'grub2', u'uefi'], 899),
#   ([u'dual-boot', u'installation'], 894),
#   ([u'dual-boot', u'14.04'], 883),
#   ([u'wireless', u'broadcom'], 858),
#   ([u'sound', u'alsa'], 853),
#   ([u'networking', u'internet'], 850),
#   ([u'boot', u'system-installation'], 837),
#   ([u'14.04', u'server'], 834),
#   ([u'windows', u'dual-boot'], 827),
#   ([u'14.04', u'nvidia'], 820),
#   ([u'apache2', u'server'], 801),
#   ([u'boot', u'12.04'], 800),
#   ([u'partitioning', u'hard-drive'], 800),
#   ([u'dual-boot', u'system-installation'], 795),
#   ([u'gparted', u'partitioning'], 764),
#   ([u'14.04', u'upgrade'], 750),
#   ([u'unity', u'14.04'], 738),
#   ([u'unity', u'gnome'], 736),
#   ([u'unity', u'compiz'], 736),
#   ([u'networking', u'12.04'], 727),
#   ([u'boot', u'installation'], 726),
#   ([u'drivers', u'12.04'], 707),
#   ([u'xorg', u'nvidia'], 707),
#   ([u'shortcut-keys', u'keyboard'], 706),
#   ([u'upgrade', u'12.04'], 702),
#   ([u'ssh', u'server'], 686),
#   ([u'partitioning', u'installation'], 680),
#   ([u'14.04', u'apt'], 671),
#   ([u'ati', u'graphics'], 663),
#   ([u'dpkg', u'package-management'], 650),
#   ([u'unity', u'12.04'], 647),
#   ([u'12.04', u'server'], 644),
#   ([u'upgrade', u'apt'], 620),
#   ([u'dual-boot', u'12.04'], 616),
#   ([u'14.04', u'system-installation'], 615),
#   ([u'partitioning', u'system-installation'], 610),
#   ([u'pulseaudio', u'alsa'], 592),
#   ([u'php', u'apache2'], 589),
#   ([u'dependencies', u'apt'], 589),
#   ([u'multiple-monitors', u'nvidia'], 588),
#   ([u'partitioning', u'mount'], 584),
#   ([u'kde', u'kubuntu'], 566),
#   ([u'12.04', u'nvidia'], 563),
#   ([u'ethernet', u'networking'], 559),
#   ([u'software-installation', u'apt'], 548),
#   ([u'dependencies', u'package-management'], 547),
#   ([u'sound', u'14.04'], 545),
#   ([u'grub2', u'14.04'], 531),
#   ([u'wireless', u'network-manager'], 528),
#   ([u'wireless', u'internet'], 520),
#   ([u'kernel', u'boot'], 504),
#   ([u'14.04', u'software-installation'], 498),
#   ([u'grub2', u'12.04'], 495),
#   ([u'juju', u'maas'], 490),
#   ([u'networking', u'dns'], 485),
#   ([u'keyboard-layout', u'keyboard'], 484),
#   ([u'unity', u'unity-dash'], 483),
#   ([u'14.04', u'command-line'], 476),
#   ([u'drivers', u'broadcom'], 473),
#   ([u'windows', u'boot'], 461),
#   ([u'11.04', u'unity'], 458),
#   ([u'grub2', u'windows-7'], 454),
#   ([u'kernel', u'14.04'], 454),
#   ([u'xfce', u'xubuntu'], 452),
#   ([u'mount', u'hard-drive'], 452),
#   ([u'unity', u'11.10'], 449)],
#  'astronomy.stackexchange.com': [([u'planet', u'solar-system'], 72),
#   ([u'sun', u'earth'], 46),
#   ([u'earth', u'the-moon'], 44),
#   ([u'black-hole', u'gravity'], 41),
#   ([u'planet', u'orbit'], 38),
#   ([u'earth', u'orbit'], 35),
#   ([u'solar-system', u'orbit'], 33),
#   ([u'milky-way', u'galaxy'], 33),
#   ([u'sun', u'solar-system'], 32),
#   ([u'sun', u'orbit'], 28),
#   ([u'distances', u'star'], 27),
#   ([u'star', u'galaxy'], 26),
#   ([u'supermassive-black-hole', u'black-hole'], 26),
#   ([u'sun', u'star'], 26),
#   ([u'orbit', u'gravity'], 25),
#   ([u'planet', u'star'], 24),
#   ([u'sun', u'the-moon'], 24),
#   ([u'planet', u'exoplanet'], 24),
#   ([u'the-moon', u'orbit'], 23),
#   ([u'amateur-observing', u'observation'], 23),
#   ([u'stellar-evolution', u'star'], 21),
#   ([u'light', u'star'], 21),
#   ([u'light', u'speed'], 20),
#   ([u'earth', u'solar-system'], 19),
#   ([u'black-hole', u'star'], 19),
#   ([u'amateur-observing', u'telescope'], 19),
#   ([u'universe', u'expansion'], 19),
#   ([u'gravity', u'general-relativity'], 18),
#   ([u'planet', u'gravity'], 18),
#   ([u'earth', u'gravity'], 17),
#   ([u'black-hole', u'space-time'], 17),
#   ([u'universe', u'big-bang-theory'], 17),
#   ([u'earth', u'rotation'], 17),
#   ([u'star-formation', u'star'], 16),
#   ([u'universe', u'cosmology'], 16),
#   ([u'planet', u'9th-planet'], 16),
#   ([u'planet', u'the-moon'], 16),
#   ([u'star', u'gravity'], 16),
#   ([u'black-hole', u'general-relativity'], 15),
#   ([u'mass', u'star'], 15),
#   ([u'space-time', u'gravity'], 15),
#   ([u'solar-system', u'the-moon'], 14),
#   ([u'light', u'gravity'], 14),
#   ([u'supernova', u'star'], 14),
#   ([u'space-time', u'general-relativity'], 14),
#   ([u'galactic-dynamics', u'galaxy'], 14),
#   ([u'universe', u'galaxy'], 14),
#   ([u'planet', u'earth'], 14),
#   ([u'optics', u'telescope'], 14),
#   ([u'gravitational-waves', u'black-hole'], 14),
#   ([u'star', u'orbit'], 14),
#   ([u'star', u'observation'], 14),
#   ([u'astrophysics', u'black-hole'], 13),
#   ([u'amateur-observing', u'star'], 13),
#   ([u'black-hole', u'neutron-star'], 13),
#   ([u'solar-system', u'gravity'], 13),
#   ([u'planet', u'observation'], 13),
#   ([u'solar-system', u'9th-planet'], 13),
#   ([u'gravitational-waves', u'gravity'], 12),
#   ([u'universe', u'space'], 12),
#   ([u'gravity', u'dark-matter'], 12),
#   ([u'asteroids', u'orbit'], 12),
#   ([u'observation', u'telescope'], 12),
#   ([u'orbital-elements', u'orbit'], 12),
#   ([u'cosmological-inflation', u'cosmology'], 12),
#   ([u'cmb', u'cosmology'], 12),
#   ([u'astrophysics', u'orbit'], 12),
#   ([u'solar-system', u'jupiter'], 12),
#   ([u'rotation', u'orbit'], 12),
#   ([u'moon-phases', u'the-moon'], 11),
#   ([u'sun', u'light'], 11),
#   ([u'sun', u'observation'], 11),
#   ([u'the-moon', u'gravity'], 11),
#   ([u'black-hole', u'mass'], 11),
#   ([u'sun', u'gravity'], 11),
#   ([u'astrophysics', u'star'], 11),
#   ([u'comets', u'asteroids'], 11),
#   ([u'universe', u'space-time'], 11),
#   ([u'planet', u'sun'], 11),
#   ([u'dark-matter', u'dark-energy'], 11),
#   ([u'earth-like-planet', u'exoplanet'], 11),
#   ([u'planet', u'rotation'], 10),
#   ([u'charon', u'pluto'], 10),
#   ([u'solar-system', u'exoplanet'], 10),
#   ([u'big-bang-theory', u'expansion'], 10),
#   ([u'neutron-star', u'star'], 10),
#   ([u'saturn', u'planetary-ring'], 10),
#   ([u'big-bang-theory', u'space-time'], 10),
#   ([u'exoplanet', u'orbit'], 10),
#   ([u'amateur-observing', u'fundamental-astronomy'], 10),
#   ([u'space-time', u'time-dilation'], 10),
#   ([u'astrophysics', u'gravity'], 10),
#   ([u'solar-system', u'galaxy'], 10),
#   ([u'universe', u'black-hole'], 10),
#   ([u'coordinate', u'star'], 9),
#   ([u'planet', u'gas-giants'], 9),
#   ([u'telescope', u'radio-astronomy'], 9),
#   ([u'lunar-eclipse', u'the-moon'], 9),
#   ([u'supermassive-black-hole', u'gravity'], 9),
#   ([u'solar-system', u'history'], 9)],
#  'aviation.stackexchange.com': [([u'aerodynamics', u'aircraft-design'], 108),
#   ([u'air-traffic-control', u'faa-regulations'], 65),
#   ([u'instrument-flight-rules', u'faa-regulations'], 58),
#   ([u'wing', u'aircraft-design'], 58),
#   ([u'flight-training', u'faa-regulations'], 53),
#   ([u'safety', u'aircraft-design'], 51),
#   ([u'aircraft-design', u'aircraft-performance'], 48),
#   ([u'airliner', u'aircraft-design'], 47),
#   ([u'safety', u'faa-regulations'], 45),
#   ([u'jet-engine', u'aircraft-design'], 43),
#   ([u'airman-certification', u'faa-regulations'], 41),
#   ([u'air-traffic-control', u'radio-communications'], 39),
#   ([u'commercial-aviation', u'safety'], 37),
#   ([u'aerodynamics', u'wing'], 35),
#   ([u'military', u'fighter-jet'], 33),
#   ([u'usa', u'faa-regulations'], 32),
#   ([u'landing', u'takeoff'], 32),
#   ([u'military', u'aircraft-design'], 31),
#   ([u'landing', u'emergency'], 28),
#   ([u'safety', u'emergency'], 28),
#   ([u'airspace', u'faa-regulations'], 28),
#   ([u'flight-data-recorder', u'cockpit-voice-recorder'], 27),
#   ([u'passenger', u'safety'], 27),
#   ([u'accidents', u'safety'], 27),
#   ([u'aerodynamics', u'lift'], 26),
#   ([u'easa-regulations', u'faa-regulations'], 26),
#   ([u'airline-operations', u'airliner'], 26),
#   ([u'airliner', u'safety'], 25),
#   ([u'faa', u'faa-regulations'], 24),
#   ([u'engine', u'jet-engine'], 24),
#   ([u'aerodynamics', u'aircraft-performance'], 24),
#   ([u'air-traffic-control', u'safety'], 24),
#   ([u'medical', u'faa-regulations'], 24),
#   ([u'flight-controls', u'aircraft-design'], 23),
#   ([u'boeing-737', u'aircraft-design'], 23),
#   ([u'aircraft-systems', u'aircraft-design'], 23),
#   ([u'instrument-procedures', u'instrument-flight-rules'], 22),
#   ([u'engine', u'aircraft-design'], 22),
#   ([u'safety', u'landing'], 22),
#   ([u'airport', u'air-traffic-control'], 22),
#   ([u'general-aviation', u'faa-regulations'], 22),
#   ([u'propeller', u'aerodynamics'], 22),
#   ([u'air-traffic-control', u'phraseology'], 22),
#   ([u'landing-gear', u'aircraft-design'], 22),
#   ([u'logging', u'faa-regulations'], 22),
#   ([u'visual-flight-rules', u'faa-regulations'], 22),
#   ([u'airline-operations', u'safety'], 22),
#   ([u'air-traffic-control', u'airspace'], 20),
#   ([u'far-91', u'faa-regulations'], 20),
#   ([u'radar', u'air-traffic-control'], 19),
#   ([u'cockpit', u'aircraft-design'], 19),
#   ([u'aerodynamics', u'helicopter'], 19),
#   ([u'air-traffic-control', u'instrument-flight-rules'], 19),
#   ([u'landing-gear', u'landing'], 19),
#   ([u'aerodynamics', u'drag'], 19),
#   ([u'commercial-aviation', u'airliner'], 19),
#   ([u'flight-training', u'usa'], 18),
#   ([u'aircraft-certification', u'faa-regulations'], 18),
#   ([u'runways', u'landing'], 18),
#   ([u'propeller', u'aircraft-design'], 18),
#   ([u'general-aviation', u'safety'], 17),
#   ([u'weather', u'faa-regulations'], 17),
#   ([u'far-61', u'faa-regulations'], 17),
#   ([u'turbine', u'jet-engine'], 17),
#   ([u'air-traffic-control', u'airline-operations'], 17),
#   ([u'commercial-aviation', u'airline-operations'], 17),
#   ([u'airliner', u'jet-engine'], 17),
#   ([u'airbus', u'boeing'], 17),
#   ([u'airport', u'ground-operations'], 17),
#   ([u'aerodynamics', u'jet-engine'], 17),
#   ([u'air-traffic-control', u'emergency'], 17),
#   ([u'accidents', u'accident-investigation'], 17),
#   ([u'aircraft-maintenance', u'faa-regulations'], 17),
#   ([u'fighter-jet', u'aircraft-design'], 16),
#   ([u'unmanned-aerial-vehicle', u'faa-regulations'], 16),
#   ([u'instrument-procedures', u'faa-regulations'], 16),
#   ([u'airline-operations', u'faa-regulations'], 16),
#   ([u'aerodynamics', u'stall'], 16),
#   ([u'runways', u'airport'], 16),
#   ([u'visual-flight-rules', u'air-traffic-control'], 16),
#   ([u'takeoff', u'aircraft-performance'], 15),
#   ([u'radio-communications', u'faa-regulations'], 15),
#   ([u'commercial-aviation', u'faa-regulations'], 15),
#   ([u'fuel', u'jet-engine'], 15),
#   ([u'airport', u'usa'], 15),
#   ([u'air-traffic-control', u'usa'], 15),
#   ([u'commercial-aviation', u'aircraft-design'], 15),
#   ([u'commercial-operations', u'commercial-aviation'], 15),
#   ([u'engine-failure', u'jet-engine'], 15),
#   ([u'passenger', u'airliner'], 15),
#   ([u'landing', u'aircraft-design'], 14),
#   ([u'ppl', u'faa-regulations'], 14),
#   ([u'aerodynamics', u'supersonic'], 14),
#   ([u'metar', u'weather'], 14),
#   ([u'airline-pilot', u'airline-operations'], 14),
#   ([u'aerodynamics', u'flight-controls'], 14),
#   ([u'airliner', u'wing'], 14),
#   ([u'aircraft-systems', u'airliner'], 14),
#   ([u'stability', u'aerodynamics'], 14),
#   ([u'flight-planning', u'faa-regulations'], 13)],
#  'avp.stackexchange.com': [([u'video', u'video-editor'], 108),
#   ([u'editing', u'video'], 105),
#   ([u'video', u'ffmpeg'], 82),
#   ([u'premiere', u'video'], 69),
#   ([u'audio', u'video'], 68),
#   ([u'video-quality', u'video'], 61),
#   ([u'editing', u'video-editor'], 58),
#   ([u'premiere', u'editing'], 56),
#   ([u'premiere', u'adobe'], 52),
#   ([u'premiere', u'after-effects'], 49),
#   ([u'after-effects', u'animation'], 48),
#   ([u'video', u'software-recommendation'], 45),
#   ([u'video', u'software'], 45),
#   ([u'premiere', u'video-editor'], 44),
#   ([u'after-effects', u'video'], 42),
#   ([u'conversion', u'video'], 40),
#   ([u'codec', u'video'], 40),
#   ([u'streaming', u'video'], 37),
#   ([u'video', u'dslr'], 36),
#   ([u'file-formats', u'video'], 36),
#   ([u'video', u'encoding'], 33),
#   ([u'camera', u'video'], 31),
#   ([u'conversion', u'ffmpeg'], 31),
#   ([u'after-effects-expressions', u'after-effects'], 30),
#   ([u'ffmpeg', u'encoding'], 30),
#   ([u'video-recording', u'video'], 30),
#   ([u'video-editor', u'software-recommendation'], 29),
#   ([u'hardware', u'video'], 28),
#   ([u'premiere', u'audio'], 26),
#   ([u'transcoding', u'ffmpeg'], 26),
#   ([u'streaming', u'live'], 26),
#   ([u'after-effects', u'adobe'], 24),
#   ([u'mp4', u'ffmpeg'], 24),
#   ([u'canon', u'dslr'], 24),
#   ([u'video', u'digital-recording'], 24),
#   ([u'software-recommendation', u'software'], 23),
#   ([u'editing', u'software'], 21),
#   ([u'mp4', u'video'], 21),
#   ([u'video', u'compression'], 21),
#   ([u'after-effects', u'video-editor'], 21),
#   ([u'video', u'effects'], 21),
#   ([u'h.264', u'ffmpeg'], 20),
#   ([u'youtube', u'video'], 20),
#   ([u'editing', u'software-recommendation'], 20),
#   ([u'cs5', u'premiere'], 20),
#   ([u'after-effects', u'adobe-media-encoder'], 19),
#   ([u'canon', u'video'], 19),
#   ([u'final-cut-pro', u'final-cut-pro-x'], 19),
#   ([u'audio', u'sync'], 18),
#   ([u'streaming', u'ffmpeg'], 18),
#   ([u'after-effects', u'editing'], 18),
#   ([u'animation', u'video'], 18),
#   ([u'editing', u'audio'], 17),
#   ([u'audio', u'ffmpeg'], 17),
#   ([u'video', u'sync'], 17),
#   ([u'after-effects', u'effects'], 17),
#   ([u'playback', u'video'], 16),
#   ([u'windows', u'video'], 15),
#   ([u'video-quality', u'video-recording'], 15),
#   ([u'codec', u'ffmpeg'], 15),
#   ([u'framerate', u'video'], 15),
#   ([u'video-quality', u'video-editor'], 15),
#   ([u'premiere', u'effects'], 14),
#   ([u'lighting', u'video'], 14),
#   ([u'special-effects', u'effects'], 14),
#   ([u'sony-vegas', u'video'], 14),
#   ([u'file-formats', u'premiere'], 14),
#   ([u'video', u'recommendation'], 14),
#   ([u'video', u'webvideos'], 14),
#   ([u'live', u'video'], 13),
#   ([u'audio-recording', u'audio'], 13),
#   ([u'video-editor', u'software'], 13),
#   ([u'compression', u'encoding'], 13),
#   ([u'premiere', u'codec'], 13),
#   ([u'after-effects', u'animation-rendering'], 13),
#   ([u'filter', u'ffmpeg'], 13),
#   ([u'file-formats', u'conversion'], 13),
#   ([u'video-quality', u'premiere'], 13),
#   ([u'ffmpeg', u'video-capture'], 12),
#   ([u'audio', u'video-editor'], 12),
#   ([u'conversion', u'mp4'], 12),
#   ([u'h.264', u'encoding'], 12),
#   ([u'editing', u'ffmpeg'], 12),
#   ([u'transcoding', u'video'], 12),
#   ([u'video-quality', u'encoding'], 12),
#   ([u'after-effects', u'3d'], 12),
#   ([u'after-effects', u'audio'], 12),
#   ([u'quicktime', u'video'], 12),
#   ([u'sony-vegas', u'video-editor'], 12),
#   ([u'file-formats', u'video-editor'], 11),
#   ([u'codec', u'encoding'], 11),
#   ([u'video-editor', u'ffmpeg'], 11),
#   ([u'editing', u'effects'], 11),
#   ([u'file-formats', u'codec'], 11),
#   ([u'microphone', u'audio'], 11),
#   ([u'mp4', u'h.264'], 11),
#   ([u'premiere', u'framerate'], 11),
#   ([u'premiere', u'final-cut-pro'], 11),
#   ([u'video-quality', u'compression'], 11),
#   ([u'effects', u'video-editor'], 10)],
#  'beer.stackexchange.com': [([u'breweries', u'local'], 10),
#   ([u'taste', u'style'], 8),
#   ([u'taste', u'flavor'], 7),
#   ([u'taste', u'brewing'], 7),
#   ([u'serving', u'temperature'], 5),
#   ([u'taste', u'history'], 5),
#   ([u'taste', u'storage'], 4),
#   ([u'specialty-beers', u'breweries'], 4),
#   ([u'growlers', u'laws'], 4),
#   ([u'brewing', u'ingredients'], 4),
#   ([u'brewing', u'breweries'], 4),
#   ([u'micropub', u'breweries'], 4),
#   ([u'taste', u'temperature'], 4),
#   ([u'german-beers', u'brewing'], 4),
#   ([u'taste', u'serving'], 4),
#   ([u'style', u'recommendations'], 4),
#   ([u'trappist', u'history'], 3),
#   ([u'production', u'brewing'], 3),
#   ([u'lager', u'style'], 3),
#   ([u'taste', u'glassware'], 3),
#   ([u'specialty-beers', u'history'], 3),
#   ([u'specialty-beers', u'recommendations'], 3),
#   ([u'taste', u'hops'], 3),
#   ([u'terminology', u'history'], 3),
#   ([u'german-beers', u'breweries'], 3),
#   ([u'taste', u'specialty-beers'], 3),
#   ([u'storage', u'temperature'], 3),
#   ([u'lager', u'brewing'], 3),
#   ([u'bottling', u'storage'], 3),
#   ([u'glassware', u'serving'], 3),
#   ([u'taste', u'recommendations'], 3),
#   ([u'specialty-beers', u'flavor'], 3),
#   ([u'flavor', u'brewing'], 3),
#   ([u'brewing', u'yeast'], 2),
#   ([u'local', u'buying'], 2),
#   ([u'pairing', u'cooking'], 2),
#   ([u'brewing', u'history'], 2),
#   ([u'laws', u'history'], 2),
#   ([u'non-alcoholic', u'laws'], 2),
#   ([u'taste', u'alcohol-level'], 2),
#   ([u'brewing', u'temperature'], 2),
#   ([u'hops', u'malt'], 2),
#   ([u'taste', u'german-beers'], 2),
#   ([u'hops', u'flavor'], 2),
#   ([u'taste', u'gas'], 2),
#   ([u'taste', u'drinking'], 2),
#   ([u'taste', u'draught'], 2),
#   ([u'breweries', u'history'], 2),
#   ([u'age', u'storage'], 2),
#   ([u'united-states', u'laws'], 2),
#   ([u'aging', u'bottle-conditioning'], 2),
#   ([u'brewing', u'tasting'], 2),
#   ([u'bottles', u'freshness'], 2),
#   ([u'skunking', u'bottles'], 2),
#   ([u'pennsylvania', u'distribution'], 2),
#   ([u'aroma', u'tasting'], 2),
#   ([u'taste', u'stout'], 2),
#   ([u'serving', u'history'], 2),
#   ([u'german-beers', u'hefeweizen'], 2),
#   ([u'porter', u'stout'], 2),
#   ([u'serving', u'foam'], 2),
#   ([u'ale', u'breweries'], 2),
#   ([u'recommendations', u'history'], 2),
#   ([u'bottling', u'brewing'], 2),
#   ([u'bottles', u'storage'], 2),
#   ([u'carbonation', u'serving'], 2),
#   ([u'lager', u'terminology'], 2),
#   ([u'style', u'classification'], 2),
#   ([u'brewing', u'recommendations'], 2),
#   ([u'ipa', u'breweries'], 2),
#   ([u'distribution', u'recommendations'], 2),
#   ([u'style', u'ipa'], 2),
#   ([u'specialty-beers', u'distribution'], 2),
#   ([u'taste', u'pairing'], 2),
#   ([u'taste', u'bottling'], 2),
#   ([u'specialty-beers', u'local'], 2),
#   ([u'hops', u'history'], 2),
#   ([u'ale', u'local'], 2),
#   ([u'draught', u'bottling'], 2),
#   ([u'head', u'foam'], 2),
#   ([u'bottles', u'cans'], 2),
#   ([u'keg', u'serving'], 2),
#   ([u'brewing', u'alcohol-level'], 2),
#   ([u'alcohol-level', u'history'], 2),
#   ([u'glassware', u'tasting'], 2),
#   ([u'style', u'united-states'], 2),
#   ([u'ipa', u'imperial-ipa'], 2),
#   ([u'style', u'pairing'], 2),
#   ([u'taste', u'ingredients'], 2),
#   ([u'glassware', u'history'], 2),
#   ([u'breweries', u'porter'], 2),
#   ([u'lager', u'ale'], 2),
#   ([u'style', u'serving'], 2),
#   ([u'fermentation', u'wine'], 2),
#   ([u'local', u'laws'], 2),
#   ([u'pennsylvania', u'laws'], 2),
#   ([u'carbonation', u'freshness'], 2),
#   ([u'competition', u'tasting'], 2),
#   ([u'serving', u'storage'], 2),
#   ([u'pairing', u'health'], 2)],
#  'bicycles.stackexchange.com': [([u'tire', u'innertube'], 80),
#   ([u'chain', u'maintenance'], 70),
#   ([u'wheels', u'tire'], 68),
#   ([u'disc-brake', u'brakes'], 64),
#   ([u'puncture', u'tire'], 63),
#   ([u'fork', u'suspension'], 62),
#   ([u'road-bike', u'tire'], 62),
#   ([u'bottom-bracket', u'crankset'], 58),
#   ([u'shimano', u'shifter'], 55),
#   ([u'repair', u'maintenance'], 54),
#   ([u'mountain-bike', u'tire'], 53),
#   ([u'tire', u'rims'], 53),
#   ([u'gears', u'derailleur'], 48),
#   ([u'mountain-bike', u'maintenance'], 47),
#   ([u'chain', u'derailleur'], 46),
#   ([u'wheels', u'hub'], 45),
#   ([u'cassette', u'chain'], 45),
#   ([u'brakes', u'maintenance'], 44),
#   ([u'wheels', u'spokes'], 44),
#   ([u'shifter', u'derailleur'], 43),
#   ([u'wheels', u'rims'], 43),
#   ([u'disc-brake', u'hydraulic-disc-brake'], 42),
#   ([u'mountain-bike', u'road-bike'], 42),
#   ([u'mountain-bike', u'suspension'], 42),
#   ([u'frames', u'road-bike'], 41),
#   ([u'shimano', u'derailleur'], 41),
#   ([u'wheels', u'road-bike'], 40),
#   ([u'gears', u'chain'], 40),
#   ([u'puncture', u'innertube'], 39),
# ...
#   ([u'permalinks', u'custom-post-types'], 433),
#   ([u'taxonomy', u'custom-taxonomy'], 381),
#   ([u'posts', u'categories'], 374),
#   ([u'custom-post-types', u'metabox'], 347),
#   ([u'custom-post-types', u'posts'], 344),
#   ([u'jquery', u'ajax'], 330),
#   ([u'custom-post-types', u'loop'], 329),
#   ([u'permalinks', u'url-rewriting'], 314),
#   ([u'menus', u'navigation'], 312),
#   ([u'custom-post-types', u'categories'], 311),
#   ([u'terms', u'custom-taxonomy'], 299),
#   ([u'jquery', u'javascript'], 292),
#   ([u'media', u'uploads'], 289),
#   ([u'url-rewriting', u'rewrite-rules'], 285),
#   ([u'custom-post-types', u'plugins'], 280),
#   ([u'functions', u'plugins'], 280),
#   ([u'posts', u'customization'], 269),
#   ([u'custom-post-types', u'taxonomy'], 267),
#   ([u'query', u'wp-query'], 266),
#   ([u'posts', u'loop'], 264),
#   ([u'posts', u'pages'], 264),
#   ([u'images', u'uploads'], 261),
#   ([u'custom-post-types', u'customization'], 259),
#   ([u'custom-taxonomy', u'wp-query'], 255),
#   ([u'metabox', u'custom-field'], 251),
#   ([u'url-rewriting', u'custom-post-types'], 251),
#   ([u'pagination', u'wp-query'], 250),
#   ([u'widgets', u'sidebar'], 250),
#   ([u'posts', u'wp-query'], 247),
#   ([u'hooks', u'actions'], 245),
#   ([u'query-posts', u'wp-query'], 242),
#   ([u'plugin-development', u'php'], 240),
#   ([u'mysql', u'database'], 239),
#   ([u'themes', u'plugins'], 238),
#   ([u'meta-query', u'wp-query'], 238),
#   ([u'hooks', u'filters'], 236),
#   ([u'customization', u'plugins'], 234),
#   ([u'custom-post-types', u'php'], 224),
#   ([u'uploads', u'media-library'], 214),
#   ([u'posts', u'plugins'], 213),
#   ([u'post-meta', u'custom-field'], 211),
#   ([u'theme-development', u'php'], 210),
#   ([u'php', u'loop'], 209),
#   ([u'theme-development', u'plugin-development'], 208),
#   ([u'jquery', u'php'], 207),
#   ([u'custom-post-types', u'plugin-development'], 206),
#   ([u'images', u'post-thumbnails'], 206),
#   ([u'custom-post-types', u'pagination'], 200),
#   ([u'wp-query', u'custom-field'], 200),
#   ([u'php', u'posts'], 197),
#   ([u'permalinks', u'custom-taxonomy'], 197),
#   ([u'actions', u'filters'], 191),
#   ([u'custom-post-types', u'custom-post-type-archives'], 189),
#   ([u'ajax', u'php'], 188),
#   ([u'url-rewriting', u'urls'], 185),
#   ([u'php', u'mysql'], 185),
#   ([u'theme-development', u'functions'], 184),
#   ([u'walker', u'menus'], 184),
#   ([u'custom-taxonomy', u'categories'], 183),
#   ([u'javascript', u'php'], 182),
#   ([u'shortcode', u'plugins'], 178),
#   ([u'taxonomy', u'terms'], 175),
#   ([u'loop', u'categories'], 174),
#   ([u'admin', u'wp-admin'], 172),
#   ([u'widgets', u'plugins'], 172),
#   ([u'images', u'attachments'], 172),
#   ([u'templates', u'custom-post-types'], 171),
#   ([u'custom-post-types', u'post-meta'], 170),
#   ([u'taxonomy', u'categories'], 169),
#   ([u'jquery', u'plugins'], 166),
#   ([u'custom-post-types', u'archives'], 164),
#   ([u'custom-post-types', u'query-posts'], 164),
#   ([u'custom-post-types', u'functions'], 163),
#   ([u'functions', u'filters'], 163),
#   ([u'php', u'customization'], 162),
#   ([u'hooks', u'plugins'], 161),
#   ([u'pagination', u'loop'], 160),
#   ([u'multisite', u'plugins'], 160),
#   ([u'wp-query', u'categories'], 160),
#   ([u'user-roles', u'capabilities'], 160),
#   ([u'ajax', u'plugins'], 156),
#   ([u'categories', u'tags'], 155),
#   ([u'redirect', u'htaccess'], 155),
#   ([u'php', u'html'], 154),
#   ([u'theme-development', u'plugins'], 153),
#   ([u'url-rewriting', u'add-rewrite-rule'], 151),
#   ([u'menus', u'sub-menu'], 150),
#   ([u'php', u'css'], 150),
#   ([u'php', u'shortcode'], 149),
#   ([u'functions', u'plugin-development'], 148),
#   ([u'hooks', u'plugin-development'], 147),
#   ([u'url-rewriting', u'custom-taxonomy'], 147)],
#  'workplace.stackexchange.com': [([u'professionalism', u'communication'], 243),
#   ([u'salary', u'negotiation'], 209),
#   ([u'interviewing', u'job-search'], 189),
#   ([u'hiring-process', u'interviewing'], 187),
#   ([u'professionalism', u'management'], 181),
#   ([u'communication', u'management'], 180),
#   ([u'professionalism', u'interviewing'], 164),
#   ([u'professionalism', u'colleagues'], 155),
#   ([u'job-search', u'resume'], 154),
#   ([u'professionalism', u'work-environment'], 151),
#   ([u'professionalism', u'software-industry'], 147),
#   ([u'software-industry', u'interviewing'], 136),
#   ([u'communication', u'colleagues'], 132),
#   ([u'software-industry', u'career-development'], 124),
#   ([u'interviewing', u'resume'], 119),
#   ([u'professionalism', u'ethics'], 104),
#   ([u'software-industry', u'resume'], 101),
#   ([u'recruitment', u'interviewing'], 94),
#   ([u'communication', u'software-industry'], 92),
#   ([u'recruitment', u'job-search'], 91),
#   ([u'colleagues', u'work-environment'], 91),
#   ([u'professionalism', u'hiring-process'], 90),
#   ([u'negotiation', u'job-offer'], 88),
#   ([u'work-experience', u'resume'], 87),
#   ([u'software-industry', u'job-search'], 85),
#   ([u'management', u'software-industry'], 82),
#   ([u'interviewing', u'job-offer'], 81),
#   ([u'communication', u'work-environment'], 81),
#   ([u'hiring-process', u'recruitment'], 80),
#   ([u'professionalism', u'email'], 76),
#   ([u'career-development', u'resume'], 76),
#   ([u'software-industry', u'work-environment'], 74),
#   ([u'salary', u'raise'], 74),
#   ([u'salary', u'job-offer'], 72),
#   ([u'job-change', u'new-job'], 70),
#   ([u'management', u'career-development'], 69),
#   ([u'professionalism', u'career-development'], 67),
#   ([u'job-search', u'new-job'], 63),
#   ([u'hiring-process', u'software-industry'], 63),
#   ([u'salary', u'interviewing'], 62),
#   ([u'professionalism', u'new-job'], 62),
#   ([u'management', u'work-environment'], 62),
#   ([u'job-change', u'job-search'], 62),
#   ([u'hiring-process', u'job-search'], 61),
#   ([u'professionalism', u'job-offer'], 60),
#   ([u'applications', u'job-search'], 60),
#   ([u'interviewing', u'new-job'], 59),
#   ([u'professionalism', u'job-search'], 58),
#   ([u'hiring-process', u'resume'], 57),
#   ([u'internship', u'software-industry'], 55),
#   ([u'job-offer', u'new-job'], 55),
#   ([u'applications', u'resume'], 54),
#   ([u'communication', u'email'], 54),
#   ([u'professionalism', u'resignation'], 53),
#   ([u'professionalism', u'company-culture'], 53),
#   ([u'management', u'team'], 53),
#   ([u'colleagues', u'management'], 52),
#   ([u'professionalism', u'team'], 52),
#   ([u'applications', u'interviewing'], 52),
#   ([u'company-culture', u'work-environment'], 51),
#   ([u'job-change', u'career-development'], 51),
#   ([u'career-development', u'career-switch'], 51),
#   ([u'career-development', u'careers'], 51),
#   ([u'job-change', u'software-industry'], 49),
#   ([u'hiring-process', u'job-offer'], 48),
#   ([u'software-industry', u'work-experience'], 48),
#   ([u'job-change', u'job-offer'], 47),
#   ([u'management', u'project-management'], 47),
#   ([u'software-industry', u'new-job'], 47),
#   ([u'negotiation', u'interviewing'], 46),
#   ([u'recruitment', u'resume'], 46),
#   ([u'software-industry', u'team'], 45),
#   ([u'job-search', u'job-offer'], 45),
#   ([u'work-environment', u'team'], 45),
#   ([u'management', u'human-resources'], 45),
#   ([u'job-search', u'career-development'], 45),
#   ([u'interviewing', u'human-resources'], 44),
#   ([u'unprofessional-behavior', u'professionalism'], 44),
#   ([u'communication', u'team'], 44),
#   ([u'job-change', u'interviewing'], 44),
#   ([u'internship', u'resume'], 43),
#   ([u'internship', u'interviewing'], 43),
#   ([u'job-change', u'professionalism'], 42),
#   ([u'salary', u'professionalism'], 42),
#   ([u'colleagues', u'software-industry'], 42),
#   ([u'communication', u'interviewing'], 41),
#   ([u'cover-letter', u'resume'], 39),
#   ([u'salary', u'software-industry'], 39),
#   ([u'professionalism', u'employer-relations'], 39),
#   ([u'relationships', u'professionalism'], 39),
#   ([u'professionalism', u'resume'], 38),
#   ([u'internship', u'professionalism'], 38),
#   ([u'hiring-process', u'new-job'], 38),
#   ([u'interviewing', u'career-development'], 38),
#   ([u'education', u'resume'], 38),
#   ([u'colleagues', u'team'], 38),
#   ([u'recruitment', u'software-industry'], 38),
#   ([u'communication', u'career-development'], 38),
#   ([u'salary', u'united-states'], 38),
#   ([u'india', u'relieving-letter'], 38)],
#  'worldbuilding.stackexchange.com': [([u'science-based', u'reality-check'],
#    318),
#   ([u'science-based', u'biology'], 236),
#   ([u'science-based', u'planets'], 211),
#   ([u'biology', u'reality-check'], 174),
#   ([u'creature-design', u'reality-check'], 170),
#   ([u'science-based', u'space'], 138),
#   ([u'science-based', u'physics'], 138),
#   ([u'biology', u'evolution'], 125),
#   ([u'evolution', u'reality-check'], 124),
#   ([u'evolution', u'creature-design'], 122),
#   ([u'science-based', u'technology'], 119),
#   ([u'biology', u'creature-design'], 116),
#   ([u'society', u'culture'], 108),
#   ([u'science-based', u'creature-design'], 104),
#   ([u'technology', u'reality-check'], 101),
#   ([u'planets', u'reality-check'], 99),
#   ([u'science-based', u'evolution'], 93),
#   ([u'biology', u'humans'], 89),
#   ([u'society', u'reality-check'], 89),
#   ([u'science-based', u'science-fiction'], 84),
#   ([u'planets', u'space'], 78),
#   ([u'reality-check', u'space'], 75),
#   ([u'science-based', u'climate'], 71),
#   ([u'environment', u'science-based'], 69),
#   ([u'science-based', u'humans'], 67),
#   ([u'society', u'economy'], 65),
#   ([u'society', u'politics'], 65),
#   ([u'society', u'government'], 62),
#   ([u'society', u'magic'], 61),
#   ([u'creature-design', u'mythical-creatures'], 60),
#   ([u'science-based', u'earth-like'], 60),
#   ([u'orbital-mechanics', u'planets'], 59),
#   ([u'science-based', u'apocalypse'], 58),
#   ([u'politics', u'government'], 57),
#   ([u'physics', u'reality-check'], 57),
#   ([u'humans', u'reality-check'], 56),
#   ([u'aliens', u'reality-check'], 56),
#   ([u'weapons', u'science-based'], 56),
#   ([u'society', u'humans'], 56),
#   ([u'science-based', u'warfare'], 54),
#   ([u'weapons', u'warfare'], 53),
#   ([u'science-based', u'magic'], 53),
#   ([u'magic', u'reality-check'], 51),
#   ([u'science-based', u'astronomy'], 51),
#   ([u'physics', u'space'], 51),
#   ([u'mythical-creatures', u'reality-check'], 51),
#   ([u'warfare', u'reality-check'], 51),
#   ([u'magic', u'warfare'], 50),
#   ([u'society', u'science-based'], 48),
#   ([u'technological-development', u'technology'], 48),
#   ([u'stars', u'planets'], 48),
#   ([u'weapons', u'reality-check'], 47),
#   ([u'astronomy', u'planets'], 47),
#   ([u'science-based', u'spaceships'], 47),
#   ([u'science-based', u'spaceflight'], 45),
#   ([u'science-based', u'geography'], 45),
#   ([u'science-based', u'moons'], 44),
#   ([u'earth-like', u'reality-check'], 44),
#   ([u'science-based', u'aliens'], 44),
#   ([u'physics', u'planets'], 43),
#   ([u'technology', u'warfare'], 42),
#   ([u'science-based', u'flora'], 42),
#   ([u'magic', u'technology'], 42),
#   ([u'science-based', u'xenobiology'], 41),
#   ([u'society', u'technology'], 40),
#   ([u'planets', u'moons'], 40),
#   ([u'physics', u'magic'], 40),
#   ([u'climate', u'geography'], 40),
#   ([u'biology', u'xenobiology'], 38),
#   ([u'gravity', u'planets'], 38),
#   ([u'technological-development', u'reality-check'], 37),
#   ([u'fauna', u'reality-check'], 37),
#   ([u'climate', u'planets'], 37),
#   ([u'science-based', u'gravity'], 37),
#   ([u'environment', u'climate'], 36),
#   ([u'apocalypse', u'reality-check'], 36),
#   ([u'orbital-mechanics', u'science-based'], 36),
#   ([u'atmosphere', u'planets'], 36),
#   ([u'earth-like', u'planets'], 35),
#   ([u'society', u'technological-development'], 35),
#   ([u'spaceflight', u'space'], 35),
#   ([u'reality-check', u'government'], 34),
#   ([u'weapons', u'technology'], 34),
#   ([u'reality-check', u'spaceflight'], 34),
#   ([u'biology', u'fauna'], 34),
#   ([u'science-based', u'technological-development'], 34),
#   ([u'culture', u'reality-check'], 34),
#   ([u'aliens', u'biology'], 33),
#   ([u'society', u'religion'], 33),
#   ([u'geology', u'geography'], 33),
#   ([u'science-based', u'atmosphere'], 32),
#   ([u'warfare', u'medieval'], 32),
#   ([u'biology', u'flora'], 32),
#   ([u'science-based', u'stars'], 32),
#   ([u'science-based', u'fauna'], 32),
#   ([u'environment', u'reality-check'], 32),
#   ([u'spaceships', u'spaceflight'], 32),
#   ([u'evolution', u'mythical-creatures'], 32),
#   ([u'biology', u'planets'], 32),
#   ([u'alternate-history', u'warfare'], 31)],
#  'writers.stackexchange.com': [([u'creative-writing', u'fiction'], 227),
#   ([u'creative-writing', u'style'], 102),
#   ([u'novel', u'fiction'], 77),
#   ([u'style', u'fiction'], 75),
#   ([u'style', u'technique'], 65),
#   ([u'plot', u'fiction'], 51),
#   ([u'creative-writing', u'novel'], 49),
#   ([u'character-development', u'characters'], 47),
#   ([u'publishing', u'self-publishing'], 46),
#   ([u'technique', u'fiction'], 46),
#   ([u'characters', u'fiction'], 46),
#   ([u'creative-writing', u'technique'], 44),
#   ([u'fantasy', u'fiction'], 43),
#   ([u'style', u'technical-writing'], 43),
#   ([u'copyright', u'legal'], 42),
#   ([u'character-development', u'fiction'], 39),
#   ([u'tools', u'software'], 39),
#   ([u'style', u'formatting'], 38),
#   ([u'style', u'citations'], 29),
#   ([u'citations', u'mla'], 28),
#   ([u'creative-writing', u'dialogue'], 28),
#   ([u'creative-writing', u'plot'], 28),
#   ([u'style', u'dialogue'], 27),
#   ([u'dialogue', u'fiction'], 27),
#   ([u'style', u'academic-writing'], 26),
#   ([u'publishing', u'fiction'], 26),
#   ([u'publishing', u'copyright'], 25),
#   ([u'apa', u'citations'], 23),
#   ([u'description', u'fiction'], 23),
#   ([u'marketing', u'publishing'], 22),
#   ([u'novel', u'publishing'], 22),
#   ([u'creative-writing', u'characters'], 22),
#   ([u'plot', u'characters'], 22),
#   ([u'plot', u'planning'], 21),
#   ([u'plot', u'storyline'], 21),
#   ([u'publishing', u'legal'], 21),
#   ([u'science-fiction', u'fiction'], 21),
#   ([u'academic-writing', u'citations'], 21),
#   ([u'plot', u'novel'], 20),
#   ([u'creative-writing', u'short-story'], 20),
#   ([u'style', u'editing'], 20),
#   ([u'style', u'word-choice'], 20),
#   ([u'creative-writing', u'description'], 20),
#   ([u'style', u'punctuation'], 20),
#   ([u'naming', u'characters'], 19),
#   ([u'creative-writing', u'fantasy'], 19),
#   ([u'style', u'novel'], 19),
#   ([u'essay', u'academic-writing'], 18),
#   ([u'essay', u'style'], 18),
#   ([u'editing', u'fiction'], 18),
#   ([u'short-story', u'fiction'], 18),
#   ([u'ebook', u'self-publishing'], 18),
#   ([u'novel', u'structure'], 18),
#   ([u'creative-writing', u'character-development'], 17),
#   ([u'dialogue', u'characters'], 17),
#   ([u'structure', u'fiction'], 17),
#   ([u'technique', u'characters'], 17),
#   ([u'academic-writing', u'technical-writing'], 17),
#   ([u'character-development', u'plot'], 17),
#   ([u'planning', u'fiction'], 16),
#   ([u'novel', u'characters'], 16),
#   ([u'creative-writing', u'narrative'], 16),
#   ([u'genre', u'fiction'], 16),
#   ([u'fantasy', u'plot'], 15),
#   ([u'style', u'structure'], 15),
#   ([u'fantasy', u'novel'], 15),
#   ([u'plot', u'structure'], 15),
#   ([u'style', u'description'], 15),
#   ([u'legal', u'fiction'], 15),
#   ([u'character-development', u'technique'], 15),
#   ([u'creative-writing', u'word-choice'], 15),
#   ([u'editing', u'publishing'], 14),
#   ([u'narrative', u'fiction'], 14),
#   ([u'fantasy', u'characters'], 14),
#   ([u'academic-writing', u'research'], 14),
#   ([u'non-fiction', u'technical-writing'], 13),
#   ([u'publishing', u'short-story'], 13),
#   ([u'quotes', u'citations'], 13),
#   ([u'creative-writing', u'structure'], 13),
#   ([u'book', u'publishing'], 13),
#   ([u'editing', u'technical-writing'], 13),
#   ([u'money', u'publishing'], 13),
#   ([u'editing', u'technique'], 13),
#   ([u'openings', u'fiction'], 13),
#   ([u'creative-writing', u'editing'], 13),
#   ([u'publishing', u'agent'], 13),
#   ([u'dialogue', u'punctuation'], 13),
#   ([u'dialogue', u'formatting'], 13),
#   ([u'style', u'publishing'], 13),
#   ([u'creative-writing', u'planning'], 13),
#   ([u'plot', u'technique'], 12),
#   ([u'style', u'grammar'], 12),
#   ([u'creative-writing', u'science-fiction'], 12),
#   ([u'editing', u'novel'], 12),
#   ([u'technical-writing', u'software'], 12),
#   ([u'formatting', u'fiction'], 12),
#   ([u'character-development', u'dialogue'], 12),
#   ([u'style', u'characters'], 12),
#   ([u'tenses', u'fiction'], 12),
#   ([u'creative-writing', u'publishing'], 12)]}
