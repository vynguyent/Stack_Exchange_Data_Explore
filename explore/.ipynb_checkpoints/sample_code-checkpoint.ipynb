# %%
from pymongo import MongoClient
from bson.code import Code
client = MongoClient('localhost', 27272)
client.admin.authenticate("yida", "yida")

database_list = client.database_names()
database_list.pop(database_list.index("admin"))
database_list.pop(database_list.index("local"))
database_list
# Out:
# [u'3dprinting_stackexchange_com',
#  u'academia_stackexchange_com',
#  u'ai_stackexchange_com',
#  u'android_stackexchange_com',
#  u'anime_stackexchange_com',
#  u'apple_stackexchange_com',
#  u'arabic_stackexchange_com',
#  u'arduino_stackexchange_com',
#  u'askubuntu_com',
#  u'astronomy_stackexchange_com',
#  u'aviation_stackexchange_com',
#  u'avp_stackexchange_com',
#  u'beer_stackexchange_com',
#  u'bicycles_stackexchange_com',
#  u'biology_stackexchange_com',
#  u'bitcoin_stackexchange_com',
#  u'blender_stackexchange_com',
#  u'boardgames_stackexchange_com',
#  u'bricks_stackexchange_com',
#  u'buddhism_stackexchange_com',
#  u'chemistry_stackexchange_com',
#  u'chess_stackexchange_com',
#  u'chinese_stackexchange_com',
#  u'christianity_stackexchange_com',
#  u'civicrm_stackexchange_com',
#  u'codegolf_stackexchange_com',
#  u'codereview_stackexchange_com',
#  u'coffee_stackexchange_com',
#  u'cogsci_stackexchange_com',
#  u'computergraphics_stackexchange_com',
#  u'cooking_stackexchange_com',
#  u'craftcms_stackexchange_com',
#  u'crafts_stackexchange_com',
#  u'crypto_stackexchange_com',
#  u'cs_stackexchange_com',
#  u'cstheory_stackexchange_com',
#  u'datascience_stackexchange_com',
#  u'dba_stackexchange_com',
#  u'diy_stackexchange_com',
#  u'drupal_stackexchange_com',
#  u'dsp_stackexchange_com',
#  u'earthscience_stackexchange_com',
#  u'ebooks_stackexchange_com',
#  u'economics_stackexchange_com',
#  u'electronics_stackexchange_com',
#  u'elementaryos_stackexchange_com',
#  u'ell_stackexchange_com',
#  u'emacs_stackexchange_com',
#  u'engineering_stackexchange_com',
#  u'english_stackexchange_com',
#  u'es_stackoverflow_com',
#  u'ethereum_stackexchange_com',
#  u'expatriates_stackexchange_com',
#  u'expressionengine_stackexchange_com',
#  u'fitness_stackexchange_com',
#  u'freelancing_stackexchange_com',
#  u'french_stackexchange_com',
#  u'gamedev_stackexchange_com',
#  u'gaming_stackexchange_com',
#  u'gardening_stackexchange_com',
#  u'genealogy_stackexchange_com',
#  u'german_stackexchange_com',
#  u'gis_stackexchange_com',
#  u'graphicdesign_stackexchange_com',
#  u'ham_stackexchange_com',
#  u'hardwarerecs_stackexchange_com',
#  u'health_stackexchange_com',
#  u'hermeneutics_stackexchange_com',
#  u'hinduism_stackexchange_com',
#  u'history_stackexchange_com',
#  u'homebrew_stackexchange_com',
#  u'hsm_stackexchange_com',
#  u'islam_stackexchange_com',
#  u'italian_stackexchange_com',
#  u'ja_stackoverflow_com',
#  u'japanese_stackexchange_com',
#  u'joomla_stackexchange_com',
#  u'judaism_stackexchange_com',
#  u'korean_stackexchange_com',
#  u'languagelearning_stackexchange_com',
#  u'latin_stackexchange_com',
#  u'law_stackexchange_com',
#  u'lifehacks_stackexchange_com',
#  u'linguistics_stackexchange_com',
#  u'magento_stackexchange_com',
#  u'martialarts_stackexchange_com',
#  u'math_stackexchange_com',
#  u'matheducators_stackexchange_com',
#  u'mathematica_stackexchange_com',
#  u'mathoverflow_net',
#  u'mechanics_stackexchange_com',
#  u'meta_3dprinting_stackexchange_com',
#  u'meta_academia_stackexchange_com',
#  u'meta_ai_stackexchange_com',
#  u'meta_android_stackexchange_com',
#  u'meta_anime_stackexchange_com',
#  u'meta_apple_stackexchange_com',
#  u'meta_arabic_stackexchange_com',
#  u'meta_arduino_stackexchange_com',
#  u'meta_askubuntu_com',
#  u'meta_astronomy_stackexchange_com',
#  u'meta_aviation_stackexchange_com',
#  u'meta_avp_stackexchange_com',
#  u'meta_beer_stackexchange_com',
#  u'meta_bicycles_stackexchange_com',
#  u'meta_biology_stackexchange_com',
#  u'meta_bitcoin_stackexchange_com',
#  u'meta_blender_stackexchange_com',
#  u'meta_boardgames_stackexchange_com',
#  u'meta_bricks_stackexchange_com',
#  u'meta_buddhism_stackexchange_com',
#  u'meta_chemistry_stackexchange_com',
#  u'meta_chess_stackexchange_com',
#  u'meta_chinese_stackexchange_com',
#  u'meta_christianity_stackexchange_com',
#  u'meta_civicrm_stackexchange_com',
#  u'meta_codegolf_stackexchange_com',
#  u'meta_codereview_stackexchange_com',
#  u'meta_coffee_stackexchange_com',
#  u'meta_cogsci_stackexchange_com',
#  u'meta_computergraphics_stackexchange_com',
#  u'meta_cooking_stackexchange_com',
#  u'meta_craftcms_stackexchange_com',
#  u'meta_crafts_stackexchange_com',
#  u'meta_crypto_stackexchange_com',
#  u'meta_cs_stackexchange_com',
#  u'meta_cstheory_stackexchange_com',
#  u'meta_datascience_stackexchange_com',
#  u'meta_dba_stackexchange_com',
#  u'meta_diy_stackexchange_com',
#  u'meta_drupal_stackexchange_com',
#  u'meta_dsp_stackexchange_com',
#  u'meta_earthscience_stackexchange_com',
#  u'meta_ebooks_stackexchange_com',
#  u'meta_economics_stackexchange_com',
#  u'meta_electronics_stackexchange_com',
#  u'meta_elementaryos_stackexchange_com',
#  u'meta_ell_stackexchange_com',
#  u'meta_emacs_stackexchange_com',
#  u'meta_engineering_stackexchange_com',
#  u'meta_english_stackexchange_com',
#  u'meta_es_stackoverflow_com',
#  u'meta_ethereum_stackexchange_com',
#  u'meta_expatriates_stackexchange_com',
#  u'meta_expressionengine_stackexchange_com',
#  u'meta_fitness_stackexchange_com',
#  u'meta_freelancing_stackexchange_com',
#  u'meta_french_stackexchange_com',
#  u'meta_gamedev_stackexchange_com',
#  u'meta_gaming_stackexchange_com',
#  u'meta_gardening_stackexchange_com',
#  u'meta_genealogy_stackexchange_com',
#  u'meta_german_stackexchange_com',
#  u'meta_gis_stackexchange_com',
#  u'meta_graphicdesign_stackexchange_com',
#  u'meta_ham_stackexchange_com',
#  u'meta_hardwarerecs_stackexchange_com',
#  u'meta_health_stackexchange_com',
#  u'meta_hermeneutics_stackexchange_com',
#  u'meta_hinduism_stackexchange_com',
#  u'meta_history_stackexchange_com',
#  u'meta_homebrew_stackexchange_com',
#  u'meta_hsm_stackexchange_com',
#  u'meta_islam_stackexchange_com',
#  u'meta_italian_stackexchange_com',
#  u'meta_ja_stackoverflow_com',
#  u'meta_japanese_stackexchange_com',
#  u'meta_joomla_stackexchange_com',
#  u'meta_judaism_stackexchange_com',
#  u'meta_korean_stackexchange_com',
#  u'meta_languagelearning_stackexchange_com',
#  u'meta_latin_stackexchange_com',
#  u'meta_law_stackexchange_com',
#  u'meta_lifehacks_stackexchange_com',
#  u'meta_linguistics_stackexchange_com',
#  u'meta_magento_stackexchange_com',
#  u'meta_martialarts_stackexchange_com',
#  u'meta_math_stackexchange_com',
#  u'meta_matheducators_stackexchange_com',
#  u'meta_mathematica_stackexchange_com',
#  u'meta_mathoverflow_net',
#  u'meta_mechanics_stackexchange_com',
#  u'meta_moderators_stackexchange_com',
#  u'meta_monero_stackexchange_com',
#  u'meta_money_stackexchange_com',
#  u'meta_movies_stackexchange_com',
#  u'meta_music_stackexchange_com',
#  u'meta_musicfans_stackexchange_com',
#  u'meta_mythology_stackexchange_com',
#  u'meta_networkengineering_stackexchange_com',
#  u'meta_opendata_stackexchange_com',
#  u'meta_opensource_stackexchange_com',
#  u'meta_outdoors_stackexchange_com',
#  u'meta_parenting_stackexchange_com',
#  u'meta_patents_stackexchange_com',
#  u'meta_pets_stackexchange_com',
#  u'meta_philosophy_stackexchange_com',
#  u'meta_photo_stackexchange_com',
#  u'meta_physics_stackexchange_com',
#  u'meta_pm_stackexchange_com',
#  u'meta_poker_stackexchange_com',
#  u'meta_politics_stackexchange_com',
#  u'meta_portuguese_stackexchange_com',
#  u'meta_productivity_stackexchange_com',
#  u'meta_programmers_stackexchange_com',
#  u'meta_pt_stackoverflow_com',
#  u'meta_puzzling_stackexchange_com',
#  u'meta_quant_stackexchange_com',
#  u'meta_raspberrypi_stackexchange_com',
#  u'meta_retrocomputing_stackexchange_com',
#  u'meta_reverseengineering_stackexchange_com',
#  u'meta_robotics_stackexchange_com',
#  u'meta_rpg_stackexchange_com',
#  u'meta_ru_stackoverflow_com',
#  u'meta_rus_stackexchange_com',
#  u'meta_russian_stackexchange_com',
#  u'meta_salesforce_stackexchange_com',
#  u'meta_scicomp_stackexchange_com',
#  u'meta_scifi_stackexchange_com',
#  u'meta_security_stackexchange_com',
#  u'meta_serverfault_com',
#  u'meta_sharepoint_stackexchange_com',
#  u'meta_skeptics_stackexchange_com',
#  u'meta_softwarerecs_stackexchange_com',
#  u'meta_sound_stackexchange_com',
#  u'meta_space_stackexchange_com',
#  u'meta_spanish_stackexchange_com',
#  u'meta_sports_stackexchange_com',
#  u'meta_sqa_stackexchange_com',
#  u'meta_stackexchange_com',
#  u'meta_stackoverflow_com',
#  u'meta_startups_stackexchange_com',
#  u'meta_stats_stackexchange_com',
#  u'meta_superuser_com',
#  u'meta_sustainability_stackexchange_com',
#  u'meta_tex_stackexchange_com',
#  u'meta_tor_stackexchange_com',
#  u'meta_travel_stackexchange_com',
#  u'meta_tridion_stackexchange_com',
#  u'meta_unix_stackexchange_com',
#  u'meta_ux_stackexchange_com',
#  u'meta_vi_stackexchange_com',
#  u'meta_webapps_stackexchange_com',
#  u'meta_webmasters_stackexchange_com',
#  u'meta_windowsphone_stackexchange_com',
#  u'meta_woodworking_stackexchange_com',
#  u'meta_wordpress_stackexchange_com',
#  u'meta_workplace_stackexchange_com',
#  u'meta_worldbuilding_stackexchange_com',
#  u'meta_writers_stackexchange_com',
#  u'moderators_stackexchange_com',
#  u'monero_stackexchange_com',
#  u'money_stackexchange_com',
#  u'movies_stackexchange_com',
#  u'music_stackexchange_com',
#  u'musicfans_stackexchange_com',
#  u'mythology_stackexchange_com',
#  u'networkengineering_stackexchange_com',
#  u'opendata_stackexchange_com',
#  u'opensource_stackexchange_com',
#  u'outdoors_stackexchange_com',
#  u'parenting_stackexchange_com',
#  u'patents_stackexchange_com',
#  u'pets_stackexchange_com',
#  u'philosophy_stackexchange_com',
#  u'photo_stackexchange_com',
#  u'physics_stackexchange_com',
#  u'pm_stackexchange_com',
#  u'poker_stackexchange_com',
#  u'politics_stackexchange_com',
#  u'portuguese_stackexchange_com',
#  u'productivity_stackexchange_com',
#  u'programmers_stackexchange_com',
#  u'pt_stackoverflow_com',
#  u'puzzling_stackexchange_com',
#  u'quant_stackexchange_com',
#  u'raspberrypi_stackexchange_com',
#  u'retrocomputing_stackexchange_com',
#  u'reverseengineering_stackexchange_com',
#  u'robotics_stackexchange_com',
#  u'rpg_stackexchange_com',
#  u'ru_stackoverflow_com',
#  u'rus_stackexchange_com',
#  u'russian_stackexchange_com',
#  u'salesforce_stackexchange_com',
#  u'scicomp_stackexchange_com',
#  u'scifi_stackexchange_com',
#  u'security_stackexchange_com',
#  u'serverfault_com',
#  u'sharepoint_stackexchange_com',
#  u'skeptics_stackexchange_com',
#  u'softwarerecs_stackexchange_com',
#  u'sound_stackexchange_com',
#  u'space_stackexchange_com',
#  u'spanish_stackexchange_com',
#  u'sports_stackexchange_com',
#  u'sqa_stackexchange_com',
#  u'stackapps_com',
#  u'stackoverflow_com',
#  u'startups_stackexchange_com',
#  u'stats_stackexchange_com',
#  u'superuser_com',
#  u'sustainability_stackexchange_com',
#  u'tex_stackexchange_com',
#  u'tor_stackexchange_com',
#  u'travel_stackexchange_com',
#  u'tridion_stackexchange_com',
#  u'unix_stackexchange_com',
#  u'ux_stackexchange_com',
#  u'vi_stackexchange_com',
#  u'webapps_stackexchange_com',
#  u'webmasters_stackexchange_com',
#  u'windowsphone_stackexchange_com',
#  u'woodworking_stackexchange_com',
#  u'wordpress_stackexchange_com',
#  u'workplace_stackexchange_com',
#  u'worldbuilding_stackexchange_com',
#  u'writers_stackexchange_com']

# %%
tag_list = {}
for community in database_list:
    print community
    posts = client[community]['Posts']
    for post in posts.find({"@Tags": {"$exists": True}}):
        tags = post["@Tags"]
        tags = tags.replace("><", ",").replace(">", "").replace("<", "")
        for tag in tags.split(","):
            tag_list[tag] = tag_list[tag] + 1 if tag in tag_list.keys() else 1
# Out:
# 3dprinting_stackexchange_com
# academia_stackexchange_com
# ai_stackexchange_com
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-84caae2cd079> in <module>()
#       3     print community
#       4     posts = client[community]['Posts']
# ----> 5     for post in posts.find({"@Tags": {"$exists": True}}):
#       6         tags = post["@Tags"]
#       7         tags.replace("><", ",").replace(">", "").replace("<", "")
#
# D:\Anacoda2\lib\site-packages\pymongo\cursor.pyc in next(self)
#    1091             if self.__manipulate:
#    1092                 return _db._fix_outgoing(self.__data.popleft(),
# -> 1093                                          self.__collection)
#    1094             else:
#    1095                 return self.__data.popleft()
#
# D:\Anacoda2\lib\site-packages\pymongo\database.pyc in _fix_outgoing(self, son, collection)
#     371           - `collection`: the collection the son object was saved in
#     372         """
# --> 373         for manipulator in reversed(self.__outgoing_manipulators):
#     374             son = manipulator.transform_outgoing(son, collection)
#     375         for manipulator in reversed(self.__outgoing_copying_manipulators):
#
# KeyboardInterrupt:

# %%
print tag_list
# Out:
